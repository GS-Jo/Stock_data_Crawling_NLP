# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
#apt로 나눔폰트설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155229 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
# 폰트지정
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
fm._rebuild()
# Out:
# NanumGothic Eco

# %%
#retina설정 - 뚜렷하게
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

plt.title('안녕')
# Out:
# Text(0.5, 1.0, '안녕')
# findfont: Font family ['NanumGothic Eco'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50504 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['NanumGothic Eco'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50504 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45397 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# konlpy & wordcloud 설치
# !pip install konlpy wordcloud
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 47.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.3.0 konlpy-0.6.0

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#############################################################

# %%
#### 1. konlpy와 nltk를 활용한 주식뉴스 키워드 '워드클라우드' 만들기

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock_news = pd.read_csv('/content/drive/MyDrive/Korean_Stock_Project/stock.csv')

# %%
stock_news
# Out:
#                     date  ...                                              title
# 0       2021.06.30 17:40  ...                       거래소, COWON 제재금 미납 따른 가중벌점 부과
# 1       2021.06.30 10:15  ...  CJ ENM "티빙, NAVER 대상 400억원 규모 3자배정 유상증자" [주목 e공시]
# 2       2021.06.30 17:24  ...                                    [코스닥 공시] CJ ENM
# 3       2021.06.30 10:49  ...               CJ ENM-네이버 결속 강화…티빙 4백억 투자·해외진출도 돕는다
# 4       2021.06.30 19:01  ...                              BYC, 고윤성→김대환 대표이사로 변경
# ...                  ...  ...                                                ...
# 18805   2021.08.29 19:39  ...                              현대글로비스, 협력사와 ESG경영 속도
# 18806   2021.08.29 19:39  ...                         장재훈 현대차 사장 '글로벌 4대 모터쇼' 데뷔
# 18807   2021.08.29 16:43  ...                  현대차, GV60에 통합 제어 OTA 적용...테슬라 넘는다
# 18808   2021.08.29 16:56  ...                            리모델링 '시동' 건 당산 현대홈타운·효성
# 18809   2021.08.29 10:29  ...                          "탄소배출권값 오른다"···휴켐스 '꿈틀꿈틀'
#
# [18810 rows x 5 columns]

# %%
news_title = stock_news['title']
# 명사 추출 위해 타이틀 문자열로 바꿔 담기
title_list = [ str(a) for a in news_title]

# 리스트 제거하기
text = ''

for each in title_list:
  text = text + each + '\n'

# %%
# 형태소분석기 임포트
import nltk
from konlpy.tag import Okt

tf = Okt()

# %%
#명사 추출
title_tokens = tf.nouns(text)
title_tokens
# Out:
# ['거래소',
#  '제재',
#  '금',
#  '미납',
#  '가중',
#  '벌점',
#  '부과',
#  '티빙',
#  '대상',
#  '규모',
#  '자',
#  '배정',
#  '유상증자',
#  '주목',
#  '공시',
#  '코스닥',
#  '공시',
#  '네이버',
#  '결속',
#  '강화',
#  '티빙',
#  '백억',
#  '투자',
#  '해외진출',
#  '고윤성',
#  '김대환',
#  '대표이사',
#  '변경',
#  '글로벌',
#  '브랜드',
#  '세대',
#  '취향',
#  '저격',
#  '감성',
#  '코퍼레이션',
#  '주가',
#  '날개',
#  '맞춤',
#  '건기',
#  '종합',
#  '플랫폼',
#  '변화',
#  '중',
#  '건설',
#  '규모',
#  '인천',
#  '여상',
#  '주변',
#  '재개발',
#  '정비',
#  '사업',
#  '수주',
#  '건설',
#  '인천',
#  '시',
#  '임대주택',
#  '생활',
#  '가전',
#  '지원',
#  '건설',
#  '규모',
#  '재개발',
#  '공사',
#  '수주',
#  '손해',
#  '보험',
#  '수익',
#  '지속',
#  '베스트',
#  '투자',
#  '증권',
#  '손해',
#  '보험',
#  '고객',
#  '약속',
#  '소비자',
#  '중심',
#  '경영',
#  '앞장',
#  '금융투자',
#  '삼성',
#  '전기',
#  '영업',
#  '이익',
#  '역대',
#  '최대',
#  '전망',
#  '주가',
#  '실적',
#  '것',
#  '금융투자',
#  '통합',
#  '자문',
#  '플랫폼',
#  '서비스',
#  '시작',
#  '엔진',
#  '중공업',
#  '규모',
#  '선박',
#  '엔진',
#  '공급',
#  '계약',
#  '체결',
#  '글로벌',
#  '해운',
#  '사',
#  '주가',
#  '고공',
#  '행진',
#  '주춤',
#  '코스피',
#  '나스닥',
#  '최고',
#  '치',
#  '행진',
#  '상승',
#  '출발',
#  '글로벌',
#  '해운',
#  '리더',
#  '올해',
#  '새',
#  '주인',
#  '현장',
#  '사람',
#  '해운',
#  '산업',
#  '정책',
#  '선원',
#  '주가',
#  '숨',
#  '흠슬',
#  '반등',
#  '수',
#  '흠슬',
#  '미래',
#  '척',
#  '배',
#  '초',
#  '호황',
#  '기',
#  '투자',
#  '통합',
#  '리테일',
#  '커머스',
#  '통합',
#  '건설',
#  '상반기',
#  '흥행',
#  '몰이',
#  '이천',
#  '더',
#  '파크',
#  '분양',
#  '대감',
#  '수의',
#  '통합',
#  '리테일',
#  '출범',
#  '매출',
#  '목표',
#  '온',
#  '오프라인',
#  '경계',
#  '허문',
#  '통합',
#  '리테일',
#  '유통',
#  '메기',
#  '리테일',
#  '카페',
#  '배달',
#  '라이프스타일',
#  '플랫폼',
#  '편의점',
#  '삼성',
#  '물산',
#  '건설',
#  '온실가스',
#  '감축',
#  '샵',
#  '에코',
#  '크리에이터',
#  '모집',
#  '영상',
#  '전하',
#  '자원',
#  '순환',
#  '캠페인',
#  '글로벌',
#  '회사채',
#  '예측',
#  '배',
#  '이상',
#  '자금',
#  '바이오',
#  '스페셜',
#  '도',
#  '젤',
#  '인수',
#  '전',
#  '참가',
#  '대기업',
#  '눈독',
#  '매력',
#  '뭐길',
#  '임',
#  '직원',
#  '소아',
#  '암',
#  '어린이',
#  '위',
#  '주머니',
#  '캠페인',
#  '참여',
#  '소비자',
#  '웰빙',
#  '환경',
#  '만족',
#  '지수',
#  '창호',
#  '부문',
#  '연속',
#  '위',
#  '수상',
#  '금융',
#  '안정',
#  '실적',
#  '주주',
#  '가치',
#  '제',
#  '방안',
#  '긍정',
#  '목표',
#  '주가',
#  '교보',
#  '아이에이치큐',
#  '규모',
#  '무기명',
#  '무',
#  '보증',
#  '사모',
#  '전환사채',
#  '발행',
#  '신한지주',
#  '생건',
#  '상반기',
#  '성과',
#  '우수',
#  '기업',
#  '라이프',
#  '디지털',
#  '서비스',
#  '교류',
#  '협력',
#  '강화',
#  '라이프',
#  '홈',
#  '트레이닝',
#  '플랫폼',
#  '사업',
#  '체결',
#  '태국',
#  '통신사',
#  '트루',
#  '현지',
#  '사업',
#  '공략',
#  '태국',
#  '시장',
#  '진출',
#  '클라우드',
#  '카드',
#  '마이',
#  '데이터',
#  '손',
#  '영역',
#  '파괴',
#  '선언',
#  '알파',
#  '판',
#  '현모',
#  '대표',
#  '차세대',
#  '유니콘',
#  '과',
#  '사업',
#  '가속',
#  '사진',
#  '카드',
#  '마이',
#  '데이터',
#  '서비스',
#  '위',
#  '클라우드',
#  '구축',
#  '모터',
#  '스',
#  '자회사',
#  '에이치',
#  '케이',
#  '알',
#  '흡수',
#  '합병',
#  '종료',
#  '전자',
#  '미니',
#  '출시',
#  '삼성',
#  '기업',
#  '파전',
#  '미니',
#  '시장',
#  '삼성',
#  '전자',
#  '선제',
#  '공격',
#  '전자',
#  '참전',
#  '전자',
#  '등판',
#  '미니',
#  '전쟁',
#  '진화',
#  '정점',
#  '전자',
#  '미니',
#  '출시',
#  '최초',
#  '최대',
#  '화학',
#  '발행',
#  '그린',
#  '본드',
#  '돈',
#  '인프라',
#  '투자',
#  '합의',
#  '수혜',
#  '가능',
#  '하이',
#  '화학',
#  '거래',
#  '일',
#  '연속',
#  '외국인',
#  '사자',
#  '상승',
#  '얼굴',
#  '보고',
#  '차도',
#  '자동',
#  '개폐',
#  '오토',
#  '모티브',
#  '기술',
#  '도전',
#  '이노',
#  '텍',
#  '영업',
#  '익',
#  '컨센서스',
#  '상회',
#  '전망',
#  '전장',
#  '연간',
#  '흑자',
#  '가능',
#  '신한지주',
#  '생건',
#  '상반기',
#  '성과',
#  '우수',
#  '기업',
#  '쇼핑',
#  '축제',
#  '희비',
#  '생건',
#  '아모레퍼시픽',
#  '울',
#  '포트',
#  '라이트',
#  '생건',
#  '성장',
#  '흐름',
#  '지속',
#  '스틴',
#  '베스트',
#  '신한지주',
#  '생건',
#  '상반기',
#  '최우수',
#  '마',
#  '그나',
#  '합작',
#  '법인',
#  '출범',
#  '전장',
#  '사업',
#  '완전체',
#  '엘지',
#  '마',
#  '그나',
#  '출범',
#  '보쉬',
#  '덴소',
#  '진검',
#  '승부',
#  '전자',
#  '미니',
#  '적용',
#  '본격',
#  '출시',
#  '전자',
#  '미니',
#  '적용',
#  '미니',
#  '출시',
#  '출시',
#  '빛',
#  '색',
#  '표현',
#  '정점',
#  '미니',
#  '적용',
#  '이데일리',
#  '삼성',
#  '전자',
#  '특허',
#  '등록',
#  '그룹',
#  '별로',
#  '그룹',
#  '위',
#  '엠',
#  '하우스',
#  '알파',
#  '공식',
#  '출범',
#  '디지털',
#  '커머스',
#  '새',
#  '판',
#  '연',
#  '유',
#  '기풍',
#  '사외이사',
#  '일신상',
#  '이유',
#  '자진',
#  '사임',
#  '이데일리',
#  '증권',
#  '앱',
#  '만족도',
#  '점',
#  '만점',
#  '점',
#  '투자',
#  '증권',
#  '앱',
#  '만족도',
#  '최고',
#  '상반기',
#  '리그',
#  '테이블',
#  '투자',
#  '증권',
#  '하나',
#  '삼성',
#  '인수',
#  '금융',
#  '위',
#  '탈환',
#  '상반기',
#  '리그',
#  '테이블',
#  '투자',
#  '증권',
#  '선두',
#  '질주',
#  '투자',
#  '증권',
#  '헌혈',
#  '날',
#  '기념',
#  '표창',
#  '수상',
#  '티빙',
#  '대상',
#  '규모',
#  '자',
#  '배정',
#  '유상증자',
#  '주목',
#  '공시',
#  '건강',
#  '정보',
#  '눈',
#  '나',
#  '건강',
#  '기록',
#  '앱',
#  '이제',
#  '네이버',
#  '카카오',
#  '이용',
#  '네이버',
#  '분투',
#  '티빙',
#  '리지',
#  '널',
#  '콘텐츠',
#  '가속',
#  '에쓰오일',
#  '울산',
#  '상가',
#  '화재',
#  '진압',
#  '소방관',
#  '유족',
#  '위로',
#  '금',
#  '네이버',
#  '창업',
#  '이해진',
#  '리더',
#  '전면',
#  '영진',
#  '쇄신',
#  '해결',
#  '책',
#  '울산',
#  '상가',
#  '화재',
#  '순직',
#  '소방관',
#  '유족',
#  '위로',
#  '금',
#  '퍼포먼스',
#  '마케팅',
#  '플랫폼',
#  '텐핑',
#  '네이버',
#  '브랜드',
#  '커넥트',
#  '서비스',
#  '협력',
#  '사',
#  '선정',
#  '혈맹',
#  '강화',
#  '네이버',
#  '티빙',
#  '분',
#  '투자',
#  '네이버',
#  '카카오',
#  '톡',
#  '나',
#  '건강',
#  '기록',
#  '확인',
#  '철강',
#  '가격',
#  '점',
#  '수도',
#  '유진',
#  '포스코',
#  '인터',
#  '무역',
#  '호조',
#  '미얀마',
#  '가스전',
#  '상쇄',
#  '목표',
#  '포스코',
#  '영업',
#  '이익',
#  '최대',
#  '예상',
#  '포스코',
#  '건',
#  '자재',
#  '베스',
#  '토',
#  '빔',
#  '국내',
#  '최초',
#  '인증',
#  '획득',
#  '포스코',
#  '철',
#  '이름',
#  '테마',
#  '파크',
#  '운영',
#  '거래소',
#  '호스',
#  '팩',
#  '상장폐지',
#  '사유',
#  '발생',
#  '정리',
#  '매매',
#  '현대',
#  '글로벌',
#  '서비스',
#  '글로벌',
#  '차세대',
#  '시스템',
#  '착수',
#  '엔솔',
#  '삼성',
#  '위',
#  '리츠',
#  '상장',
#  '추진',
#  '이사회',
#  '의결',
#  '하반기',
#  '코스피',
#  '상장',
#  '목표',
#  '인텔',
#  '낸드',
#  '인수',
#  '변수',
#  '업계',
#  '관심',
#  '중국',
#  '통',
#  '최태원',
#  '자산',
#  '리츠',
#  '하반기',
#  '상장',
#  '공시',
#  '케미칼',
#  '젤',
#  '인수',
#  '당사',
#  '무관',
#  '오후',
#  '주식시장',
#  '하이닉스',
#  '카카오',
#  '강세',
#  '코스피',
#  '또',
#  '사상',
#  '최고',
#  '찍',
#  '반도체',
#  '대세',
#  '상승',
#  '문제',
#  '삼성',
#  '하이닉스',
#  '실적',
#  '맑음',
#  '텔레콤',
#  '인베',
#  '적정',
#  '총',
#  '최소',
#  '매수',
#  '현대차',
#  '증권',
#  '특징',
#  '주',
#  '마이크론',
#  '반도체',
#  '우려',
#  '불',
#  '하이닉스',
#  '강세',
#  '부정',
#  '신용',
#  '전망',
#  '꼬리표',
#  '하이닉스',
#  '낸드',
#  '부문',
#  '하반기',
#  '흑자',
#  '전환',
#  '예상',
#  '마켓',
#  '인사이트',
#  '특징',
#  '주',
#  '하이닉스',
#  '외국인',
#  '집중',
#  '매수',
#  '상승',
#  '양자',
#  '기술',
#  '경쟁력',
#  '통신',
#  '사',
#  '현대차',
#  '하이닉스',
#  '하이닉스',
#  '외인',
#  '매수',
#  '강세',
#  '하이닉스',
#  '램',
#  '정보',
#  '댐',
#  '텔레콤',
#  '멤버십',
#  '대폭',
#  '변경',
#  '할인',
#  '적립',
#  '방식',
#  '표준',
#  '협회',
#  '결과',
#  '발표',
#  '텔레콤',
#  '연속',
#  '위',
#  '아웃백',
#  '적립',
#  '파바',
#  '멤버십',
#  '개편',
#  '텔레콤',
#  '최첨단',
#  '기술',
#  '무장',
#  '품질',
#  '위',
#  '바사',
#  '비교',
#  '임',
#  '수출',
#  '우려',
#  '대한',
#  '개발',
#  '회사',
#  '입장',
#  '모건',
#  '이노베이션',
#  '목표',
#  '제시',
#  '원자재',
#  '상향',
#  '사이클',
#  '특징',
#  '주',
#  '이노베이션',
#  '투자',
#  '의견',
#  '상향',
#  '호실',
#  '대감',
#  '가수',
#  '노지훈',
#  '이노베이션',
#  '산',
#  '진미',
#  '캠페인',
#  '송',
#  '재능기부',
#  '특징',
#  '주',
#  '아이',
#  '테크놀로지',
#  '수요',
#  '급증',
#  '대감',
#  '연일',
#  '강세',
#  '거래',
#  '일',
#  '연속',
#  '외인',
#  '매수',
#  '상승세',
#  '지속',
#  '머티리얼즈',
#  '행복',
#  '얼라이언스',
#  '영주시',
#  '행복',
#  '끼',
#  '프로젝트',
#  '협약',
#  '디스커버리',
#  '젤',
#  '인수',
#  '당사',
#  '관련',
#  '내용',
#  '사실',
#  '디',
#  '앤디',
#  '규모',
#  '연료',
#  '발전소',
#  '공사',
#  '수주',
#  '트릴',
#  '리온',
#  '명품',
#  '브랜드',
#  '사랑',
#  '뮤즈',
#  '지드래곤',
#  '의',
#  '샴푸',
#  '프리',
#  '론칭',
#  '광고',
#  '공개',
#  '단독',
#  '파인트',
#  '리',
#  '파트너',
#  '스',
#  '중공업',
#  '분',
#  '블록딜',
#  '컨소시엄',
#  '흥',
#  '해운',
#  '인수',
#  '금',
#  '전액',
#  '류덕',
#  '경동제약',
#  '창업',
#  '주',
#  '퇴임',
#  '류',
#  '기성',
#  '대표',
#  '단독',
#  '체제',
#  '증',
#  '선위',
#  '공시',
#  '의무',
#  '위반',
#  '디',
#  '에스티',
#  '경방',
#  '과징금',
#  '경동제약',
#  '창업',
#  '주',
#  '류덕',
#  '회장',
#  '퇴임',
#  '너',
#  '세',
#  '단독',
#  '경영',
#  '돌입',
#  '거래소',
#  '경남',
#  '헬',
#  '스케',
#  '상장폐지',
#  '관련',
#  '이의신청',
#  '접수',
#  '글로벌',
#  '브랜드',
#  '세대',
#  '취향',
#  '저격',
#  '감성',
#  '코퍼레이션',
#  '주가',
#  '날개',
#  '강원랜드',
#  '탄소',
#  '인프라',
#  '구축',
#  '광명',
#  '전기',
#  '규모',
#  '도시',
#  '생활',
#  '주택',
#  '신축',
#  '공사',
#  '수주',
#  '유가',
#  '증권',
#  '시장',
#  '공시',
#  '광명',
#  '전기',
#  '건설',
#  '골프',
#  '인기',
#  '골프',
#  '존',
#  '아카데미',
#  '호점',
#  '개관',
#  '광동',
#  '제약',
#  '기능',
#  '표시',
#  '옥수수',
#  '수염',
#  '차',
#  '출시',
#  '탁원',
#  '내달',
#  '개',
#  '상',
#  '장사',
#  '의무',
#  '보유',
#  '해제',
#  '교보',
#  '증권',
#  '분',
#  '포함',
#  '국동',
#  '트로이',
#  '코로나',
#  '날숨',
#  '포집',
#  '키트',
#  '독점',
#  '판매',
#  '계약',
#  '체결',
#  '국동',
#  '규모',
#  '무기명',
#  '무',
#  '보증',
#  '사모',
#  '전환사채',
#  '발행',
#  '상',
#  '장사',
#  '교보',
#  '증권',
#  '중소기업',
#  '은행',
#  '등',
#  '곳',
#  '주식',
#  '의무',
#  '보유',
#  '해제',
#  '기아',
#  '새',
#  '로고',
#  '첨단',
#  '달',
#  '고급',
#  '차',
#  '정',
#  '조준',
#  '기아',
#  '텔루',
#  '라이드',
#  '더',
#  '산다',
#  '토요타',
#  '특징',
#  '주',
#  '엑사',
#  '엔씨',
#  '현대',
#  '기아차',
#  '차세대',
#  '전기차',
#  '히터',
#  '도입',
#  '소식',
#  '강세',
#  '기업은행',
#  '자체',
#  '오픈',
#  '플랫폼',
#  '구축',
#  '핀',
#  '테크',
#  '협업',
#  '기대',
#  '나노',
#  '켐텍',
#  '사회',
#  '취약',
#  ...]

# %%
## 단어의 등장빈도를 보자

# %%
# Text메서드에 넣어 활용해보자.
TT = nltk.Text(title_tokens)

print(len(set(TT.tokens)))
TT.vocab()
# Out:
# 147153
# 11210
# FreqDist({'거래소': 90,
#           '제재': 14,
#           '금': 43,
#           '미납': 7,
#           '가중': 3,
#           '벌점': 3,
#           '부과': 12,
#           '티빙': 8,
#           '대상': 159,
#           '규모': 774,
#           '자': 221,
#           '배정': 61,
#           '유상증자': 161,
#           '주목': 257,
#           '공시': 550,
#           '코스닥': 275,
#           '네이버': 626,
#           '결속': 1,
#           '강화': 156,
#           '백억': 2,
#           '투자': 925,
#           '해외진출': 9,
#           '고윤성': 1,
#           '김대환': 1,
#           '대표이사': 43,
#           '변경': 129,
#           '글로벌': 300,
#           '브랜드': 155,
#           '세대': 84,
#           '취향': 5,
#           '저격': 5,
#           '감성': 8,
#           '코퍼레이션': 41,
#           '주가': 475,
#           '날개': 39,
#           '맞춤': 35,
#           '건기': 20,
#           '종합': 169,
#           '플랫폼': 173,
#           '변화': 17,
#           '중': 155,
#           '건설': 527,
#           '인천': 21,
#           '여상': 1,
#           '주변': 3,
#           '재개발': 17,
#           '정비': 22,
#           '사업': 710,
#           '수주': 219,
#           '시': 29,
#           '임대주택': 2,
#           '생활': 61,
#           '가전': 63,
#           '지원': 240,
#           '공사': 146,
#           '손해': 20,
#           '보험': 80,
#           '수익': 117,
#           '지속': 150,
#           '베스트': 64,
#           '증권': 954,
#           '고객': 150,
#           '약속': 10,
#           '소비자': 42,
#           '중심': 39,
#           '경영': 247,
#           '앞장': 14,
#           '금융투자': 40,
#           '삼성': 2174,
#           '전기': 99,
#           '영업': 1196,
#           '이익': 413,
#           '역대': 179,
#           '최대': 572,
#           '전망': 273,
#           '실적': 980,
#           '것': 244,
#           '통합': 64,
#           '자문': 6,
#           '서비스': 242,
#           '시작': 93,
#           '엔진': 10,
#           '중공업': 180,
#           '선박': 23,
#           '공급': 365,
#           '계약': 444,
#           '체결': 298,
#           '해운': 23,
#           '사': 231,
#           '고공': 18,
#           '행진': 40,
#           '주춤': 24,
#           '코스피': 211,
#           '나스닥': 12,
#           '최고': 165,
#           '치': 30,
#           '상승': 257,
#           '출발': 23,
#           '리더': 20,
#           '올해': 157,
#           '새': 84,
#           '주인': 14,
#           '현장': 35,
#           '사람': 15,
#           '산업': 200,
#           '정책': 17,
#           '선원': 5,
#           '숨': 8,
#           '흠슬': 2,
#           '반등': 103,
#           '수': 73,
#           '미래': 126,
#           '척': 34,
#           '배': 164,
#           '초': 108,
#           '호황': 29,
#           '기': 57,
#           '리테일': 110,
#           '커머스': 59,
#           '상반기': 352,
#           '흥행': 66,
#           '몰이': 4,
#           '이천': 19,
#           '더': 234,
#           '파크': 25,
#           '분양': 132,
#           '대감': 178,
#           '수의': 2,
#           '출범': 61,
#           '매출': 491,
#           '목표': 565,
#           '온': 52,
#           '오프라인': 17,
#           '경계': 3,
#           '허문': 1,
#           '유통': 46,
#           '메기': 1,
#           '카페': 77,
#           '배달': 29,
#           '라이프스타일': 6,
#           '편의점': 17,
#           '물산': 69,
#           '온실가스': 10,
#           '감축': 22,
#           '샵': 23,
#           '에코': 164,
#           '크리에이터': 7,
#           '모집': 58,
#           '영상': 47,
#           '전하': 1,
#           '자원': 8,
#           '순환': 12,
#           '캠페인': 85,
#           '회사채': 67,
#           '예측': 31,
#           '이상': 62,
#           '자금': 87,
#           '바이오': 680,
#           '스페셜': 21,
#           '도': 99,
#           '젤': 64,
#           '인수': 424,
#           '전': 141,
#           '참가': 22,
#           '대기업': 23,
#           '눈독': 8,
#           '매력': 46,
#           '뭐길': 9,
#           '임': 188,
#           '직원': 106,
#           '소아': 2,
#           '암': 12,
#           '어린이': 26,
#           '위': 692,
#           '주머니': 1,
#           '참여': 114,
#           '웰빙': 7,
#           '환경': 72,
#           '만족': 11,
#           '지수': 28,
#           '창호': 1,
#           '부문': 85,
#           '연속': 166,
#           '수상': 76,
#           '금융': 347,
#           '안정': 33,
#           '주주': 236,
#           '가치': 100,
#           '제': 403,
#           '방안': 8,
#           '긍정': 58,
#           '교보': 25,
#           '아이에이치큐': 4,
#           '무기명': 2,
#           '무': 45,
#           '보증': 43,
#           '사모': 34,
#           '전환사채': 71,
#           '발행': 219,
#           '신한지주': 10,
#           '생건': 36,
#           '성과': 53,
#           '우수': 38,
#           '기업': 518,
#           '라이프': 39,
#           '디지털': 152,
#           '교류': 8,
#           '협력': 194,
#           '홈': 36,
#           '트레이닝': 1,
#           '태국': 12,
#           '통신사': 2,
#           '트루': 7,
#           '현지': 20,
#           '공략': 82,
#           '시장': 391,
#           '진출': 183,
#           '클라우드': 76,
#           '카드': 118,
#           '마이': 36,
#           '데이터': 67,
#           '손': 132,
#           '영역': 7,
#           '파괴': 3,
#           '선언': 23,
#           '알파': 16,
#           '판': 68,
#           '현모': 16,
#           '대표': 141,
#           '차세대': 57,
#           '유니콘': 17,
#           '과': 31,
#           '가속': 49,
#           '사진': 19,
#           '구축': 140,
#           '모터': 27,
#           '스': 173,
#           '자회사': 190,
#           '에이치': 105,
#           '케이': 97,
#           '알': 52,
#           '흡수': 43,
#           '합병': 126,
#           '종료': 28,
#           '전자': 1185,
#           '미니': 31,
#           '출시': 619,
#           '파전': 17,
#           '선제': 6,
#           '공격': 14,
#           '참전': 14,
#           '등판': 7,
#           '전쟁': 20,
#           '진화': 13,
#           '정점': 4,
#           '최초': 150,
#           '화학': 282,
#           '그린': 92,
#           '본드': 9,
#           '돈': 28,
#           '인프라': 35,
#           '합의': 33,
#           '수혜': 89,
#           '가능': 107,
#           '하이': 110,
#           '거래': 205,
#           '일': 94,
#           '외국인': 186,
#           '사자': 14,
#           '얼굴': 2,
#           '보고': 8,
#           '차도': 1,
#           '자동': 16,
#           '개폐': 1,
#           '오토': 20,
#           '모티브': 16,
#           '기술': 339,
#           '도전': 49,
#           '이노': 197,
#           '텍': 199,
#           '익': 847,
#           '컨센서스': 20,
#           '상회': 27,
#           '전장': 40,
#           '연간': 26,
#           '흑자': 183,
#           '쇼핑': 106,
#           '축제': 6,
#           '희비': 14,
#           '아모레퍼시픽': 59,
#           '울': 13,
#           '포트': 13,
#           '라이트': 21,
#           '성장': 385,
#           '흐름': 11,
#           '스틴': 2,
#           '최우수': 7,
#           '마': 30,
#           '그나': 15,
#           '합작': 31,
#           '법인': 115,
#           '완전체': 1,
#           '엘지': 6,
#           '보쉬': 2,
#           '덴소': 1,
#           '진검': 2,
#           '승부': 51,
#           '적용': 59,
#           '본격': 171,
#           '빛': 13,
#           '색': 4,
#           '표현': 2,
#           '이데일리': 39,
#           '특허': 104,
#           '등록': 28,
#           '그룹': 319,
#           '별로': 3,
#           '엠': 116,
#           '하우스': 12,
#           '공식': 27,
#           '연': 56,
#           '유': 122,
#           '기풍': 1,
#           '사외이사': 28,
#           '일신상': 2,
#           '이유': 118,
#           '자진': 4,
#           '사임': 7,
#           '앱': 57,
#           '만족도': 17,
#           '점': 130,
#           '만점': 4,
#           '리그': 9,
#           '테이블': 4,
#           '하나': 183,
#           '탈환': 24,
#           '선두': 13,
#           '질주': 50,
#           '헌혈': 9,
#           '날': 34,
#           '기념': 37,
#           '표창': 6,
#           '건강': 83,
#           '정보': 51,
#           '눈': 33,
#           '나': 34,
#           '기록': 58,
#           '이제': 22,
#           '카카오': 766,
#           '이용': 23,
#           '분투': 10,
#           '리지': 8,
#           '널': 8,
#           '콘텐츠': 76,
#           '에쓰오일': 23,
#           '울산': 24,
#           '상가': 3,
#           '화재': 56,
#           '진압': 1,
#           '소방관': 4,
#           '유족': 3,
#           '위로': 14,
#           '창업': 19,
#           '이해진': 1,
#           '전면': 20,
#           '영진': 20,
#           '쇄신': 1,
#           '해결': 17,
#           '책': 11,
#           '순직': 1,
#           '퍼포먼스': 2,
#           '마케팅': 67,
#           '텐핑': 2,
#           '커넥트': 3,
#           '선정': 132,
#           '혈맹': 6,
#           '분': 271,
#           '톡': 13,
#           '확인': 58,
#           '철강': 33,
#           '가격': 101,
#           '수도': 8,
#           '유진': 78,
#           '포스코': 317,
#           '인터': 50,
#           '무역': 15,
#           '호조': 84,
#           '미얀마': 5,
#           '가스전': 9,
#           '상쇄': 1,
#           '예상': 99,
#           '건': 43,
#           '자재': 23,
#           '베스': 1,
#           '토': 7,
#           '빔': 1,
#           '국내': 235,
#           '인증': 89,
#           '획득': 83,
#           '철': 23,
#           '이름': 15,
#           '테마': 20,
#           '운영': 63,
#           '호스': 26,
#           '팩': 67,
#           '상장폐지': 25,
#           '사유': 8,
#           '발생': 44,
#           '정리': 20,
#           '매매': 36,
#           '현대': 794,
#           '시스템': 190,
#           '착수': 19,
#           '엔솔': 33,
#           '리츠': 168,
#           '상장': 251,
#           '추진': 184,
#           '이사회': 11,
#           '의결': 5,
#           '하반기': 444,
#           '인텔': 58,
#           '낸드': 32,
#           '변수': 15,
#           '업계': 74,
#           '관심': 41,
#           '중국': 86,
#           '통': 29,
#           '최태원': 33,
#           '자산': 76,
#           '케미칼': 169,
#           '당사': 2,
#           '무관': 6,
#           '오후': 10,
#           '주식시장': 3,
#           '하이닉스': 387,
#           '강세': 422,
#           '또': 82,
#           '사상': 166,
#           '찍': 6,
#           '반도체': 393,
#           '대세': 8,
#           '문제': 20,
#           '맑음': 14,
#           '텔레콤': 58,
#           '인베': 6,
#           '적정': 11,
#           '총': 183,
#           '최소': 10,
#           '매수': 184,
#           '현대차': 714,
#           '특징': 916,
#           '주': 1342,
#           '마이크론': 25,
#           '우려': 94,
#           '불': 70,
#           '부정': 12,
#           '신용': 42,
#           '꼬리표': 2,
#           '전환': 324,
#           '마켓': 335,
#           '인사이트': 200,
#           '집중': 81,
#           '양자': 8,
#           '경쟁력': 47,
#           '통신': 43,
#           '외인': 47,
#           '램': 38,
#           '댐': 3,
#           '멤버십': 33,
#           '대폭': 16,
#           '할인': 88,
#           '적립': 17,
#           '방식': 15,
#           '표준': 14,
#           '협회': 19,
#           '결과': 27,
#           '발표': 81,
#           '아웃백': 1,
#           '파바': 2,
#           '개편': 28,
#           '최첨단': 3,
#           '무장': 2,
#           '품질': 28,
#           '바사': 65,
#           '비교': 12,
#           '수출': 125,
#           '대한': 12,
#           '개발': 412,
#           '회사': 88,
#           '입장': 4,
#           '모건': 3,
#           '이노베이션': 102,
#           '제시': 23,
#           '원자재': 9,
#           '상향': 103,
#           '사이클': 23,
#           '의견': 107,
#           '호실': 158,
#           '가수': 4,
#           '노지훈': 1,
#           '산': 32,
#           '진미': 7,
#           '송': 2,
#           '재능기부': 1,
#           '아이': 156,
#           '테크놀로지': 37,
#           '수요': 93,
#           '급증': 64,
#           '연일': 16,
#           '상승세': 44,
#           '머티리얼즈': 67,
#           '행복': 8,
#           '얼라이언스': 4,
#           '영주시': 1,
#           '끼': 8,
#           '프로젝트': 40,
#           '협약': 175,
#           '디스커버리': 4,
#           '관련': 121,
#           '내용': 3,
#           '사실': 26,
#           '디': 92,
#           '앤디': 34,
#           '연료': 45,
#           '발전소': 11,
#           '트릴': 27,
#           '리온': 28,
#           '명품': 25,
#           '사랑': 20,
#           '뮤즈': 2,
#           '지드래곤': 4,
#           '의': 96,
#           '샴푸': 21,
#           '프리': 26,
#           '론칭': 63,
#           '광고': 69,
#           '공개': 135,
#           '단독': 151,
#           '파인트': 2,
#           '리': 82,
#           '파트너': 55,
#           '블록딜': 10,
#           '컨소시엄': 36,
#           '흥': 3,
#           '전액': 3,
#           '류덕': 2,
#           '경동제약': 4,
#           '퇴임': 5,
#           '류': 4,
#           '기성': 1,
#           '체제': 27,
#           '증': 18,
#           '선위': 2,
#           '의무': 9,
#           '위반': 14,
#           '에스티': 48,
#           '경방': 6,
#           '과징금': 27,
#           '회장': 134,
#           '너': 16,
#           '세': 210,
#           '돌입': 39,
#           '경남': 17,
#           '헬': 72,
#           '스케': 75,
#           '이의신청': 7,
#           '접수': 25,
#           '강원랜드': 31,
#           '탄소': 122,
#           '광명': 7,
#           '도시': 12,
#           '주택': 56,
#           '신축': 33,
#           '유가': 149,
#           '골프': 56,
#           '인기': 68,
#           '존': 41,
#           '아카데미': 9,
#           '호점': 10,
#           '개관': 17,
#           '광동': 16,
#           '제약': 148,
#           '기능': 41,
#           '표시': 4,
#           '옥수수': 5,
#           '수염': 2,
#           '차': 132,
#           '탁원': 3,
#           '내달': 56,
#           '개': 142,
#           '상': 169,
#           '장사': 28,
#           '보유': 76,
#           '해제': 12,
#           '포함': 7,
#           '국동': 12,
#           '트로이': 2,
#           '코로나': 386,
#           '날숨': 1,
#           '포집': 3,
#           '키트': 107,
#           '독점': 32,
#           '판매': 292,
#           '중소기업': 21,
#           '은행': 89,
#           '등': 645,
#           '곳': 76,
#           '주식': 293,
#           '기아': 310,
#           '로고': 2,
#           '첨단': 102,
#           '달': 133,
#           '고급': 8,
#           '정': 39,
#           '조준': 19,
#           '텔루': 3,
#           '라이드': 3,
#           '산다': 7,
#           '토요타': 3,
#           '엑사': 6,
#           '엔씨': 31,
#           '기아차': 12,
#           '전기차': 175,
#           '히터': 3,
#           '도입': 97,
#           '소식': 186,
#           '기업은행': 75,
#           '자체': 18,
#           '오픈': 115,
#           '핀': 21,
#           '테크': 150,
#           '협업': 58,
#           '기대': 422,
#           '나노': 36,
#           '켐텍': 4,
#           '사회': 60,
#           '취약': 23,
#           '계층': 23,
#           '화장품': 40,
#           '기부': 43,
#           '남양유업': 69,
#           '세종': 32,
#           '공장': 208,
#           '개월': 60,
#           '영업정지': 7,
#           '확정': 57,
#           '고개': 1,
#           '단백질': 6,
#           '두유': 3,
#           '프로': 78,
#           '틴': 18,
#           '남성': 4,
#           '양재': 3,
#           '택': 3,
#           '고수': 56,
#           '지금': 68,
#           '진원': 23,
#           '생명과학': 36,
#           '네이처': 17,
#           '셀': 87,
#           '매도': 130,
#           '활발': 9,
#           '클릭': 143,
#           '종목': 241,
#           '농심': 80,
#           '라면': 57,
#           '인상': 95,
#           '개선': 285,
#           '녹원': 1,
#           '프라나': 1,
#           '랩': 69,
#           '처분': 76,
#           '결정': 428,
#           '거': 17,
#           '버넌스': 11,
#           '워치': 74,
#           '식품': 55,
#           '생산': 169,
#           '노바': 17,
#           '렉스': 31,
#           '넷마블': 91,
#           '모멘텀': 88,
#           '대구': 23,
#           '백화점': 89,
#           '역사': 12,
#           '뒤안길': 1,
#           '악화': 7,
#           '눈물': 4,
#           '다스': 2,
#           '코': 101,
#           '태양광': 33,
#           '도로': 7,
#           '안전': 84,
#           '시설': 37,
#           '시너지': 43,
#           '대화': 15,
#           '총력': 10,
#           '뉴': 75,
#           '로스': 9,
#           '철회': 19,
#           '한국': 438,
#           '조선해': 57,
#           '대우조선': 27,
#           '기한': 4,
#           '연장': 30,
#           '윤석열': 16,
#           '로': 220,
#           '크게': 5,
#           '오른': 23,
#           '대원': 6,
#           '전선': 8,
#           '전무': 10,
#           '화난': 1,
#           '창선': 3,
#           '중흥': 27,
#           '대우건설': 104,
#           '인': 56,
#           '수단': 4,
#           '직접': 21,
#           '진두': 2,
#           '지휘': 2,
#           '왜': 85,
#           '인사': 49,
#           '대신': 156,
#           '여객': 8,
#           '의존': 4,
#           '대한항공': 107,
#           '먹거리': 20,
#           '확보': 129,
#           '대현': 3,
#           '업황': 25,
#           '평가': 156,
#           '신용등급': 28,
#           '급': 26,
#           '타석': 1,
#           '홈런': 6,
#           '의류': 10,
#           '분석': 30,
#           '급등': 237,
#           '항공사': 1,
#           '채권': 28,
#           '뭉칫돈': 6,
#           '아시아나': 69,
#           '계획': 49,
#           '안': 61,
#           '최종': 20,
#           '뱅크': 87,
#           '항': 22,
#           '공유': 19,
#           '친환경': 186,
#           '활성화': 21,
#           '후': 114,
#           '일방': 2,
#           '운임': 18,
#           '스탁': 3,
#           '대한민국': 34,
#           '하나투어': 17,
#           '약진': 7,
#           '왕산': 2,
#           '레저': 15,
#           '매각': 201,
#           '우선': 25,
#           '협상': 43,
#           '대상자': 9,
#           '칸': 4,
#           '자산운용': 8,
#           '대한전선': 9,
#           '조직': 33,
#           '체계': 12,
#           '확립': 2,
#           '호반': 3,
#           '편입': 40,
#           '급부': 3,
#           '가스': 50,
#           '국가': 24,
#           '동방': 7,
#           '위원회': 33,
#           '위원장': 6,
#           '동국제강': 18,
#           '공채': 11,
#           '정치권': 3,
#           '도이치': 7,
#           '조작': 4,
#           '사건': 2,
#           '주가조작': 1,
#           '더블유': 22,
#           '게임': 252,
#           '설명': 45,
#           '회': 94,
#           '개최': 128,
#           '동아': 38,
#           '홀딩스': 154,
#           '보고서': 129,
#           '가마솥': 2,
#           '동양': 32,
#           '생명': 119,
#           '두산인프라코어': 56,
#           '관리': 81,
#           '두산': 171,
#           '스마트': 148,
#           '핵심': 76,
#           '브리핑': 10,
#           '조달': 45,
#           '속도': 79,
#           '육박': 12,
#           '퓨얼': 20,
#           '모채': 20,
#           '차환용': 3,
#           '개인': 55,
#           '동일': 7,
#           '고무': 11,
#           '벨트': 4,
#           '볼보': 2,
#           '기계': 49,
#           '롤러': 2,
#           '동원': 55,
#           '국제': 56,
#           '해안': 1,
#           '클린': 6,
#           '업': 57,
#           '데이': 15,
#           '행사': 76,
#           '진행': 189,
#           '간편식': 15,
#           '요거트': 3,
#           '덴마크': 1,
#           '거밀': 1,
#           '리딩': 7,
#           '김': 21,
#           '평주': 1,
#           '양반': 2,
#           '콜라보': 17,
#           '선봬': 59,
#           '해운대구': 2,
#           '숙박시설': 4,
#           '디아': 8,
#           '이씨': 11,
#           '계': 84,
#           '열사': 70,
#           '채무': 43,
#           '알텍': 2,
#           '동영상': 6,
#           '디텍터': 1,
#           '일본': 35,
#           '에이': 126,
#           '디지탈': 9,
#           '옵': 29,
#           '취득': 187,
#           '소각': 16,
#           '예정': 51,
#           '락앤락': 35,
#           '일상': 12,
#           '특별': 20,
#           '쇼케이스': 1,
#           '디자인': 51,
#           '대회': 25,
#           '도약': 47,
#           '셀트리온': 186,
#           '삼바': 32,
#           '투톱': 8,
#           '레고': 14,
#           '켐': 19,
#           '라이': 14,
#           '징': 12,
#           '스타': 61,
#           '릭스': 5,
#           '솔루션': 185,
#           '리노': 6,
#           '공업': 19,
#           '더존': 15,
#           '비즈': 51,
#           '솔': 23,
#           '브레인': 14,
#           '독보': 7,
#           '강소기업': 2,
#           '롯데': 380,
#           '푸드': 110,
#           '아이스크림': 10,
#           '구독': 48,
#           '힙스터': 1,
#           '페스티벌': 9,
#           '하이마트': 28,
#           '메이드': 19,
#           '위생': 9,
#           '라인업': 22,
#           '확대': 296,
#           '맘': 6,
#           '드림': 41,
#           '엄마': 2,
#           '꿈': 19,
#           '응원': 11,
#           '칠성': 54,
#           '굿': 28,
#           '달성': 126,
#           '공동': 114,
#           '노력': 15,
#           '반월': 3,
#           '시화': 2,
#           '슬로베니아': 1,
#           '불가리아': 1,
#           '서도': 20,
#           '휘바': 1,
#           '제과': 41,
#           '동유럽': 2,
#           '정밀': 31,
#           '경고': 14,
#           '손보': 39,
#           '위험관리': 1,
#           '재편': 13,
#           '매일유업': 27,
#           '비방': 1,
#           '사과': 4,
#           '신고': 119,
#           '경신': 61,
#           '워랩': 1,
#           '서울대': 11,
#           '병원': 33,
#           '멕': 4,
#           '에스': 223,
#           '수면': 5,
#           '호흡': 6,
#           '치료': 212,
#           '표': 68,
#           '메': 176,
#           '사주': 144,
#           '신청': 135,
#           '역': 70,
#           '테이퍼링': 3,
#           '실시': 74,
#           '유동성': 10,
#           '증가': 237,
#           '유지': 51,
#           '증시': 30,
#           '타격': 10,
#           '지난달': 5,
#           '일임': 1,
#           '수익률': 49,
#           '메리츠화재': 8,
#           '신탁': 46,
#           '포스트': 18,
#           '간엽': 2,
#           '줄기세포': 13,
#           '배양': 5,
#           '방법': 9,
#           '캐나다': 14,
#           '미래에셋': 74,
#           '증권사': 38,
#           '성공': 82,
#           '세포': 31,
#           '활': 6,
#           '면역': 22,
#           '니아': 22,
#           '패혈증': 4,
#           '신약': 84,
#           '후보': 28,
#           '물질': 22,
#           '출원': 18,
#           '미코': 13,
#           '비상교육': 5,
#           '국정': 2,
#           '도서': 3,
#           '비보': 7,
#           '평': 17,
#           '신규': 130,
#           '부지': 14,
#           '매입': 19,
#           '브릿지': 11,
#           '특': 18,
#           '발성': 2,
#           '폐': 27,
#           '섬유': 13,
#           '브이': 23,
#           '티': 88,
#           '지엠': 14,
#           '피': 70,
#           '부티크': 1,
#           '주상': 6,
#           '복합': 33,
#           '아파트': 39,
#           '스타일': 13,
#           '뷰웍스': 6,
#           '하이엔드': 6,
#           '용': 133,
#           '카메라': 21,
#           '눈길': 27,
#           '큐': 22,
#           '레이': 36,
#           '션': 27,
#           '빅데이터': 22,
#           '기반': 62,
#           '시계': 15,
#           '혁신': 99,
#           '탁': 9,
#           '돌파': 153,
#           '이노션': 24,
#           '격차': 33,
#           '무한': 10,
#           '영토': 10,
#           '확장': 49,
#           '수소차': 14,
#           ...})

# %%
# stopword 설정하기
stop_words = ['.','(',')',',',"'",'%','-','X','[',']','의','자',
              '에','안','번','호','을','이','다','만','로','가','를',
              '금','중','시','사','치','새','숨','수','척','배','초',
              '기','더','온','전','임','위','무','손','판','과','년',
              '익','눈','나','날','점','젤','스','토','또','주','등',
              '제']

TT = [word for word in TT if word not in stop_words]
TT
# Out:
# ['거래소',
#  '제재',
#  '미납',
#  '가중',
#  '벌점',
#  '부과',
#  '티빙',
#  '대상',
#  '규모',
#  '배정',
#  '유상증자',
#  '주목',
#  '공시',
#  '코스닥',
#  '공시',
#  '네이버',
#  '결속',
#  '강화',
#  '티빙',
#  '백억',
#  '투자',
#  '해외진출',
#  '고윤성',
#  '김대환',
#  '대표이사',
#  '변경',
#  '글로벌',
#  '브랜드',
#  '세대',
#  '취향',
#  '저격',
#  '감성',
#  '코퍼레이션',
#  '주가',
#  '날개',
#  '맞춤',
#  '건기',
#  '종합',
#  '플랫폼',
#  '변화',
#  '건설',
#  '규모',
#  '인천',
#  '여상',
#  '주변',
#  '재개발',
#  '정비',
#  '사업',
#  '수주',
#  '건설',
#  '인천',
#  '임대주택',
#  '생활',
#  '가전',
#  '지원',
#  '건설',
#  '규모',
#  '재개발',
#  '공사',
#  '수주',
#  '손해',
#  '보험',
#  '수익',
#  '지속',
#  '베스트',
#  '투자',
#  '증권',
#  '손해',
#  '보험',
#  '고객',
#  '약속',
#  '소비자',
#  '중심',
#  '경영',
#  '앞장',
#  '금융투자',
#  '삼성',
#  '전기',
#  '영업',
#  '이익',
#  '역대',
#  '최대',
#  '전망',
#  '주가',
#  '실적',
#  '것',
#  '금융투자',
#  '통합',
#  '자문',
#  '플랫폼',
#  '서비스',
#  '시작',
#  '엔진',
#  '중공업',
#  '규모',
#  '선박',
#  '엔진',
#  '공급',
#  '계약',
#  '체결',
#  '글로벌',
#  '해운',
#  '주가',
#  '고공',
#  '행진',
#  '주춤',
#  '코스피',
#  '나스닥',
#  '최고',
#  '행진',
#  '상승',
#  '출발',
#  '글로벌',
#  '해운',
#  '리더',
#  '올해',
#  '주인',
#  '현장',
#  '사람',
#  '해운',
#  '산업',
#  '정책',
#  '선원',
#  '주가',
#  '흠슬',
#  '반등',
#  '흠슬',
#  '미래',
#  '호황',
#  '투자',
#  '통합',
#  '리테일',
#  '커머스',
#  '통합',
#  '건설',
#  '상반기',
#  '흥행',
#  '몰이',
#  '이천',
#  '파크',
#  '분양',
#  '대감',
#  '수의',
#  '통합',
#  '리테일',
#  '출범',
#  '매출',
#  '목표',
#  '오프라인',
#  '경계',
#  '허문',
#  '통합',
#  '리테일',
#  '유통',
#  '메기',
#  '리테일',
#  '카페',
#  '배달',
#  '라이프스타일',
#  '플랫폼',
#  '편의점',
#  '삼성',
#  '물산',
#  '건설',
#  '온실가스',
#  '감축',
#  '샵',
#  '에코',
#  '크리에이터',
#  '모집',
#  '영상',
#  '전하',
#  '자원',
#  '순환',
#  '캠페인',
#  '글로벌',
#  '회사채',
#  '예측',
#  '이상',
#  '자금',
#  '바이오',
#  '스페셜',
#  '도',
#  '인수',
#  '참가',
#  '대기업',
#  '눈독',
#  '매력',
#  '뭐길',
#  '직원',
#  '소아',
#  '암',
#  '어린이',
#  '주머니',
#  '캠페인',
#  '참여',
#  '소비자',
#  '웰빙',
#  '환경',
#  '만족',
#  '지수',
#  '창호',
#  '부문',
#  '연속',
#  '수상',
#  '금융',
#  '안정',
#  '실적',
#  '주주',
#  '가치',
#  '방안',
#  '긍정',
#  '목표',
#  '주가',
#  '교보',
#  '아이에이치큐',
#  '규모',
#  '무기명',
#  '보증',
#  '사모',
#  '전환사채',
#  '발행',
#  '신한지주',
#  '생건',
#  '상반기',
#  '성과',
#  '우수',
#  '기업',
#  '라이프',
#  '디지털',
#  '서비스',
#  '교류',
#  '협력',
#  '강화',
#  '라이프',
#  '홈',
#  '트레이닝',
#  '플랫폼',
#  '사업',
#  '체결',
#  '태국',
#  '통신사',
#  '트루',
#  '현지',
#  '사업',
#  '공략',
#  '태국',
#  '시장',
#  '진출',
#  '클라우드',
#  '카드',
#  '마이',
#  '데이터',
#  '영역',
#  '파괴',
#  '선언',
#  '알파',
#  '현모',
#  '대표',
#  '차세대',
#  '유니콘',
#  '사업',
#  '가속',
#  '사진',
#  '카드',
#  '마이',
#  '데이터',
#  '서비스',
#  '클라우드',
#  '구축',
#  '모터',
#  '자회사',
#  '에이치',
#  '케이',
#  '알',
#  '흡수',
#  '합병',
#  '종료',
#  '전자',
#  '미니',
#  '출시',
#  '삼성',
#  '기업',
#  '파전',
#  '미니',
#  '시장',
#  '삼성',
#  '전자',
#  '선제',
#  '공격',
#  '전자',
#  '참전',
#  '전자',
#  '등판',
#  '미니',
#  '전쟁',
#  '진화',
#  '정점',
#  '전자',
#  '미니',
#  '출시',
#  '최초',
#  '최대',
#  '화학',
#  '발행',
#  '그린',
#  '본드',
#  '돈',
#  '인프라',
#  '투자',
#  '합의',
#  '수혜',
#  '가능',
#  '하이',
#  '화학',
#  '거래',
#  '일',
#  '연속',
#  '외국인',
#  '사자',
#  '상승',
#  '얼굴',
#  '보고',
#  '차도',
#  '자동',
#  '개폐',
#  '오토',
#  '모티브',
#  '기술',
#  '도전',
#  '이노',
#  '텍',
#  '영업',
#  '컨센서스',
#  '상회',
#  '전망',
#  '전장',
#  '연간',
#  '흑자',
#  '가능',
#  '신한지주',
#  '생건',
#  '상반기',
#  '성과',
#  '우수',
#  '기업',
#  '쇼핑',
#  '축제',
#  '희비',
#  '생건',
#  '아모레퍼시픽',
#  '울',
#  '포트',
#  '라이트',
#  '생건',
#  '성장',
#  '흐름',
#  '지속',
#  '스틴',
#  '베스트',
#  '신한지주',
#  '생건',
#  '상반기',
#  '최우수',
#  '마',
#  '그나',
#  '합작',
#  '법인',
#  '출범',
#  '전장',
#  '사업',
#  '완전체',
#  '엘지',
#  '마',
#  '그나',
#  '출범',
#  '보쉬',
#  '덴소',
#  '진검',
#  '승부',
#  '전자',
#  '미니',
#  '적용',
#  '본격',
#  '출시',
#  '전자',
#  '미니',
#  '적용',
#  '미니',
#  '출시',
#  '출시',
#  '빛',
#  '색',
#  '표현',
#  '정점',
#  '미니',
#  '적용',
#  '이데일리',
#  '삼성',
#  '전자',
#  '특허',
#  '등록',
#  '그룹',
#  '별로',
#  '그룹',
#  '엠',
#  '하우스',
#  '알파',
#  '공식',
#  '출범',
#  '디지털',
#  '커머스',
#  '연',
#  '유',
#  '기풍',
#  '사외이사',
#  '일신상',
#  '이유',
#  '자진',
#  '사임',
#  '이데일리',
#  '증권',
#  '앱',
#  '만족도',
#  '만점',
#  '투자',
#  '증권',
#  '앱',
#  '만족도',
#  '최고',
#  '상반기',
#  '리그',
#  '테이블',
#  '투자',
#  '증권',
#  '하나',
#  '삼성',
#  '인수',
#  '금융',
#  '탈환',
#  '상반기',
#  '리그',
#  '테이블',
#  '투자',
#  '증권',
#  '선두',
#  '질주',
#  '투자',
#  '증권',
#  '헌혈',
#  '기념',
#  '표창',
#  '수상',
#  '티빙',
#  '대상',
#  '규모',
#  '배정',
#  '유상증자',
#  '주목',
#  '공시',
#  '건강',
#  '정보',
#  '건강',
#  '기록',
#  '앱',
#  '이제',
#  '네이버',
#  '카카오',
#  '이용',
#  '네이버',
#  '분투',
#  '티빙',
#  '리지',
#  '널',
#  '콘텐츠',
#  '가속',
#  '에쓰오일',
#  '울산',
#  '상가',
#  '화재',
#  '진압',
#  '소방관',
#  '유족',
#  '위로',
#  '네이버',
#  '창업',
#  '이해진',
#  '리더',
#  '전면',
#  '영진',
#  '쇄신',
#  '해결',
#  '책',
#  '울산',
#  '상가',
#  '화재',
#  '순직',
#  '소방관',
#  '유족',
#  '위로',
#  '퍼포먼스',
#  '마케팅',
#  '플랫폼',
#  '텐핑',
#  '네이버',
#  '브랜드',
#  '커넥트',
#  '서비스',
#  '협력',
#  '선정',
#  '혈맹',
#  '강화',
#  '네이버',
#  '티빙',
#  '분',
#  '투자',
#  '네이버',
#  '카카오',
#  '톡',
#  '건강',
#  '기록',
#  '확인',
#  '철강',
#  '가격',
#  '수도',
#  '유진',
#  '포스코',
#  '인터',
#  '무역',
#  '호조',
#  '미얀마',
#  '가스전',
#  '상쇄',
#  '목표',
#  '포스코',
#  '영업',
#  '이익',
#  '최대',
#  '예상',
#  '포스코',
#  '건',
#  '자재',
#  '베스',
#  '빔',
#  '국내',
#  '최초',
#  '인증',
#  '획득',
#  '포스코',
#  '철',
#  '이름',
#  '테마',
#  '파크',
#  '운영',
#  '거래소',
#  '호스',
#  '팩',
#  '상장폐지',
#  '사유',
#  '발생',
#  '정리',
#  '매매',
#  '현대',
#  '글로벌',
#  '서비스',
#  '글로벌',
#  '차세대',
#  '시스템',
#  '착수',
#  '엔솔',
#  '삼성',
#  '리츠',
#  '상장',
#  '추진',
#  '이사회',
#  '의결',
#  '하반기',
#  '코스피',
#  '상장',
#  '목표',
#  '인텔',
#  '낸드',
#  '인수',
#  '변수',
#  '업계',
#  '관심',
#  '중국',
#  '통',
#  '최태원',
#  '자산',
#  '리츠',
#  '하반기',
#  '상장',
#  '공시',
#  '케미칼',
#  '인수',
#  '당사',
#  '무관',
#  '오후',
#  '주식시장',
#  '하이닉스',
#  '카카오',
#  '강세',
#  '코스피',
#  '사상',
#  '최고',
#  '찍',
#  '반도체',
#  '대세',
#  '상승',
#  '문제',
#  '삼성',
#  '하이닉스',
#  '실적',
#  '맑음',
#  '텔레콤',
#  '인베',
#  '적정',
#  '총',
#  '최소',
#  '매수',
#  '현대차',
#  '증권',
#  '특징',
#  '마이크론',
#  '반도체',
#  '우려',
#  '불',
#  '하이닉스',
#  '강세',
#  '부정',
#  '신용',
#  '전망',
#  '꼬리표',
#  '하이닉스',
#  '낸드',
#  '부문',
#  '하반기',
#  '흑자',
#  '전환',
#  '예상',
#  '마켓',
#  '인사이트',
#  '특징',
#  '하이닉스',
#  '외국인',
#  '집중',
#  '매수',
#  '상승',
#  '양자',
#  '기술',
#  '경쟁력',
#  '통신',
#  '현대차',
#  '하이닉스',
#  '하이닉스',
#  '외인',
#  '매수',
#  '강세',
#  '하이닉스',
#  '램',
#  '정보',
#  '댐',
#  '텔레콤',
#  '멤버십',
#  '대폭',
#  '변경',
#  '할인',
#  '적립',
#  '방식',
#  '표준',
#  '협회',
#  '결과',
#  '발표',
#  '텔레콤',
#  '연속',
#  '아웃백',
#  '적립',
#  '파바',
#  '멤버십',
#  '개편',
#  '텔레콤',
#  '최첨단',
#  '기술',
#  '무장',
#  '품질',
#  '바사',
#  '비교',
#  '수출',
#  '우려',
#  '대한',
#  '개발',
#  '회사',
#  '입장',
#  '모건',
#  '이노베이션',
#  '목표',
#  '제시',
#  '원자재',
#  '상향',
#  '사이클',
#  '특징',
#  '이노베이션',
#  '투자',
#  '의견',
#  '상향',
#  '호실',
#  '대감',
#  '가수',
#  '노지훈',
#  '이노베이션',
#  '산',
#  '진미',
#  '캠페인',
#  '송',
#  '재능기부',
#  '특징',
#  '아이',
#  '테크놀로지',
#  '수요',
#  '급증',
#  '대감',
#  '연일',
#  '강세',
#  '거래',
#  '일',
#  '연속',
#  '외인',
#  '매수',
#  '상승세',
#  '지속',
#  '머티리얼즈',
#  '행복',
#  '얼라이언스',
#  '영주시',
#  '행복',
#  '끼',
#  '프로젝트',
#  '협약',
#  '디스커버리',
#  '인수',
#  '당사',
#  '관련',
#  '내용',
#  '사실',
#  '디',
#  '앤디',
#  '규모',
#  '연료',
#  '발전소',
#  '공사',
#  '수주',
#  '트릴',
#  '리온',
#  '명품',
#  '브랜드',
#  '사랑',
#  '뮤즈',
#  '지드래곤',
#  '샴푸',
#  '프리',
#  '론칭',
#  '광고',
#  '공개',
#  '단독',
#  '파인트',
#  '리',
#  '파트너',
#  '중공업',
#  '분',
#  '블록딜',
#  '컨소시엄',
#  '흥',
#  '해운',
#  '인수',
#  '전액',
#  '류덕',
#  '경동제약',
#  '창업',
#  '퇴임',
#  '류',
#  '기성',
#  '대표',
#  '단독',
#  '체제',
#  '증',
#  '선위',
#  '공시',
#  '의무',
#  '위반',
#  '디',
#  '에스티',
#  '경방',
#  '과징금',
#  '경동제약',
#  '창업',
#  '류덕',
#  '회장',
#  '퇴임',
#  '너',
#  '세',
#  '단독',
#  '경영',
#  '돌입',
#  '거래소',
#  '경남',
#  '헬',
#  '스케',
#  '상장폐지',
#  '관련',
#  '이의신청',
#  '접수',
#  '글로벌',
#  '브랜드',
#  '세대',
#  '취향',
#  '저격',
#  '감성',
#  '코퍼레이션',
#  '주가',
#  '날개',
#  '강원랜드',
#  '탄소',
#  '인프라',
#  '구축',
#  '광명',
#  '전기',
#  '규모',
#  '도시',
#  '생활',
#  '주택',
#  '신축',
#  '공사',
#  '수주',
#  '유가',
#  '증권',
#  '시장',
#  '공시',
#  '광명',
#  '전기',
#  '건설',
#  '골프',
#  '인기',
#  '골프',
#  '존',
#  '아카데미',
#  '호점',
#  '개관',
#  '광동',
#  '제약',
#  '기능',
#  '표시',
#  '옥수수',
#  '수염',
#  '차',
#  '출시',
#  '탁원',
#  '내달',
#  '개',
#  '상',
#  '장사',
#  '의무',
#  '보유',
#  '해제',
#  '교보',
#  '증권',
#  '분',
#  '포함',
#  '국동',
#  '트로이',
#  '코로나',
#  '날숨',
#  '포집',
#  '키트',
#  '독점',
#  '판매',
#  '계약',
#  '체결',
#  '국동',
#  '규모',
#  '무기명',
#  '보증',
#  '사모',
#  '전환사채',
#  '발행',
#  '상',
#  '장사',
#  '교보',
#  '증권',
#  '중소기업',
#  '은행',
#  '곳',
#  '주식',
#  '의무',
#  '보유',
#  '해제',
#  '기아',
#  '로고',
#  '첨단',
#  '달',
#  '고급',
#  '차',
#  '정',
#  '조준',
#  '기아',
#  '텔루',
#  '라이드',
#  '산다',
#  '토요타',
#  '특징',
#  '엑사',
#  '엔씨',
#  '현대',
#  '기아차',
#  '차세대',
#  '전기차',
#  '히터',
#  '도입',
#  '소식',
#  '강세',
#  '기업은행',
#  '자체',
#  '오픈',
#  '플랫폼',
#  '구축',
#  '핀',
#  '테크',
#  '협업',
#  '기대',
#  '나노',
#  '켐텍',
#  '사회',
#  '취약',
#  '계층',
#  '규모',
#  '화장품',
#  '기부',
#  '공시',
#  '남양유업',
#  '세종',
#  '공장',
#  '개월',
#  '영업정지',
#  '확정',
#  '고개',
#  '남양유업',
#  '남양유업',
#  '단백질',
#  '두유',
#  '하이',
#  '프로',
#  '틴',
#  '출시',
#  '남성',
#  '양재',
#  '택',
#  '사외이사',
#  '일신상',
#  '이유',
#  '자진',
#  '사임',
#  '주식',
#  '고수',
#  '지금',
#  '진원',
#  '생명과학',
#  '네이처',
#  '셀',
#  '매수',
#  '매도',
#  '활발',
#  '클릭',
#  '종목',
#  '농심',
#  '라면',
#  '인상',
#  '이익',
#  '개선',
#  '전망',
#  '녹원',
#  '아이',
#  '프라나',
#  '랩',
#  '처분',
#  '결정',
#  '거',
#  '버넌스',
#  '워치',
#  '건강',
#  '기능',
#  '식품',
#  '생산',
#  '노바',
#  '렉스',
#  '시작',
#  '클릭',
#  '종목',
#  '넷마블',
#  '모멘텀',
#  '목표',
#  ...]

# %%
# 빈도순 차트

tt = nltk.Text(TT)

plt.figure(figsize=(12,6))
tt.plot(50)
plt.show()

# %%
# 4차 산업혁명 키워드 - 얼마나 등장했을까?
keywords = ['IOT','사물인터넷','빅데이터','인공지능','AI','블록체인','암호화폐','NFT','3D 프린팅','모빌리티','드론','자율','주행','전기차','메타','버스','가상세계','ESG','친환경']

for word in keywords:
  print( f'{word} :', tt.count(word))
# Out:
# IOT : 0
# 사물인터넷 : 0
# 빅데이터 : 22
# 인공지능 : 0
# AI : 0
# 블록체인 : 0
# 암호화폐 : 0
# NFT : 0
# 3D 프린팅 : 0
# 모빌리티 : 79
# 드론 : 7
# 자율 : 45
# 주행 : 27
# 전기차 : 175
# 메타 : 196
# 버스 : 212
# 가상세계 : 0
# ESG : 0
# 친환경 : 186

# %%
# 워드클라우드

# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'

font_name = font_manager.FontProperties(fname=path).get_name()
rc('font',family=font_name)

# %%
from wordcloud import WordCloud

data = tt.vocab().most_common(200)

cloud = WordCloud(font_path=path, relative_scaling=0.2,
                  background_color='white').generate_from_frequencies(dict(data))

plt.figure(figsize=(16,12))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
###########################################################################

# %%
#### 2. 감성분석

# 크롤링한 주가데이터를 활용하여 해당 뉴스가 개제된날의 주식 등락률을 0,1로 라벨링하여, 주식 뉴스 텍스트분석
# 나이브베이즈를 활용, 특정 신문기사를 입력했을 때 해당기사가 주가에 긍정적인가, 부정적인가를 보여주는 감성분석 프로젝트

# %%
import pandas as pd

# 크롤링한 주식뉴스 데이터 및 주가데이터 불러오기

stock_news = pd.read_csv('/content/drive/MyDrive/Korean_Stock_Project/stock.csv')
stock_price = pd.read_csv('/content/drive/MyDrive/Korean_Stock_Project/데이터.csv',index_col=0)

stock_news = stock_news.drop(['news_link'],axis=1)

# %%
#날짜 컬럼 합치기 쉽게 전처리
character = '.: '

for a in range(len(character)):
  stock_news['date'] = stock_news['date'].str.replace(character[a],'')

stock_news['date'] = stock_news['date'].str.slice(start=0, stop=8)
stock_news = stock_news.astype({'date':'object'})

# %%
# 결측치 및 문제있는값 제거
idx = stock_news[stock_news['date']=='date'].index
stock_news.drop(idx,inplace=True)

stock_news = stock_news.dropna()

# %%
# 주가 등락 컬럼 추가
stock_price['GoodBad'] = [0. if value.find('-')== 0 else 1. for value in stock_price['FLUC_RT']]

GB = stock_price[['ISU_SRT_CD','DATE','GoodBad']]

GB = GB.rename(columns={'DATE':'date','ISU_SRT_CD':'stock_code'})
GB = GB.astype({'date':'string'})
GB = GB.astype({'date':'object'})

GB = GB.dropna()

# %%
# 날짜 데이터타입 변환
stock_news['date'] = pd.to_datetime(stock_news['date'])
GB['date'] = pd.to_datetime(GB['date'])

# %%
GB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159593 entries, 0 to 159592
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   stock_code  159593 non-null  object
#  1   date        159593 non-null  datetime64[ns]
#  2   GoodBad     159593 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 4.9+ MB

# %%
stock_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18748 entries, 0 to 18809
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        18748 non-null  datetime64[ns]
#  1   stock       18748 non-null  object
#  2   stock_code  18748 non-null  object
#  3   title       18748 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 732.3+ KB

# %%
# 합치기
df = pd.merge(stock_news,GB,how='left',on=['date','stock_code'])
df
# Out:
#             date  ... GoodBad
# 0     2021-06-30  ...     1.0
# 1     2021-06-30  ...     1.0
# 2     2021-06-30  ...     1.0
# 3     2021-06-30  ...     1.0
# 4     2021-06-30  ...     1.0
# ...          ...  ...     ...
# 18743 2021-08-29  ...     0.0
# 18744 2021-08-29  ...     0.0
# 18745 2021-08-29  ...     0.0
# 18746 2021-08-29  ...     0.0
# 18747 2021-08-29  ...     0.0
#
# [18748 rows x 5 columns]

# %%
df['GoodBad'].value_counts()
# Out:
# 1.0    9573
# 0.0    9175
# Name: GoodBad, dtype: int64

# %%
# # df csv파일로 저장
# df.to_csv('./news_df.csv')

# %%
# 데이터 나누기
from sklearn.model_selection import train_test_split

text_train,text_test,class_train,class_test = train_test_split(df['title'],df['GoodBad'],test_size=0.2)

# %%
# 데이터타입 변경
text_train = text_train.values.astype('str')
text_test = text_test.values.astype('str')

# %%
# 벡터화
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer()
train_count = count_vect.fit_transform(text_train)
train_count.shape
# Out:
# (14998, 26308)

# %%
# tf-idf 변환
from sklearn.feature_extraction.text import TfidfTransformer

tf = TfidfTransformer(use_idf=False).fit(train_count)
train_tf = tf.transform(train_count)
train_tf.shape
# Out:
# (14998, 26308)

# %%
# 나이브베이즈 분류기 학습
from sklearn.naive_bayes import MultinomialNB


multinb = MultinomialNB()

classifier = multinb.fit(train_tf, class_train)

# %%
# 테스트
# 2022.01.12 HDC 현대산업개발 아파트 붕괴사고 기사 - 주가 폭락
# 2022.01.12 sk하이닉스 기사 - 주가 상승
tt = ['광주 악몽 HDC현대산업개발, 7개월만에 또 사고…휘청','골드만·씨티·UBS 등 글로벌 IB의 잇단 반도체 긍정론…삼성전자·SK하이닉스 상승세 불 지펴']

tt_counts = count_vect.transform(tt)
tt_tf = tf.transform(tt_counts)

pred_tt = classifier.predict(tt_tf)

for text, gb in zip(tt, pred_tt):
  print('%r => %s' %(text, '주가에 긍정적' if gb == 1 else '주가에 부정적' ))
# Out:
# '광주 악몽 HDC현대산업개발, 7개월만에 또 사고…휘청' => 주가에 부정적
# '골드만·씨티·UBS 등 글로벌 IB의 잇단 반도체 긍정론…삼성전자·SK하이닉스 상승세 불 지펴' => 주가에 긍정적

# %%
# 파이프라인

from sklearn.pipeline import Pipeline

pipe_clf = Pipeline([
                ('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', MultinomialNB()),
])

# %%
# 파이프라인 학습시키기
pipe_clf.fit(text_train,class_train)

# test데이터 예측하기
pred_test = pipe_clf.predict(text_test)
pred_test
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
## test_accuracy 확인
# 예상대로 낮은 수치
import numpy as np

np.mean(pred_test == class_test)
# Out:
# 0.6378666666666667

# %%
# 제언

- 주가의 등락을 0,1로 할 것이 아니라, 주가의 등락률이 +-1%이내는 보합으로 추가하여 삼중분류로 분류기를 돌린다면 더 높은 accuracy가 나오지 않을까?

# %%
################################################################

# %%
#### word2vec을 이용한 유사도분석 (목표: 4차혁명 관련 키워드 / 테마주 관련 키워드 분석)
import pandas as pd
import numpy as np

import gensim
from gensim.models import word2vec

# %%
news_df = pd.read_csv('./news_df.csv')

# %%
news_df
# Out:
#        Unnamed: 0  ... GoodBad
# 0               0  ...     1.0
# 1               1  ...     1.0
# 2               2  ...     1.0
# 3               3  ...     1.0
# 4               4  ...     1.0
# ...           ...  ...     ...
# 18743       18743  ...     0.0
# 18744       18744  ...     0.0
# 18745       18745  ...     0.0
# 18746       18746  ...     0.0
# 18747       18747  ...     0.0
#
# [18748 rows x 6 columns]

# %%
from konlpy.tag import Okt

tf = Okt()

# %%
# 정규표현식으로 필요없는 문자 제거
drop_text = '"[],.·→\''

for a in range(len(drop_text)):
  news_df['title'] = news_df['title'].str.replace(drop_text[a],"")

# %%
# 형태소 분해 및 조사, 어미, 접사 제거

result = []

for line in title_text:
  parts = tf.pos(line, norm=True, stem= True)
  a = []

  for word in parts:
    if not word[1] in ['Josa', 'Eomi', 'Punctuation']:
      a.append(word[0])

  core = (" ".join(a)).strip()
  result.append(core)
  print(core)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 억 못 돌려주다 삼성 생명 즉시 연금 항소
# 램 가격 꺾다 삼 성전 자 하이닉스 동반 급락 이유
# 분기 안방 지키다 삼성 스마트폰
# 초대형 극 강 화질 삼성 형 출시
# 삼성 전자 사내 식당 곳 추가 입찰 지역 중 소 급식 업체 상생 강화
# 돌아오다 이재용 삼성 미국 투자 마지막 퍼즐 끼울다
# 사 조 산업 주주명부 열람 등사 가처분 신청 피소
# 주진우 사 조 산업 회장 지 분 쪼개다 소액 주주 룰 무력 화 편법
# 주진우 사 조 산업 회장 씩 주식 대여 소액 주주 분노
# 삼성 증권 한 온 시스템 전기차 시대 맞다 하반기 성장 기대
# 마켓 인사이트 삼성 증권 야간 공 모주 청약 실시
# 삼 표시 멘트 자회사 삼척 에너지 흡수 합병 결정
# 샘표 지르다 스위트 빠다 간장 쓰다 육포 출시
# 샘코 대다 감자 결정
# 성문 전자 억 규모 전환사채 발행
# 서호 전기 억 규모 공급 계약 체결
# 이 베스트 증권 올해 미술품 경매 시장 규모 억원 서울 옥션 주가 오르다 것
# 활황 기 접다 미술 경매 시장 서울 옥션 추가 상승 여력 크다
# 세원 앤 씨 건설 화공 플랜트 기기 추가 공급 계약 체결
# 셀트리온 허쥬마 일본 시장점유율 넘다
# 셀트리온 형제 동반 강세 렉 키로 나주 치료 대상 확대 기 대감
# 셀트리온 형제 코로나 치료 제 적용 대상 확대 신청 동반 상승
# 셀트리온 허쥬마 일본 시장 점유 율 돌파
# 세종 텔레콤 부산 은행 블록 체인 기반 디지털 자산 거래 플랫폼 협업
# 셀트리온 헬 스케 어 허쥬마 점유 율 돌파
# 스카이라이프 현저 저 평가 구간 목표 가신
# 스타 모빌리티 억 규모 전환사채 발행 결정
# 신세계 무인 결제 상용 화 그룹 사 투자 확대 수혜
# 신 영 증권 한예종 인재 육성 협약
# 신 영 증권 한국 예술 종합 학교 예술 인재 육성 협약 체결
# 신세계 이천시 첫 주거 브랜드 빌리브 어바인 시티
# 신세계 주거 브랜드 빌리브 어바인 시티 이 달 분양
# 신세계 건설 초고 층 주상 복합 빌리브 어바인 시티 이 달 분양
# 신세계 이천시 첫 주거 브랜드 빌리브 어바인 시티
# 용진 이형 예고 하다 행사 앞두다 야구 위기 론 아쉽다 신세계
# 신성 이 지다 한화 시스템 억 규모 태양광 모듈 납품 계약
# 신세계 푸드 마켓 유료 멤버십 실험 통 하다 타 점포 확대 예고
# 정용진 신세계 부회장 앓이 아미가 돼다 보련 다
# 우리 있다 롯데 신세계 이다 도 페이 시장 뛰어들다
# 신세계 주거 브랜드 빌리브 어바인 시티 이 달 분양
# 신규 백화점 고객 뺏다 신세계 경기 갤러리아 싹 바꾸다
# 신제품 신 기술 신 일 전자 무선 물걸레 청소기 출시
# 신 일 전자 무선 물걸레 청소기 출시
# 쌍용 씨 앤 주다 원 현금 배당
# 쌍용 주다 원 현금 배당
# 유가 증권 시장 공시 쌍용 씨 앤
# 신한지주 모든 영역 좋아지다 중 목표
# 바이오 엑스 코넥스 코스닥 상장 주 관사 신 한 금투 선정
# 특징 주 신규 확 진자 명 바이오 씨 젠 강세
# 아이 퀘스트 분기 영업 익 억 전 년
# 상폐 위기 벗어나다 아이 원스 주 신고 정도 경영 설립
# 상폐 위기 벗어나다 아이 원스 거래 재 개장 중 폭등 주 신고
# 오늘 거래 재개 되다 아이 원스 올해 전 망치 상향 조정 증권
# 특징 주 아이 원스 상폐 위기 벗어나다 급등 주 신고
# 아이엘 사이언스 자회사 어헤즈 상표권 무단 선점 분쟁 승리
# 아이 씨디 캐논 억 규모 공급 계약 체결
# 알 체라 현 대 모비스 억원 규모 계약 체결
# 안랩 채용 제안 이메일 함부로 누르다 말다
# 앤 씨 앤 연결 기준 매출 액 억 하반기 더 좋다
# 애경 화학사 애경 산업 협의 체 구축
# 알다 젠 캐 싸 이르다 고 용량 서도 안전
# 에이 블 씨 엔씨 분기 영업 손실 억 적자 폭 개선
# 에이 블 씨 엔씨 해외 온라인 매출 증가 분기 적자 폭 개선
# 에스제이 케이 회생 절차 폐지 결정 상장 적 격 성 심사 사유
# 에이 티 세미 콘 전환 가액 원 원 조정
# 특징 주 지 켐 생명과학 경 구형 코로나 치료 제 호주 상용 화 첫 발 소식 강세
# 엔씨소프트 분기 영업 이익 억 원 전 년비
# 엔씨소프트 글로벌 신작 리니지 티저 사이트 공개
# 엔씨소프트 블소 출시 연기 성 장통
# 엔씨소프트 분기 영업 익 억 전 년 동기 반토막
# 엔씨소프트 분기 영업 익 감소 한국 매출 줄다
# 종합 엔씨소프트 글로벌 기업 도전 년 대 도약 자신
# 엔씨소프트 분기 영업 익 억 전 년
# 엔씨소프트 리니지 미리보기 사이트 오픈
# 엠씨 넥스 부진하다 실적 연간 기 대치 낮추다 목표 대신
# 엠로 코스닥 상장 승인 일 매매 거래 개시
# 겨자 무 고추냉이 속이다 판매 오뚜기 자회사 등 개 업체 적발
# 오뚜기 열라면 이색 레시피 힘 입다 상반기 매출
# 오리온 분기 영업 익 억 전 년 감소
# 오리온 상반기 매출 액 조억 분기 선방 효과
# 오리온 분기 영업 익 억 전 년 동기 대비
# 오리온 상반기 영업 이익 감소
# 오 성 첨단 소재 전환 가액 원 원 조정
# 와이 제 이 엠게임 즈 억 규모 전환사채 발행 결정
# 코스닥 공시 원 방 테크
# 원 익 연간 영업 익 역대 최대 기대
# 원 익 영업 익 억
# 특징 주 위지윅 스튜디오 게임 체인 저 전략 적 투자 소식 강세
# 위메이드 분기 영업 이익 억 원 전 년 흑자 전환
# 위메이드 분기 영업 익 흑자 전환 미르 누적 매출 억
# 위메이드 분기 영업 이익 억원 흑자 전환
# 위메이드 영업 익 억 전 년 흑자 전환
# 컨콜 장 현 국 위메이드 대표 블록 체인 이 코 노미 만들다 낼 것
# 위메이드 맥스 영업 손실 억 적자 폭 축소
# 위메이드 맥스 영업 손실 억 전 년 적자 폭 감소
# 웹젠 월 신작 뮤 아크엔젤 최종 점검 나서다
# 유진 투자 헐리웃 대작 개봉 효과 목표 상향
# 유안 타 증권 카뱅 상장 금융 주 관심 높이다 계기
# 이노션 제작 스위첸 등대 프로젝트 만 뷰 돌파
# 이노션 주다 원 현금 배당 결정
# 이스트소프트 분기 영업 익 억 원 전 년 주목 공시
# 이마트 카드 닐슨 빅데이터 동맹 맺다
# 이마트 제의 초마 짬뽕 찾다
# 인 크로스 분기 영업 이익 억 원 전 년 주목 공시
# 인 크로스 영업 익 억 전 년
# 인 크로스 분기 영업 익 억 분기 사상 최대
# 인스 코비 비 플 라스 티 비톡신 앰플 런칭 주년 기념 롯데 홈쇼핑 방송 기 대감
# 특징 주 인 바이오 젠 세계 최초 코로나 변 치료 제 개발 대형 협력 사 계약 진행 부각
# 인바디 영업 익 억 전 년
# 정상 제이 엘에스 영업 익 억 전 년
# 정상 제이 엘에스 영업 익 억 전 년
# 정상 아깝다 비 영업 이익 률 벽
# 제일기획 플레이 리스트 세대 사로자다
# 제이 케이 제이 케이 바이오 국립 암 센터 공 동 연 구 계약 체결
# 제 이시스 메다 칼 분기 최대 실적 하반기 이다 갈다 것
# 제주항공 아이디어 공모전 월 일 접수
# 클릭 종목 조이시티 주력 게임 성장 주목
# 성남시 한국 지역 난방 공사 여성 창업 아이디어 경진 대회 개최
# 앨리스 달튼 브라운 전시회 지니 뮤직 추천 음악 더 특별하다
# 종목 속 상폐 부활 지누 스올 매출 조 찍다 년 조 넘다 보다
# 줌인터넷 영업 익 억 전 년
# 특징 주 진원 생명과학 희귀 병 유전자 치료 제 개발 참여 소식 강세
# 컨 버즈 상반기 순이익 흑 전 성공 경영 정상화 노력 결실
# 해외 진출 성공하다 이 것 필수 카페 페이팔 솔루션
# 개미 파워 카카오 만원 넘다 목표 높이다 증권사 들
# 네 카오 주춤 하다 코스닥 인터넷 주 뜨다 네 카페 다나 씽씽
# 블루 오션 동남아 커머스 네이버 카페 업다 간다
# 웹툰 보다 카카오 터 주식 주다 총 주 규모 장외 시 장선 만 원선
# 카카오 웹툰 이용자 명 카카오 터 주 쏜다
# 네이버 카카오 기어 갈다 때 코스닥 대표 인터넷 종목 날아가다
# 세 이상 임 직원 비율 천차만별 명중 명 카카오 명중 명
# 케이 씨 텍 양호 근 최 동규 각자 대표 체제
# 케어 젠 영업 익 억 전 년
# 케어 젠 영업 익 억 전 년
# 코스 맥스 비 티아이 영업 익 억 전 년
# 단가 후려 꼼수 수수료 돌리다 받다 하도급 가다 코 아스 제재
# 코스 맥스 영업 익 억 전 년
# 세계 위 화장품 코스 맥스 영업 익
# 특징 주 분기 어닝 서프라이즈 코스 맥스 강세
# 중국 발 최대 실적 코스 맥스 분기 어닝 서프라이즈
# 코스 맥스 엔비 티 영업 익 억 전 년
# 코스 맥스 엔비 티 해외 계 열 회사 억 규모 채무 보증 결정
# 코웨이 환경 가전 렌털 시장 선도 순간 온 수로 전력
# 태양광 공장 가동 폐기물 자원 화 탄소 중립 나선 코웨이
# 코웨이 협의 회장 기후변화 위기 친환경 제품 돌파
# 클릭 종목 키우다 증권 부문 추가 성장 기대
# 테스 억 규모 반도체 시험 장비 양수
# 반도체 시장 지 각 변동 테스 하나마이크론 수혜 전망
# 태 영 건설 억 규모 신경주역 세 권 아파트 공사 수주
# 태 영 건설 다산역 데시 앙 일 견본주택 오픈
# 태광 영업 익 억 전 년
# 코넥스 개 종목 거래 거래 대금 위 툴젠
# 토니모리 분기 순 익 흑자 전환 사업 전략 리 빌딩
# 시그널 파 메다 유상증자 청약 률 올리다 베다 맙 임 상 파란 불
# 티플랙스 분기 이다 분기도 분기 사상 최대 실적 달성
# 파라다이스 영업 손실 억 전 년 적자 폭
# 파라다이스 분기 영업 손실 억 원 전 년 확대 주목 공시
# 특징 주 팍스 넷 정리 매매 절차 돌입
# 신 상품 라운지 풀무원 한 끼 두부 종 출시 쓱싹 비비 완성
# 폴라리스 오피스 폴라리스 쉐어 법적 대응 상표권 침해 소송 및 계약 해지 절차
# 피플 바이오 자회사 신약 개 발사 곳 억원 지 분 투자
# 아미가 되어다 보련 다정 용진 찌다 팬 인증
# 에그타르트 인연 정용진 아미가 되어다 보련 다
# 팬 되다 정용진 부회장 아미 돼다 보련 다
# 반도체 시장 지 각 변동 테스 하나마이크론 수혜 전망
# 한국 비엔 씨 안트로퀴노놀 델타 람다 변 바이러스 억제 효과 기대
# 한국 선재 억 규모 부동산 처분
# 한국 토지 신탁 이천 진 암 지구 우방 아이유 쉘 메 하이브 완판
# 상장 나선 현대 중공업 신 사업 육성 정기 선 승계 힘 싣다
# 현대 중공업 시동 미래 먹거리 실탄 확보
# 년 완제 기 수출 하다 하반기 전망 여전하다 먹구름
# 한미 반도체 대만 사오다 억 규모 계약
# 특징 주 한 솔로 스틱스 해상 운임 급등 순 익 배재 평가 기대
# 한 온 시스템 포드 달리다 실적 본 입찰 지켜보다
# 매각 이슈 부각 한 온 시스템 실적 부진 주가 오르다
# 삼성 증권 한 온 시스템 전기차 시대 맞다 하반기 성장 기대
# 한 온 시스템 전기차 열 관리 시스템 성장 세 주목 현대차
# 월 본 입찰 앞두다 한 온 시스템 분 매각 이벤트 주목 한국 투자
# 한송네오텍 배터리 소재 기업 신화 아이티 인수 차다 사업 본격 화
# 기업 공시 월 일 한 송네오텍 억 규모 차다 소재 업체 신화 아이티 지 분 취득 등
# 한전 광양 그린 에너지 억 규모 정비 용역 계약
# 강남 권 귀하다 정비 사업 마천 구역 시공사 현 대 건설 유력
# 현대 건설 대구 중심 입지 힐스테이트 대 구역 퍼스트 일 계약
# 우수 협력 사 포상 총 억 현 대 건설 안전 관리 인 센티 브 확대
# 현대 건설 기술 교육 원 년 하반기 교육 생 명 모집 취업 알선
# 한화 투자 증권 바이오 플라스틱 사업 부 성장 기업 가치 상승 예상
# 한화 에어로 스페이스 분기 어닝 서프라이즈 목표 증권
# 대신 증권 한화 에어로 스페이스 전 부문 실적 호조 목표 주가 상향
# 신성 이 지다 한화 시스템 억 규모 태양광 모듈 납품 계약
# 한화 생명 신설 동 사옥 판다
# 한화 생명 라이프 어 드 바이 저 캠페인 일상 솔루션 제공
# 한화 생명 전문가 생활 문제 해결 도움 주다 캠페인 실시
# 한화 에너지 한화 세 보유 에이치 솔루션 흡수 합병
# 현 대비 앤지 스틸 영업 익 전 년비 증가 전방 산업 호조 수혜
# 현대 백화점 와인 선물 패키지 종이 소재 바꾸다
# 현 대리 바트 미드 세다 추리 스타일 책장 바꾸다 보다
# 등 드리다 현대 모비스 알고리즘 경진 대회 개최
# 알 체라 현 대 모비스 억원 규모 계약 체결
# 현대 모비스 일반인 알고리즘 경진 대회
# 국토부 현대 벤츠 등 개 차종 만대 리콜
# 기아 노조 파업 카드 만지작 현대차 다르다 가나
# 현대차 엠 배서 더 스타일 리스트 모집
# 현대차 도쿄올림픽 양궁 국가대표팀 온택트 환영 회 격려 억대 포상
# 현대차 중고차 시장 진출 초읽기 이 달말 협상 결론 내다
# 국토부 현대차 등 개 차종 만대 리콜 조치
# 현대차 홍보 대사 스타일 리스트 기 모집
# 현대 제철 당진시 협업 탄소 배출 제로 지역 행사 연 다
# 현대 제철 당진시 국내 최초 탄소 배출 제로 행사
# 유가 증권 메모 일 보통주 추가 상장 화승 엔터프라이즈 스톡옵션 행사
# 자 컨소 구성 휴 젤 인수 나서다 조 안팎 제시
# 컨소시엄 보톡스 위 휴 젤 인수 유력
# 휴 젤 순항 중인 톡 신 필러 허가 모멘텀 삼성
# 프레 시 웨이 중 장기 체력 개선 가능성 목표 하이
# 제일제당 뼈 없다 비비고 순 살 생선 구이 간편식 선봬
# 공시 제일제당 건강 사업 개편 검토 중
# 단독 대 한 통운 택배 기사 사용자 첫 심다 사용자 맞다
# 대 한 통운 이 천 허브 터미널 소형 택배 전담 분류 하다
# 안되다 사업 없다 현재 만원 목표 주가 만천원 나오다
# 번가 예능 형 방 자영 업자 김 다비 오픈
# 마켓 인사이트 세종 텔레콤 부산 은행 블록 체인 기반 부동산 수익 증권 거래 플랫폼 계좌 관리 계약 체결
# 비 은행 계 열사 탈 석탄 금융 힘 모으다
# 금융 지주 지 속 가능 경 영 보고서 발간
# 손해 보험 상반기 순 익 억 전 년 증가
# 표준 협회 금융 지주 자발 적 온실가스 배출 량 검증
# 손보 분기 영업 익 억 전 년
# 손보 상반기 당 기 순 익 일반 보험 손해 율 개선
# 이 앤 씨 친환경 건축 소재 공장 짓다
# 이 앤 씨 현 대 오 일 뱅크 친환경 건축 소재 상용 화 나서다
# 정유 부산물 시멘트 만들다 현대 오일 뱅크 이 앤 씨 협력
# 마이 샵 스타트업 잇다 플 의 맛있다 저 염 도시락 론칭
# 현대 해운 매물 다시 품
# 이다 영업 이익 억 연봉 제자리 파업 임박 위기
# 현대 산업 개발 고덕 아이파크 디어 반 디어 반 갤러리 오픈
# 건설 이다 예정자 원스톱 홈스 타 일링 서비스
# 분기 영업 손 억 기록
# 건설 등대 프로젝트 유튜브 만 뷰
# 건설 해운대 센트 스위첸 견본주택 일 오픈
# 표 등 코스닥 자 사주 신청 내 역일
# 특징 주 갤럭시 폴더 플 폰 공개 바텍세경 하이테크 등 강세
# 전자담배 후 발주 자 년 개국 수출 비결
# 신다 카바 이오 슈퍼 컴 센터 구축 나서다
# 투자 증권 그룹 사 포트폴리오 재편 강하다 실적 상승 예상
# 전화 한 통 간편하다 통 하다 콜 체크 하루 만 명 사용
# 현대차 카카오 자율 원 팀 조 시장 잡다
# 세대 소통 드립 시네마 유튜브 조 회수 만 달성
# 만 명 써다 다세대 겨냥 게임 박스 인기
# 구 현모 대표 철학 담다 업무 용 전기차 새롭다 단장
# 투자 증권 그룹 사 포트폴리오 재편 강하다 실적 상승 예상
# 일렉트론 만주 전환 청구권 행사 일 상장
# 일렉트론 아기 상어 버블 퐁 프렌즈 구글 창구 프로그램 기 선정
# 만주 전환 청구권 행사
# 트렌드 생활 건강 년 기술 숨다 노화 잡다 일만 지치다 피부 탄력 있다
# 닥스 아트 하우스 캠페인 아티스트 컬래버
# 생건 화장품 가맹 점 월세 지원
# 생활 건강 가맹 점 월세 긴급 지원 코로나 고통 분담
# 가장 싸다 스마트폰 내다 레드 미노트 출시 전자 폰 빈자리 들어오다 샤오미
# 전자 프라 초음파 클렌저 신제품 출시
# 전자 삼성 전자 올해 녹색 상품 수상
# 삼성 전자 올해 녹색 상품 최고 권위 상 석권 종합
# 전자 프라 초음파 클렌저 신제품 출시
# 넥스 원 상반기 영업 익 억 전 년
# 이노 텍 노조 코로나 피해 소상 공인 지원
# 돌비 시네마 셋톱 출시 영화관 경험 집 안
# 미디어 사업 강화하다 유플러스 홈시네마 족 겨냥 사운드 바 블랙
# 뉴욕 재즈 클럽 통째 내 방 사운드 바로 집콕족 정 조준
# 하우 시스 개 제품 올해 녹색 상품 오르다
# 분기 영업 익 억 전 년
# 배터리 관련 서비스 다 하다 기업 거듭 나
# 공시 분기 영업 익 억원 작년 동기 증가
# 에너지 솔루션 프로 테라 배터리 공급 계약 체결
# 초 중 고교 곳 무궁화 무상 보급
# 유 플 셋톱박스 우리 집 영화관 돼다
# 삼성 대한민국 올해 녹색 상품 최고 권위 상 받다
# 배터리 연합 관계 강화
# 영업 익 전 년 억크래프톤 역성 장
# 전국 개 학교 무궁화 보급
# 삼성 무료 콘텐츠 생태계 잡다
# 만원 붕괴 하이닉스 네이버 시 총 위 주인공 되다
# 네이버 시가총액 위 등 극 하나 급락 하이닉스 차이 조원 좁히다
# 광고 버즈 빌다 네이버 마켓 광고 수익 화 솔루션 제공
# 네이버 가상 화폐 링크 상장 카카오 클레이 맞다 불
# 하이닉스 주가 만원 붕괴 시 총 위 네이버 위협
# 종목 속 네이버 하다 배 타다 카페 아직 지켜보다 때
# 네이버 카카오 수면 오른 성 장통 직원 달래다 나서다
# 포스코 부생 수소 활용 전력 생산
# 국민연금 포스코 주식 만주 장내 매도
# 포스코 농 산업 벤처기업 육성 해외진출 지원 추진
# 선박 제품 함께 실어 주다 포스코 한 달 만 톤 수송
# 하이닉스 넘버 내주 네이버 억 격차 접전
# 포스코 광양 부생 수소 연료 전 지 발전소 짓다
# 포스코 수 소 발전 만 명 년 간 쓸다 전기 생산
# 코인 거래소 빗썸 맞붙다 네이버 링크 카카오 클레이
# 클릭 종목 팔방미인 콘텐츠 미디어 그룹 숨다 메타 버스
# 가스 지 속 가능 경 영 보고서 위 수상
# 배터리 떼 내다 이노 다음 폐 배터리 정 조준
# 배터리 관련 서비스 다 하다 기업 거듭 나
# 이노 배터리 공장 억원 에너지 절감 성과 우수 사업 장 인증
# 한국 버크셔 그룹 쪼개다 상장 바쁘다 바쁘다
# 유가 증권 시장 공시 진에어 중공업 등
# 이노 내달 지배구조 헌장 정관 명문 화
# 개장 시 황 삼 전하 닉 급락 양대 증시 소 폭 상승 출발
# 전기차 충전 시스템 업체 시 그 넷 이브이 자회사 편입
# 이노 에너지 절감 우수 사업 장 선정 배터리 셀 생산 전 기 사 용량
# 이노 유럽 합작 법인 각형 배터리 개발 추진
# 이 테크 건설 억 규모 분양 중도 금 연대보증 결정
# 이 테크 건설 쿠팡 물류 센터 공사 수주
# 이 테크 건설 억 규모 쿠팡 신축 계약 체결
# 글로벌 엇갈리다 전망 골드만삭스 삼 전 닉스 괜찮다 모건 하이닉스 파다
# 코스피 외국인 팔자 소 폭 하락 마감 삼 전 하이닉스 약세
# 하이닉스 주가 만원 붕괴 시 총 위 네이버 위협
# 네이버 시가총액 위 등 극 하나 급락 하이닉스 차이 조원 좁히다
# 모건스탠리 하이닉스 파다 목표 절반 낮추다
# 마감 시 황 삼성 전자 조 하이닉스 조 내다 판 외인 코스피 흔들다
# 외국 계 리포트 뚝뚝 삼성 전자 하이닉스 연중 최저
# 삼성 전자 하이닉스 또 급락 이틀 새 시 총 조원 증발
# 주 성 엔지니어링 하이닉스 억 규모 공급 계약
# 삼성 전자 하이닉스 검다 목요일 외국인 사흘 간 조 팔 치우다
# 삼성 전자 하이닉스 파다 월 큰손 경고
# 하이닉스 넘버 내주 네이버 억 격차 접전
# 유가 증권 시장 공시 진에어 중공업 등
# 코스피 마감 삼 전 하이닉스 급락 환율 압박
# 아 그때 파다 하다 삼 성전 자 하이닉스 연중 최저 치 동학 개미 어쩌나
# 만원 붕괴 하이닉스 네이버 시 총 위 주인공 되다
# 특징 주 공매도 거래 위 하이닉스 장 중 만 원 깨다
# 특징 주 삼 성 전자 하이닉스 외국 계 매도 리포트 연중 최저 점
# 특징 주 하이닉스 장 중 만원 붕괴 코스피 시 총 위 위태
# 하나 금투 하이닉스 디램 가격 하락 영업 익 하향 조정 목표 내다
# 하이닉스 램 가격 하락 우려 흔들다 한때 만원 아래
# 대다 쓸다 담다 국민연금 삼 성 전자 하이닉스 대량 매도
# 홀딩스 주다 원 분기 배당 결정
# 하이닉스 메모리 값 하락 전환 새 악재 아니다
# 삼성 하이닉스 반도체 급락 다운 사이클 장기 화 알다
# 하이닉스 만 원선 무너지다 오늘 하락 출발
# 코스피 개인 기관 동반 매수 선 강 보합 삼전 하이닉스 하락
# 코스피 강 보합 출발 삼 전 하이닉스 하락
# 외국인 매도 삼 성 전자 하이닉스 플 티어 따다 상 성공
# 급락 하이닉스 목표 증권 차가워지다 반도체 시선 포트 라이트
# 삼성 전자 하이닉스 램 가격 하락 우려 주가 약세
# 특징 주 삼 전 하이닉스 우울하다 반도체 전망 주가 뚝뚝
# 모티브 현금 배당 결정 강세
# 텔레콤 외국인 매도 억대 월말 적극 비중 확대
# 이노베이션 배터리 셀 전 기 사 용량 감축 우수 사업 장 인증
# 카카오 억 규모 펀드 공동 조성
# 이노베이션 유럽 서도 포드 손잡다 배터리 공장 짓다
# 월 분기 리뷰 발표 비중 축소 주목
# 이노베이션 서산 배터리 공장 에너지 절감 우수 사업 장 인증
# 한화 투자 텔레콤 구독 서비스 등 신규 사업 주목
# 가입자 쑥 텔레콤 신규 단말기 없다 호실 적 한국 투자
# 특징 주 호실 적 저 평가 강세
# 특징 주 텔레콤 카카오 펀드 조성 소식 강세
# 빅 테크 투자 첫 손 카카오 억 규모 펀드 공동 조성
# 법률 정책 플랫폼 코딧 코리아 최종 선정
# 지수 편입 에코 프로비 엠 급등
# 바사 에코 프로비 엠 편입
# 분할 이벤트 배당 매력 대다 강세
# 호실 적 배당 매력 부각 텔레콤 장 중 강세
# 바사 지금 고 점임 직원 주다 만원 물량 털다
# 이데일리 지수 바사 에코 프로비 엠 편입
# 바사 에코 프로비 엠 편입
# 특징 주 분기 영업 익 급증 강세
# 트릴 리온 식물성 카페인 담다 카페인 샴푸 출시
# 특징 주 스틸 제의 테슬라 리 비다 조억원 전기차 양산 공장 추진 소식
# 게임빌 매출 억 영업 익 억 하반기 게임 사업 강화 박차
# 게임빌 플랫폼 기업 도전 코인 원 실적 반영 기대
# 공시 게임빌 분기 영업 익 억 전 년 동기
# 게임빌 분기 영업 이익 억 원 전 년 동 기 대비
# 경동나비엔 일렉트로 마트 내 체험 형 매장 리뉴얼 및 기념 이벤트 진행
# 골프 존 데카 골프 버디 구매 고객 대상 쿨 마스크 증정 이벤트
# 교촌치킨 번가 방 만 명 보다 사상 최대 성과
# 광주 신세계 분기 영업 익 억 원 전 년 동 기 대비
# 광림 만주 전환 청구권 행사 일 상장
# 최창걸 고려아연 명예 회장 코리아 써다 키트 주식 만주 매도
# 금호 타이어 기아 공명 음 저 감 타이어 공급
# 특징 주다 스텔 바작 자 사주 취득 기대 강세
# 나스 미디어 영업 익 억
# 나스 미디어 분기 영업 이익 억원 전 년 증가
# 특징 주 나노 씨 엠에스 투자 경고 연일 강세
# 특징 주기 외국 계 매수 대다
# 금호 타이어 기아 공명 음 저 감 타이어 공급
# 현대차 기아 못 하다 한국 볼트 온라인 판매
# 잘나가다 수입 전기차 판매 뚝 왜 현대차 기아 질주
# 상상 영감 공간 기아 브랜드 체험 공간 리뉴얼 오픈
# 기아 브랜드 체험 공간 기아 전기차 중심 리뉴얼
# 증권 넷마블 하반기 실적 개선 전망 밸류 이 션 부담 여전
# 넷마블 카겜 주식 억원 치 전량 매도 투자 수익
# 특징 주 어닝쇼크 넷마블 주가 뚝뚝
# 넷마블 카카오 게임 주 주식 만주 처분 결정
# 신 한 금투 넷마블 대작 출시 소셜 카지노 인수 실적 개선 기대
# 넥스 틴 삼 성 전자 억 규모 웨이퍼 검사 장비 계약
# 넥슨 티 호조 전 년 영업 익
# 네오위즈 영업 익 억 전 년
# 네오위즈 영업 익 억 원 전 년 동 기 대비
# 네오위즈 매출 억 영업 익 억 신작 출시 하반기 실적
# 녹십자 홀딩스 기업 탐사 녹십자 물 쓰다 판관 비 일감 몰다 총 체적 도덕 적 해이
# 녹십자 혈액 분획 제제 북미 임 상 상 결과 국제 학술지 게재
# 녹십자 혈우병 치료 제 품목 허가 승인
# 녹십자 혈우병 치료 제 중국 허가 획득
# 녹십자 웰빙 올해 실적 개선 세 전망 질적 성장하다 것
# 녹십자 셀 오다 상반기 최대 매출 이 뮨셀 씨 최고 치 경신
# 녹십자 홀딩스 기업 탐사 녹십자 물 쓰다 판관 비 일감 몰다 총 체적 도덕 적 해이
# 농심 해물탕 유럽 발암 물질 검 추다 해당 제품 리콜 조치
# 농심 국물 없다 신라면 볶음 출시 주 만 개 판매
# 다날 핀 테크 페이 코인 모바일 게임 드래곤 블러드 사전예약 이벤트
# 대봉 엘에스 영업 익 억 전 년
# 대봉 엘에스 영업 익 억 원 전 년 동 기 대비
# 중흥 컨소시엄 다음주 대우건설 실사 돌입 인수 절차 본격 화
# 대한항공 한국 공항 율도 항 공유 비축 기지 임대
# 대한항공 월 하와이 향 하다 하늘 길 다시 연 다
# 덴티움 글로벌 임플란트 수요 증가 실적 기 대감 대신
# 동원 개 리 채다 작가 배드 보스 공동 기부
# 신약 강 자 동아 에스티 옛 명성 되찾다
# 동일 고무 벨트 억 인터 메 딕스 주식 만주 취득
# 두산인프라코어 중동 지역 건설 기계 총 대다 수주
# 듀켐 바이오 세 브로 타우 치매 진단 제 제조 서비스 계약 체결
# 두산 중공업 트리 마제 양산 일 본격 분양
# 알 에스 오토메이션 두산 퓨얼 셀 억 규모 공급 계약
# 두산인프라코어 사우디 바레인 건설 기계 대다 수주
# 다이나믹 디자인 구 세 화 아이엠 씨 억 규모 전환사채 발행
# 사료 신선도 생명 락앤락 반려동물 진공 사료 통 출시
# 트렌드 롯데 하이마트 슬기롭다 집콕 생활 올인 홈 가전 대전 시작 하다
# 플라스틱 롯데 푸드 친환경 선물 세트 출시
# 코지 마 롯데 하이마트 창립 주년 특별 프로모션 진행
# 롯데 하이마트 가전제품 오프 프라 이스 스토어 시범 운영
# 라면 이다 과자 값 롯데 제과 인상
# 과자 값 오르다 롯데 제과 비스킷 등 과자 종 평균 인상
# 빠다 코코 낫 값 오르다 꼬깔콘 양 줄이다 롯데 제과 년 가격 조정
# 루트 닉 신제품 출시 연말 호실 적 지속
# 맘스 터치 아르바이트 캐릭터 맘스비 공개
# 거 버넌스 워치 메가스터디 맏딸 손 희소 심상찮 행보
# 메리츠화재 분기 영업 익 억 전 년
# 메리츠화재 상반기 순 익 억 전 년비
# 메 리츠 증권 중국 유동성 통제 미국 금리 하락 영향 미치다 수도
# 표메 리츠 증권 등 코스피 자 사주 신청 내 역일
# 거 버넌스 워치 메가스터디 맏딸 손 희소 심상찮 행보
# 특징 주 모트 렉스 반기 영업 익 배 해외 흥행 전기차 성장 기대
# 변액 보험 강 자 미래에셋 생명 해외 투자 형 펀드 자산 조 돌파
# 베스파 신작 타임 디펜더 스 일 일본 출시 예고
# 클릭 종목 바텍 분기 매출 역대 최고 치 달성 목표
# 바이오 니아 자회사 유산균 갱년기 증상 개선 돕다
# 코스닥 기업 공시 일 바이브 컴퍼니 등
# 마켓 인사이트 대세 메타 버스 바이브 컴퍼니 이지스 전략 적 투자 하다 플랫폼 공동 개발
# 바이브 컴퍼니 억 규모 시스템 구축 계약 체결
# 블루베리 한국 프로농구 연맹 프로농구 발전 업무 협약 체결
# 블루 콤 억 규모 자 사주 만주 소각
# 브이 티 지엠 피 코스 메 틱 호조 영업 익 억 급증
# 산업 용 카메라 수요 증가 뷰웍스 쑥
# 파리 바게뜨 여름 맛 타다 빙그레 비비빅 협업
# 하이트진로 빙그레 메로나 담다 메로나 이슬 한정 출시
# 아이큐 어 비츠로 셀 차세대 스마트 패치 사업 협약
# 특징 주 비디아이 임 상 상 췌장암 치료 제 진행 상황 보고 급등
# 삼성 물산 래미안 이다 앞두다 아파트 단지 새 첫 선
# 삼성 물산 래미안 신규 외벽 적용 모습 공개
# 삼성 증권 장맛빛 전망 주가 훨훨 사상 최고 경신
# 삼성 배터리 투자 기 대감 장 중 사상 최고 터치
# 삼성 글로벌 완성 차 업체 협력 가능성 투자 증권
# 코스피 강 보합 출발 삼 전 하이닉스 하락
# 개장 시 황 삼 전하 닉 급락 양대 증시 소 폭 상승 출발
# 삼성 갤폴드 플립 톰 브라운 에디 션 한정 판매
# 외국인 매도 삼 성 전자 하이닉스 플 티어 따다 상 성공
# 특징 주 삼 전 하이닉스 우울하다 반도체 전망 주가 뚝뚝
# 지속 가능 갤럭시 생태계 만들다 삼성 친환경 비다 발표
# 이재용 가석방 하루 앞두다 삼성 합병 재판 출석
# 글로벌 엇갈리다 전망 골드만삭스 삼 전 닉스 괜찮다 모건 하이닉스 파다
# 삼성 전자 등 개 제품 올해 녹색 상품 선정
# 역대 급 스마트폰 보다 방문자 폭주 삼성 홈페이지 한때 멈추다
# 만원 짜다 폰 사다 수 천명 몰리다 삼성 홈페이지 마비
# 사진 삼성 갤럭시 플립 공개
# 사진 이재용 삼성 전자 부회장 가석방
# 삼성 전자 하이닉스 램 가격 하락 우려 주가 약세
# 삼성 전자 모든 갤럭시 제품 재활용 소재 적용 하다
# 삼성 전자 창사 이렇다 첫 단체 협약 체결 노사 관계 새 이정표
# 이데일리 삼성 전자 충격 물 강하다 개다 폴드 공개 펜 지원
# 삼성 전자 올해 녹색 상품 최고 권위 상 석권 종합
# 코스피 개인 기관 동반 매수 선 강 보합 삼전 하이닉스 하락
# 신작 반응 뜨겁다 네 삼 성전 자 홈페이지 마비 사태
# 삼양식품 고용노동부 청년 고용 정책 홍보 업무 협약
# 삼성 화재 상반기 순 익 억 전 년
# 삼성 화재 분기 영업 익 억 원 전 년
# 삼성 화재 해상 보험 분기 영업 익 억 전 년
# 삼성 화재 상반기 순 익 성장
# 삼성 화재 세 전 이익 넘다
# 삼성 화재 등 손 보사 상반기 실적 빛나다
# 삼성 중공업 미국 페트로브라스 손 배소 재개
# 특징 주 삼 성 전자 하이닉스 외국 계 매도 리포트 연중 최저 점
# 코스피 외국인 팔자 소 폭 하락 마감 삼 전 하이닉스 약세
# 전자 삼성 전자 올해 녹색 상품 수상
# 대다 쓸다 담다 국민연금 삼 성 전자 하이닉스 대량 매도
# 현장 경영 활동 제약 삼성 정 공법 돌파 하다
# 삼성 전자 하이닉스 파다 월 큰손 경고
# 단독 삼성 다음주 전자 계열 사 장단 회의 이재용 참석 여부 주목
# 삼성 전자 하이닉스 검다 목요일 외국인 사흘 간 조 팔 치우다
# 삼성 무료 콘텐츠 생태계 잡다
# 이재용 약속 결실 삼성 전자 창사 이렇다 첫 단협 맺다
# 아 그때 파다 하다 삼 성전 자 하이닉스 연중 최저 치 동학 개미 어쩌나
# 삼성 신형 폴 더블 폰 나오다 개다 노트 그리다
# 넥스 틴 삼 성 전자 억 규모 웨이퍼 검사 장비 계약
# 마감 시 황 삼성 전자 조 하이닉스 조 내다 판 외인 코스피 흔들다
# 코스피 마감 삼 전 하이닉스 급락 환율 압박
# 뉴 삼성 약속 결실 삼성 전자 노사 첫 단협 체결
# 품절 대란 이유 있다 삼성 갤럭시 워치 살펴보다 영상 말 리뷰
# 외국 계 리포트 뚝뚝 삼성 전자 하이닉스 연중 최저
# 오늘 의미 있다 날 삼성 전자 노동조합 공 동 교섭 단 첫 단체 협약
# 삼성 전기 초소 형 초고 용량 전 장용 개발
# 삼성 전기 자율 주 행차 뚫다 전 장용 부품 종 개발
# 삼성 전자 하이닉스 또 급락 이틀 새 시 총 조원 증발
# 삼 영 이 앤 씨 주주명부 열람 소송 취하
# 특징 주 상지 카일 룸 자회사 렉틴 코로나 치료 제 접목 부각 렉틴 활용 기술 부각
# 상상 그룹 걷기 프로젝트 이산화탄소 톤 감축 효과 창 추다
# 특징 주 갤럭시 폴더 플 폰 공개 바텍세경 하이테크 등 강세
# 성광벤드 분기 영업 손실 억만 원 적자 전환
# 선진 선진 포크 한 돈 불꽃 삼겹 에어 이벤트
# 코로나 차 대유행 셀트리온 형제 진단 키트 뛰다
# 셀트리온 렉 키로 브라질 긴급 사용승인 획득
# 셀트리온 렉 키로 브라질 긴급 사용승인 획득
# 셀트리온 코로나 치료 제 렉 키로 브라질 긴급 사용 승인
# 다이나믹 디자인 구 세 화 아이엠 씨 억 규모 전환사채 발행
# 솔루 에타 억 규모 생산 중단 물 환경법 위반 조업 정지
# 명품 보복 소비 신세계 인터 내다 날 상반기 역대 최대 실적 달성
# 신세계 인터 내다 날 분기 영업 이익 억원 흑자 전환
# 신세계 푸드 한미 헬 스케 어 협업 비타민 젤리 브이 츄 선봬
# 신세계 이천 빌리브 어바인 시티 이 달 분양
# 명품 힘 신세계 분기 역대 최대 영업 익 축포
# 신세계 건설 이천 빌리브 어바인 시티 이 달 분양
# 신세계 분기 영업 이익 억원 흑자 전환
# 신세계 분기 영업 익 억 흑자 전환
# 명품 쇼핑 시 마을 오다 이익 급증 신세계 인터
# 신세계 끄다 끄다 미아 굳다 슬립 페스 타 특 프로모션
# 신세계 인터 분기 영업 익 억 흑자 전환
# 마켓 개발자 공개 채용 신세계 시너지 초석 다지다
# 보복 소비 흑자 전환 신세계 영업 이익 억원
# 아파트 메다 터 리신 세계 강남 세대 인테리어 팝업 매장 공개
# 돌아오다 소비 심리 신세계 매출 신기록 갈아 치우다
# 신성 이 지다 일 분기 개최
# 전기차 충전 시스템 업체 시 그 넷 이브이 자회사 편입
# 스튜디오 산타클로스 배우 차 주영 전속 계약 체결
# 시너지 이노베이션 억 규모 전환사채 발행 결정
# 신 한 금투 넷마블 대작 출시 소셜 카지노 인수 실적 개선 기대
# 신한 건물 내 모든 곳 실천 공간
# 신한은행 신한 실천 빌딩 선언
# 신다 카바 이오 슈퍼 컴 센터 구축 나서다
# 유가 증권 기업 공시 일 쌍용 씨 앤 등
# 아모레퍼시픽 프리 메라 대한민국 올해 녹색 상품 수상
# 라씨 인쇄회로기판 제 조사 심텍 외국인 매다 몰리다
# 아 나 패스 자 사주 만주 소각
# 씨유 메다 칼 억 규모 만기 전 취득 소각 예정
# 씨 엠에스 에듀 주다 원 중간 현금 배당
# 코스닥 공시 주 성 엔지니어링 씨 엠에스 에듀
# 아이 톡시 억원 규모 제 자 배정 유상증자 결정
# 아이큐 어 비츠로 셀 차세대 스마트 패치 사업 협약
# 특징 주 애니 젠 신약 개발 기 대감 급등
# 애니 젠 신약 개발 기업 재 평가 소식 대다 급등
# 애니 젠 펩타이드 로 매출 늘 것 신약 모멘텀 보유
# 애니 젠 신약 개발 기업 재 평가
# 알 에스 오토메이션 두산 퓨얼 셀 억 규모 공급 계약
# 안트로젠 영업 손실 억 적자 폭 축소
# 에스원 비대 마케팅 시스템 구축
# 에스 와이 분기 영업 익 전 년 억원 철강 시 황 개선 효과
# 그룹 티케 이 케미칼 애플 라인 드 원 사공 급 업무 협약
# 주목 기업 이비 온 정밀 임 상 설계 목표 조준
# 주식 초 고수 지금 연일 강세 에코 프로 매수 매도 활발
# 특징 주 에코 프로 알토 란 관계 사 주가 급등
# 지수 편입 에코 프로비 엠 급등
# 바사 에코 프로비 엠 편입
# 에스 전환 가액 원 원 조정
# 에스 쇼핑 분기 영업 손 억 적자 폭 확대
# 엔씨소프트 게임 업계 첫 보고서 발간
# 엔씨소프트 오다 리니지 연 이 출시 기 대감
# 크래프톤 충격 갈다 곳 잃다 게임 주 엔씨소프트 목표 주가 뚝
# 엔씨소프트 국내 게임 사 첫 지 속 가능 경 영 보고서 발간
# 분기 어닝 쇼크 엔씨소프트 증권사 곳 목표 주가 줄 하향
# 엔씨소프트 하반기 블소 리니지 효과 기대 키우다
# 엔씨소프트 분기 실적 기 대치 하 회 목표 하향 흥국 증권
# 엘 아이 에스 억원 규모 제자 배정 유상증자 결정
# 엘 아이 에스 억 규모 전환사채 발행 결정
# 엠 플러스 지멘스 배터리 산업 분야 협력
# 단독 오 스템 임플란트 치과 장비 기업 품다
# 오리온 믿다 중국 발목 잡히다 이익 감소 왜
# 오리온 신제품 효과 하반기 실적 모멘텀 회복
# 오뚜기 카트라이더 협업 이후 진라면 매출 증가
# 엔터 분기 영업 익 전 년 장 중 주 신고
# 와이지 터 영업 이익 억 전 년 동 기 대비
# 와이지엔터테인먼트 영업 익 억 전 년 주목 공시
# 웅진 엠 더블유 제 일차 억 금전 대여 결정
# 특징 주우진 비 앤지 렉틴 단백질 변 코로나 치료 제 개발 국내 유일 추출 기술 보유
# 우리 만주 전환 청구권 행사
# 특징 주 메모리 반도체 우려 원 익 등 장비 주도 약세
# 위메이드 게임 넘다 메타 버스 가상 자산 진격 사상 최고 돌진
# 위메이드 블록 체인 접목 미르 일 글로벌 출시
# 위메이드 하반기 미르 글로벌 효과 톡톡 목표 케이프
# 웹케시 영업 이익 억원 전 년 동기
# 기업 공시 월 일 원 방 테크 주다 주 무상증자 결정 등
# 특징 주 원 방 테크 신주 주 무상증자 미국 차다 증설 경쟁 수혜 기대
# 특징 주 브이 에이치 계 열사 원 방 테크 전기차 열 관리 시스템 승부 수
# 위지윅 스튜디오 자회사 위즈 온센 오다 파트너 십 계약
# 다 보 링크 일 코스닥 상장 유안 타 제호 스팩 합병
# 우리 이렇게 채용 하다 유진 투자 인턴십 종료 전 직무 관련 평가 하다
# 유진기업 자회사 유진 디랩 억 추가 출자
# 르포 자동화 불모 지다 혁신 꽃 피우다 스마트 레미콘 유진기업 천안 공장
# 유가 증권 메모 일 보통주 추가 상장 유유제약 키우다 증권 이상 전환
# 이마트 분기 영업 이익 억 원년 흑자 성공
# 집밥 힘 이마트 년 분기 흑자
# 이마트 영업 익 억 흑자 전환 주목 공시
# 이마트 분기 영업 이익 억원 흑자 전환
# 이 노인 스 트루먼 트 영업 익 억 원년 분기 최고 실적
# 이노션 분기 영업 이익 억 원 전 년
# 이노 벡스 차 전지 싸이 크다 사업 진출 코스닥 상장 성장동력 확보
# 이노션 분기 영업 익 억 원 전 년 동 기 대비
# 이 베스트 투자 증권 슈카염블리윤쎈 이리 온 뭉치다
# 이 지 케어 텍 분기 연속 영업 흑자 달성
# 특징 주인 스 코비 자회사 아피 메 즈 지 분 확대 급등
# 일동제약 신제품 비오비 타 미니 정제 출시
# 자안 바이오 오다 하반기 본격 성장 기 대감
# 주 성 엔지니어링 하이닉스 억 규모 공급 계약
# 코스닥 공시 주 성 엔지니어링 씨 엠에스 에듀
# 급 기업 도약 눈 앞 두다 종근당 마켓 인사이트
# 제주항공 기내식 카페 승무원 유니폼 체험 하다
# 지역 난방 공사 분기 영업 손 억 기록
# 지역 난방 공사 영업 손실 억원
# 특징 주 텔레콤 카카오 펀드 조성 소식 강세
# 카카오 게임 즈 자다 나가다 대 장주 엔씨 목표 줄 하향 왜
# 카카오 억 규모 펀드 공동 조성
# 빅 테크 투자 첫 손 카카오 억 규모 펀드 공동 조성
# 네이버 카카오 수면 오른 성 장통 직원 달래다 나서다
# 닥터 포 헤어 카카오 헤어샵 운영 오다 이어트 억 투자 유치 성공
# 한진 택배 게임 카카오 이모티콘 출시
# 현대차 카카오 자율 원 팀 조 시장 잡다
# 네이버 가상 화폐 링크 상장 카카오 클레이 맞다 불
# 카카오 택시 이다 자전거 요금 올린다 분당 분 이용 료
# 카이 노스 메드 임 상 상 프로토콜 완성 소식 강세
# 코인 거래소 빗썸 맞붙다 네이버 링크 카카오 클레이
# 유가 증권 시장 공시 진에어 중공업 등
# 진에어 유상증자 영 구채 발행 연내 억원 조달
# 공시 진에어 억원 규모 주주 배정 유상증자 결정
# 케이 씨 고상 걸이 수희 대표 신규 선임
# 컴투스 컨콜 백년전쟁 일 매출 억 안정화 하반기 성과 상승 노력
# 컴투스 매출 억 역대 최대 영업 익다 억
# 컴투스 분기 영업 익 억 감소
# 컴투스 컨콜 내년 조 매출 달성 가능
# 컴투스 컨콜 서머 너 즈 워 크로니클 내년 분기 론칭 매출 목표 유효
# 컴투스 영업 이익 억 원 전 년 동 기 대비
# 컨 버즈 단 기차 입금 억원 감소
# 컴투스 백년전쟁 마케팅 수익 성 뒷걸음질
# 컬러 레이 고 기능 나노 소재 시장 진출 위 더칭 컬러 레이 나노재료 연구원 출범
# 종목 속 네이버 하다 배 타다 카페 아직 지켜보다 때
# 카페 매출 성장 둔화 투자 의견 중립 하향
# 최창걸 고려아연 명예 회장 코리아 써다 키트 주식 만주 매도
# 코디 억 규모 신주인수권 부 사채 발행 결정
# 코오롱 이 앤 씨 헌 옷 재활용 건축 자재 시장 개척 하다
# 특징 주 코스모 화학 쏟아지다 폐 배터리 조 시장 종합 차다 원료 회사 도약
# 코스 맥스 엔비 티 아쉽다 분기 하반기 기 대감 여전
# 코스 맥스 국내외 변수 펀더 멘털 견고 목표
# 클릭 종목 코스 맥스 중국 법인 실적 기여 확대 목표
# 큐리 언 트 자회사 에이치 파다 흡수 합병 결정
# 쿠콘 상반기 매출 억 영업 이익 억 창사 최대 실적
# 코스 맥스 시장 호실 적 목표 투자 증권
# 코스 맥스 분기 실적 기 대치 상회 목표 메 리츠
# 코윈 테크 상반기 매출 액 억원 역대 최 대치 달성
# 유가 증권 메모 일 보통주 추가 상장 유유제약 키우다 증권 이상 전환
# 몸집 키우다 내다 채운 키우다 증권 종 투사 행보 주목
# 테이프 한우물 테이 팩스 년 새 뛰다 비결
# 다산역 세 권 최대 주거 복합 랜드마크 태 영 건설 다산역 데시 앙 일금 견본주택 개관
# 태광 본업 회복 자회사 기대 이상 수익 목표 대신
# 텔레 칩스 영업 익 억만 원 흑자 전환
# 특징 주 티앤 알바 이 오 팹 세계 최초 프린팅 이 식용 인공 기관 개발 성공 소식 강세
# 파 메다 운영 비 조달 유상증자 흥행 하다 주가 껑충
# 클릭 종목 델타 변 때문 시 회복 멀어지다 파라다이스
# 파라다이스 델타 변 확산 내년 영업 익 하향 목표 삼 성 증권
# 시그널 끝 보이지 않다 파라다이스 보릿고개 하반기 신용 전망 먹구름
# 파라다이스 적자 행진 속 중장 기적 접근 유효 키우다
# 파라다이스 시티 올인 클루 시브 인 파라다이스 패키지 출시
# 팅크 웨어 블랙박스 판매 급증 분기 영업 익 늘다 억
# 그룹 티케 이 케미칼 애플 라인 드 원 사공 급 업무 협약
# 펄 어비스 영업 손실 억 적자 전환
# 펄 어비스 컨콜 분기 억 영업 손실 회계 상 이 연 인건비 증가
# 펄 어비스 컨콜 붉다 사막 론칭 연기 길어지다 않다 것
# 펄 어비스 분기 영업 손실 억원 적자 전환
# 인건비 부담 펄 어비스 첫 분기 적자
# 펄 어비스 하반기 검사 모 서비스 집중
# 팬오션 영업 익 년 최대 실적
# 팬오션 분기 영업 익 억 전 년
# 정리 매매 팍스 넷 주가 롤러코스터 투자 주의보
# 신 상품 라운지 풀무원 치즈 흘러내리다 치즈 폭포 시카고피자 출시
# 풍 국 주정 영업 익 억 전 년
# 폴라리스 오피스 글로벌 억 명 유저 참여 형 멀티 플랫폼 성장
# 소재 미래 포스코 케미칼 홈페이지 개편
# 피 에이치 씨 이랜드리테일 스마트 케어 존 임대 계약 체결
# 유출 김 새다 갤플 립 들다 깜짝등장 언 팩 달구다
# 하나은행 원더 카 직거래 경매 서비스 출시
# 하나은행 앱 내 차 내 판다 개 인간 중고차 경매 서비스 출시
# 소주 빠지다 메로나 하이트진로 메로나 이슬 한정 판매
# 참이슬 빠지다 메로나 하이트진로 메로나 이슬 한정 출시
# 공시 한국 바이오 젠 상반기 영업 익 억 전 년
# 한국 바이오 젠 상반기 영업 익 억 급증
# 한국 바이오 젠 상반기 영업 익 억만 원 전 년
# 한국 바이오 젠 충북 괴산 소재 제공 장 생산 중단
# 한국 바이오 젠 공장 개보 수로 생산 중단 매출 영향
# 한국 콜마 자회사 이노 덕분 신용 오르다 전망 마켓 인사이트
# 한전 윤리 준법 경영 본격 화 국민권익위 원 회 업무 협약
# 권익위 한전 등 개 공기업 윤리 준법 경영 업무 협약
# 한 샘 가정 용 바닥재 휴 출시
# 한미 반도체 오다 반도체 제조 용 장비 수주 계약 체결
# 단독 전설 일본전산 한 온 시스템 인수 전 뛰어들다
# 프랑스 한화 솔루션 잇다 자금 소요 촉각 곤 세우다 신평 사 마켓 인사이트
# 한화 시스템 우주 인터넷 기업 원 웹 억 달러 투자
# 한화 시스템 오버 에어 전환사채 권 억원 취득 주목 공시
# 한화 시스템 원 웹 주식 만주 억원 취득 주목 공시
# 한화 시스템 미국 사 전환사채 권 취득 결정
# 한화 시스템 우주 기업 원 웹 억 달러 투자 이사회 합류
# 한화 시스템 위성 통신 업체 주식 만주 취득
# 한화 우주 인터넷 억 투자
# 에이치 솔루션 한화 에너지 합병 한화 승계 구도 미치다 영향 보다
# 한진 택배 게임 카카오 이모티콘 출시
# 한전기술 분기 영업 손실 억만 원 적자 축소
# 한전기술 영업 손실 억만 원 적자 축소 주목 공시
# 한전기술 분기 영업 손 억 매출 억
# 현대 건설 도시 형 생활 주택 힐스테이트 남산 이 달 분양
# 현대 건설 주거 용 브랜드 오피스텔 힐스테이트 도안 퍼스트 이 달 분양
# 자율 주행 산업 협회 출범 하다 협회장 조성환 모비스 대표
# 신 상품 라운지 현대 그린 푸드 그리팅 요거트 출시
# 일진 하 이솔 루스 현대차 넥쏘 수소 탱크 단독 공급
# 현대 분기 영업 익 억 전 년
# 더 현대 서울 면세점 힘 입다 현대 백화점 분기 영업 익 억원
# 현대차 해외 기관 투자가 대상 개최
# 현대차 기아 못 하다 한국 볼트 온라인 판매
# 더 현대 서울 특수 현대 분기 영업 익 년새 배 쑥
# 노조 막히다 현대차 보다 듯 볼트 첫 전기차 온라인 판매
# 현대 인도네시아 발릭파판 현장 중량 물 기 운송 완료
# 현대차 카카오 자율 원 팀 조 시장 잡다
# 마켓 현대 해운 시장 나오다 추석 이후 예비 입찰
# 잘나가다 수입 전기차 판매 뚝 왜 현대차 기아 질주
# 당진 효성 해링턴 현대 제철 임대 확정
# 가나 첫 전기차 현대차 코
# 현대 백화점 분기 영업 이익 억 전 년 동 기 대비
# 현대 백화점 분기 영업 익 억 전 년 동기
# 현대 백화점 분기 영업 익 억 원 전 년비
# 더 현대 서울 면세점 힘 입다 현대 백화점 분기 영업 익 억원
# 파 이토 컬 유산균 시간 발효 주스 현대 홈쇼핑 앙코르 라이브 방송
# 현우 산업 억 규모 전환사채 평가 손실 발생
# 당진 효성 해링턴 현대 제철 임대 확정
# 휴 온스 서울대 병원 뇌 질환 혁신 치료 기기 엑사 블레이트 뉴 설치
# 휴맥스 분기 영업 손실 억원 적자 전환
# 휠라 홀딩스 국세청 추징 금 억원 억원 감액
# 컨소시엄 휴 젤 조원 인수 유력
# 하이 텍 지 분 매각 검토 안해
# 제일제당 비비고 순 살 생선 구이 출시
# 제일제당 오다 일 기업 설명 회 개최
# 유가 증권 메모 일 보통주 추가 상장 전환 등
# 거리 두기 강화 되다 프레 시 몰다 구매 고객 급증
# 건설 홈스 타 일링 컨설팅 이다 서비스 실시
# 분기 흑자 전환 프리미엄 건기 식 업체 인수 등 실적 개선 박차
# 매각 설 부인 하이 텍 분기 사상 최대 실적
# 이 앤 씨 현 대 오 일 뱅크 친환경 건축 소재 상용 화
# 반도체 쇼티 지다 하이 텍 분기 사상 최대 실적
# 금융 그룹 핀 테크 뉴 지스 탁 인수
# 하이 텍 매각 설 부인 매각 사실 무근 검토 안 해
# 손보 헬 스케 어 분야 스타트업 협업 속도
# 클릭 종목 손보 실적 모든 면 다 좋다 목표
# 해운 운임 급등 분기 역대 최대 실적 종합
# 이다 영업 이익 위 임금 파업 초읽기
# 바다 하늘 대한항공 깜짝 실적 실어 나르다
# 분기 영업 익 사상 최대 조 억 원전 년 배 급증
# 분기 영업 익 조억원 전 년 배 증가
# 분기 이다 분기도 사상 최대 실적 영업 익 조 억원
# 상반기 영업 익 조억사 상 최대 속보
# 영업 익 조억원 전 년
# 영업 익 조억 사상 최대
# 리테일 컴바인 드 딜리 버리다 주식 만주 억 인수
# 요기 새 주인 되다 리테일 퀵 커머스 강 자 노리다
# 억 규모 전환사채 밉다 발행 처리
# 리테일 요기 인수 완료
# 표 등 코스닥 자 사주 신청 내 역일
# 상반기 재무제표 감사 의견 거절
# 동부 제철 년 연속 무 분규 임단협 타결
# 건설 해운대 센트 스위첸 금 일일 모델하우스 오픈
# 국민은행 인니 부코 핀 은행 억 증자 참여
# 국민은행 인니 부코 핀 은행 증자 참여 최대 억 투입
# 전자 야심작 신세계 정용진 반하다 묘 매력
# 협력 사 지원 동반성 장 앞장
# 유플러스 광복절 기념 숨기다 독립운동가 조명 캠페인
# 공룡 디즈니 월 한국 출시 제휴 관심
# 디즈니 월 한국 상륙 공식 화 유 플 줄다리기 종합
# 주가 상승 관건 상장 분 스왑 유 안타
# 공룡 에너지 솔루션 예비 심사 연기상 장 더 늦어지다
# 디 이 티 에너지 솔루션 공급 계약 변화 없다
# 셋톱박스 필요없다 채널 대폭 확대 되다 글로벌 시장 맞춤 형 콘텐츠 공략
# 디즈니 월 한국 상륙 공식 화 유 플 줄다리기 종합
# 넥스 원 풍부하다 수 주 잔고 실적 개선 목표 대신
# 네이버 인물정보 개인 사업자 직업 군 신설
# 네이버 시리즈 온 광복절 영화관 프로모션
# 네이버 하이닉스 제 장 중 시 총 위 등 극
# 별로 별 점점 네이버 펜션 미용실 별 점 테러 없애다
# 네이버 라인 가상 화폐 링크 빗썸 상장
# 대상 네이버 브랜드 데이 쇼핑 라이브 방송 진행
# 네이버 문 피아 인수 결정 되다 사안 없다
# 마켓 인사이트 스팩 강 자 투자 증권 올해 네 번째 스팩 예심 청구
# 투자 증권 진에어 영 구채 발행 등 자본잠식 우려 해소
# 투자 증권 삼 섬 화재 오다 분 호실 적 기록 목표 올리다
# 벅스 영업 손실 만원 적자 전환
# 한국 사이버 결제 영업 익 억 전 년
# 분기 영업 익 억 지난해 감소
# 실적 부진 하반기 반등 가능하다
# 공시 분기 영업 이익 억 원 전 년
# 그룹 온라인 과학 교실 드림 사이언스 클래스 진행
# 전선 대상 억원 유증 신 성장동력 투자 가속 화
# 그룹 온라인 과학 교실 드림 사이언스 클래스 실시
# 전선 주식 만주 억원 취득
# 외국인 조 매도 폭탄 기아 화학 삼성 늘다 러브콜
# 포스코 조 규모 그린 본드 교환 사채 발행
# 한수원 포스코 국내 최초 제철소 부생 수소 활용 사업 협력
# 유가 증권 시장 공시 포스코
# 억 규모 자기 주식 취득 결정
# 플라스틱 업계 원자재 급등 위기 롯데 한화 동반성 장 촉구
# 마켓 조 규모 투자 유치 국내외 파전 윤곽
# 중공업 씨아이 에스 약 억원 규모 대구 공장 매각
# 하이닉스 목표 만 만 반도체 업황 이견 심화
# 삼성 전자 하이닉스 외인 이탈 제한 적 가을 반등 노리다
# 앰플 브라운 옥외 광고 인증샷 이벤트 진행
# 개장 시 황 바닥 없다 삼성 전자 하이닉스 코스피 붕괴
# 삼립 위 그릭 요거트 초 바니 국내 론칭
# 환율 급등 원 근접 삼성 전자 하이닉스 집중 매도 상보
# 삼성 전자 만원 대 털썩 하이닉스 한때 시 총 위로 밀리다
# 램 위기 설 마이크론 폭락 삼 성 전자 하이닉스 동병상련
# 특징 주 하이닉스 반등 시 그날 거래 일 상승 전환
# 삼성 전자 하이닉스 또 다시 연중 최저 치 코스피 개월 붕괴
# 삼성 전자 하이닉스 급락 세 미스 매치 해소 하다 과정
# 삼성 전자 하이닉스 줍다 줍다 타이밍 패닉 셀 가지 이유
# 삼성 전자 하이닉스 검다 금요일 외국인 조원 매도 폭탄
# 이데일리 램 업황 우려 삼 전 하이닉스 이다 마이크론 급락
# 삼성 전자 연일 연 저 점 행진 하이닉스 시 총 위 지키다
# 하이닉스 장 중 시 총 위 자리 내주다
# 삼 전 하이닉스 매도 폭탄 한주 시 총 조 증발
# 삼 전 하이닉스 나흘 간 조 팔 치우다 외국인 들 왜
# 취약 계층 아동 스마트 기기 기부
# 반도체 추락 삼성 전자 연 저 점 하이닉스 한때 시 총 위
# 외국인 하루 평균 조원 이상 던지다 삼전 하이닉스 집중 매도
# 주 식초 고수 지금 임 상 상 진입 바이오 사이언스 관심 삼 성 전자 줍다 줍다
# 바사 주가 천장 찍다 임원 인 일간 지 분 억원 처분
# 특징 주 바이오 사이언스 거래 일 상승 전환 편입 임 상 상 등 호재
# 생생 코스닥 가비아 신입 경력 대규모 공채 월 일 마감
# 샴푸 트릴 리온 향수 샴푸 퍼퓸 현대 홈쇼핑 일일 론칭
# 더이앤엠 루카 에이 아이 셀 바이오 원천 기술 기업 루카헬스 합병
# 영업 익 억 원 전 년 흑 전
# 코스닥 공시 갤럭시 멀다 트리 지에스 이
# 국순당 두다 고랭 토마토 축제 후원
# 국도화학 억원 유상증자 성공 마켓 인사이트
# 교촌치킨 번가 라이브 보다 방송 사상 최대 기록 달성
# 교촌 에프 앤비 분기 매출 억원 폐점 매장
# 골든 베다 광동 제약 헛개차 협업 제품 출시
# 신 한 금융투자 골프 존 국내 해외 성장 세 주목
# 골프 빠지다 세 대 골프 존 주목 하다 증권
# 현대차 기아 투자 어르다 이 벌 내년 전기 상용차 본격 생산
# 외국인 조 매도 폭탄 기아 화학 삼성 늘다 러브콜
# 금강 공업 억만원 규모 자기 주식 처분
# 클릭 종목 네오위즈 대체로 부진 블레스 희망
# 남양유업 아이꼬 과자 선물 세트 체험 단 모집
# 유가 증권 기업 공시 일 녹십자 등
# 녹십자 홀딩스 기업 탐사 백신 기업 녹십자 코로나 백신 후 발주 자 불명예
# 노루 페인트 천안 독립기념관 광복절 벽화 페인트 후원
# 투자 귀 재 넷마블 년 간 평가 차익
# 넷마블 스틸 얼라이브 베타서비스 실시
# 카카오 게임 즈 급락 넷마블 보유 주식 처분
# 넥 스턴 바이오 자회사 통화 동 보제 약과 당뇨 치료 제 개발 협약
# 넥센 타이어 년 연속 영국 맨시티 공식 후원
# 특징 주 넥스트 사이언스 나노 젠 델타 변 이 효과 백신 베트남 정부 긴급 승인 임박 부각
# 동원 더 반찬 레스토랑 간편식 누적 매출 억 돌파
# 녹십자 홀딩스 기업 탐사 백신 기업 녹십자 코로나 백신 후 발주 자 불명예
# 다날 상반기 매출 액 억 순이익 억원 사상 최대
# 뉴 트리 상반기 영업 이익 전 년 올해 고 성장
# 농심 신라면 볶음 출시 주 천만 개 판매 돌파
# 농심 오뚜기 이다 삼 양 팔도 라면 가격 인상 종합
# 비빔면 한 봉 원 돼다 오뚜기 농심 이다 삼양 팔도 올리다
# 대교 자라다 상상 키즈 창의 홈 캠프 출시
# 대 영 포장 억원 규모 전환사채 발행
# 대신 증권 분기 영업 이익 억원 흑자 전환
# 대신 증권 분기 순이익 억 원 전 년 흑자 전환
# 포스트 대모 코로나 수출 부진 매년 실적 악화
# 대유 상반기 사상 최대 이익 달성 경영 권 변경 이후 호실 적
# 대우건설 올해 경영 목표 달성 순항
# 더 네이쳐 홀딩스 분기 영업 이익 늘어나다 억원
# 공시 더블유 게임 즈 매출 액 전 년 영업 이익 감소
# 대한항공 영업 익 억 원 전 년
# 델타 변 확산 대한항공 아시아나 추석 하와이 운항 취소
# 대한항공 분기 영업 익 억 원 전 년
# 대한항공 분기 매출 조 영업 이익 억원 달성
# 코로나 분기 연속 흑자 내다 대한항공 화물 효자
# 바다 하늘 대한항공 깜짝 실적 실어 나르다
# 대 한 뉴 파다 건강 기능 성 의약품 매출 이익 동반 성장
# 동서 상반기 매출 억 제조 부진 영업 익
# 조 달러 인프라 투자 임박 두산 밥캣 호재 만 나나
# 두산 분기 영업 이익 억원 흑자 전환 계열 사도 고르다 성장
# 있다 그대로 빛나다 우리 두산 청소년 사회 공헌 프로그램 시간여행 자 전시회 개최
# 산업 용 고무 제조 업체 동일 고무 벨트 사업 다각 화 위해 인터 메 딕스 인수 마켓 인사이트
# 디자인 아리 바이오 에이 이치 엔비 억 인수
# 디자인 장관 순 이정옥 이현웅 대표이사 변경
# 디 이 티 에너지 솔루션 공급 계약 변화 없다
# 디앤 씨미디어 더앤트 지 분 억 추가 인수
# 디앤 씨미디어 자회사 더 코믹스 영업 정지
# 라이프 시맨틱스 전립선암 발생 위험 예측 솔루션 실증 특례 승인 받다
# 디티알 오토 모티브 조 베팅 두산 공작기계 인수 다
# 오리온 중국 쇼크 분기 매출 위 롯데 제과 내주다
# 롯데 제과 거꾸로 수박 바 판매 처 전국 확대
# 매일유업 신제품 앱솔 루트 킨더밀쉬 바나나 출시
# 롯데 하이마트 롯데 카드 하이 플랜 바이 롤라 카드 출시
# 표메 리츠 증권 등 코스피 자 사주 신청 내 역일
# 메 디톡스 분기 영업 이익 흑자 전환
# 매직마이크 불 성실 공시 법인 지정
# 무림페이퍼 컵 빨대 완충 재 친환경 종 올해 녹색 상품 선정
# 삼일 기업 공사 억 규모 모나미 화장품 공장 신축 공사 수주
# 모나미 억원 규모 물류 창고 및 생산 공장 신축
# 메다 파스 만주 신주인수권 행사 일 상장
# 미스터 블루 게임 사업 일시 적 비용 증가 영업 적자 흑자 전환 확실
# 미래에셋 생명 분기 영업 이익 억 전 년
# 미래에셋 생명 분기 영업 익 억 원 전 년
# 스튜디오 만들다 미래에셋 증권 내 친김 웹 드라마
# 미래에셋 베다 처 투자 분기 영업 이익 억 전 년 증가
# 람다 변 이 바이오 그 디바이스 관계 사 코빅 실 관심
# 코스닥 기업 공시 일 바이브 컴퍼니
# 베스파 분기 매출 억원 적자 지속
# 브릿지 바이오 전문 인력 보강 신 약 개발 더욱 집중 하다 것
# 하이트진로 빙그레 메로나 메로나 이슬 한정 출시
# 비 케이 탑스 게임 개발 업체 스펙 지 분 인수
# 비 엠티 영업 익 억 전 년
# 비 엠티 매출 액 전 년 실적 성장 지속 전망
# 삼성 화재 호실 적 배당 매력 목표
# 삼성 증권 금 현물 상장 지수 증권 지급 이벤트
# 이데일리 램 업황 우려 삼 전 하이닉스 이다 마이크론 급락
# 마켓 뷰 코스피 선 깨지다 삼 성전 자 넘다 밀리다
# 대체 바닥 어디 삼 성 전자 사흘 째 연 저 점 동학 개미 비상 걸리다
# 외국인 매도 폭탄 시 총 조원 사라지다 삼성 전자
# 삼 성 전자 떨어지다 어디 투자 하나 고민 라면
# 가석방 이재용 삼성 전자 서초 사옥 찾다
# 카메라 최고 사양 중국 폰 삼성 폰 실제 사진 비교 하다 보다
# 삼성 연내 파운드리 배터리 조 투자 속도 내 고 이재용 백 신 특사 나서다
# 영상 만원 삼성 폴 더블 폰 물 풍덩 고장 안 나나
# 개다 폴 들다 아이폰 삼성 때 아니다 판매점 이슈 경쟁
# 글로벌 판매 확대 삼성 바이오 피스 셀트리온 헬 스케 어 순항
# 삼성 전자 하이닉스 줍다 줍다 타이밍 패닉 셀 가지 이유
# 이재용 추다 소 서초 사옥 북적 삼성 직원 뭐라다 달라지다
# 삼성 전자 만원 마감 연중 최저 점 재경 신
# 특징 주 삼 성 바이오 직스 주 최고 카카오 꺾다 시 총 위
# 삼성 생명 상반기 당기다 순이익 조억원 전 년
# 삼성 생명 분기 영업 익 억 원 전 년
# 즉시 연금 패소 삼성 생명 영업 익 날아가다 올해 전망 종합
# 이재용 추다 첫날 삼성 긴장 또 긴장 내주 오다 것 오다
# 가석방 추다 하다 이재용 삼성 전자 부회장
# 서프라이즈 아쉽다 삼성 생명 상반기 순 익 상보
# 삼성 생명 분기 영업 익 급감 하다 주가 약세
# 상반기 작년 전체 실적 내다 삼성 생명
# 삼성 전자 연일 연 저 점 행진 하이닉스 시 총 위 지키다
# 삼 전 하이닉스 매도 폭탄 한주 시 총 조 증발
# 코스피 외인 매도 폭탄 선 밑 삼 성 전자
# 삼 전 하이닉스 나흘 간 조 팔 치우다 외국인 들 왜
# 삼성 전자 하이닉스 검다 금요일 외국인 조원 매도 폭탄
# 메모리 겨울 오다 있다 외국인 작정 던지다 삼 성전 자 엿새 째 하락
# 반도체 추락 삼성 전자 연 저 점 하이닉스 한때 시 총 위
# 코스피 반도체 주춤 하다 선 밑 삼 성 전자
# 외국인 하루 평균 조원 이상 던지다 삼전 하이닉스 집중 매도
# 반도체 투톱 일주일 시 총 조 증발 삼전 개미 조 손실
# 환율 급등 원 근접 삼성 전자 하이닉스 집중 매도 상보
# 삼성 이재용 가석방 현장 찬반 집회 벌어지다
# 외국인 조억 매도 폭탄 코스피 붕괴 삼성 전자 추락
# 삼성 전자 어쩌나 또 연중 최저 치 거래 일 시 총 조 증발
# 삼성 전자 하이닉스 또 다시 연중 최저 치 코스피 개월 붕괴
# 삼전 급락 더 떨어지다 전문가 패닉 셀링 과 하다
# 주 식초 고수 지금 임 상 상 진입 바이오 사이언스 관심 삼 성 전자 줍다 줍다
# 삼성 전자 하이닉스 급락 세 미스 매치 해소 하다 과정
# 이재용 추다 날 하필 삼성 전자 주가 급락 왜
# 돌아오다 이재용 삼성 핵심 먹거리 반도체 배터리 챙기다
# 복귀 삼성 그룹 사회 공 헌 고용 창 추다 가속도
# 현장 르포 도 사과 이재용 삼성 서초 사옥 서두르다 경영 복귀
# 가석방 되다 이재용 자택 대신 서초 삼성 전자 사옥 직행
# 업황 우려 삼성 전자 반도체 담당 임원 들 자 사주 줄 매수
# 외국인 조 매도 폭탄 기아 화학 삼성 늘다 러브콜
# 삼성 배터리 공장 신설 복귀 후 첫 해외 투자 되다
# 삼성 진출 임박 일리노이주 공장 검토
# 삼일 기업 공사 억 규모 모나미 화장품 공장 신축 공사 수주
# 삼양식품 원 재료 비 등 상승 압박 라면 가격 평균 인상
# 삼양식품 미국 판매 법인 설립 현지 특화 상품 공급
# 오뚜기 농심 이다 삼양식품 라면 가격 올린다 평균 인상
# 상상 그룹 걷기 프로젝트 이산화탄소 만 톤 감축 효과
# 선데이 토즈 영업 익 억 전 년
# 선데이 토즈 영업 익 억 전기 광고 사업 호조
# 솔루 에타 일시 생산 중단 재고 확보 실적 영향 미미
# 글로벌 판매 확대 삼성 바이오 피스 셀트리온 헬 스케 어 순항
# 셀트리온 헬 스케 어 분기 영업 익 억 원전 분기 대비
# 셀트리온 분기 어닝 쇼크 기대다 하 회
# 셀트리온 분기 영업 익 억 원 전 년 감소
# 셀트리온 분기 영업 익 억 생산 조정 영향
# 셀트리온 매출 억원 영업 이익 억원
# 쇼박스 넷플릭스 계약 소식 대다 강세
# 신세계 온라인 수익 성 확보 기대 이상 목표 삼성
# 전자 야심작 신세계 정용진 반하다 묘 매력
# 대신 신세계 타 유통업체 대비 실적 개선 크다 것 기대
# 어닝 서프라이즈 신세계 장 초반 상승세
# 컬렉션 신세계 백화점 팝업 스토어 진행
# 키우다 증권 신세계 백신 접종 률 상승 하다 중 장기 수요 회복 가능
# 신세계 또 어닝 서프라이즈 저 점 매수 고민 필요 유 안타
# 신라 젠 검사 출신 서재 식 사외이사 신규 선임
# 신라 젠 대표이사 신현필 김상원 변경
# 특징 주 엠투 신라 젠 이다 총 개최 경영 정상화 기 대감 강세
# 시너지 이노베이션 분기 영업 익 억원 실적 개선 지속
# 신 한 금융 억 분기 배당 국내 금융 지주 가운데 처음
# 남대문 앞 신한 본점 실천 빌딩 싹 바꾸다
# 신 한 금융 출범 후 첫 분기 배당 주다 원
# 골프 존 목표 만원 신규 커버 리지 개시 신한
# 군인공제회 목돈 수탁 대여 출시 신한은행 맞다 손
# 중공업 씨아이 에스 약 억원 규모 대구 공장 매각
# 씨아이 에스 억 규모 대구 공장 부지 양수
# 대륙 아주 그룹 쌍용 자동차 인수 법률자문 사 선정
# 바이오 스페셜 싸이 토젠 혈관 속 종양 세포 잡다 기술 공략 본격 화
# 아스 트 씨 에스 윈드 피 수설 논의 중 확정 되다 바 없다
# 단독 동구 바이오 씨티 씨 바이오 지 분 추가 확보 긍정 적 검토
# 씨젠 상반기 억 영업 이익 전 년비 증가
# 씨젠 영업 익 억 전 년
# 씨 엠에스 에듀 억 영업 이익 달성 반기 역대 최대 기록
# 아스 트 씨 에스 윈드 피 수설 논의 중 확정 되다 바 없다
# 아센 디오 초대형 블록버스터 하이브 영화 화 전격 발표
# 델타 변 확산 대한항공 아시아나 추석 하와이 운항 취소
# 아시아나 억 규모 교보 생명 디지털 채널 리뉴얼 사업 수주
# 아모레퍼시픽 오다 일 기업 설명 회 개최
# 아주 투자 반기 영업 이익 억 원 전 년
# 아이엘 사이언스 분기 매출 액 억원 영업 익 흑자 전환
# 특징 주 애니 젠 코로나 항바이러스제 개발 가능성 주목 신약 개발 기업 재 평가
# 안랩 차세대 방화벽 트러스 가드 출시
# 에스 씨 엠 생명과학 임 직원 명 스톡옵션 만주 부여
# 에스엘 바이오 닉스 용인 공장 억 인수
# 에이 에프 더블 류 분기 매출 액 억 원 전 년
# 에이스침대 에이스 스퀘어 관악 점 오픈
# 금감원 에이 티 세미 콘 정정 신고 제출 요구
# 엔비 티 상반기 매출 억 전 년 최대 실적
# 엠게임 분기 영업 익 억 열혈강호 온라인 흥행
# 엘앤 에프 억 규모 파생상품 평가 손실 발생
# 엘앤 씨 바이오 최대 반기 실적 달성 연매출 목표 초과 기대
# 특징 주 에코 프로 에이치 거래 일 연속 급등 세이 달 수익률
# 특징 주 엠투 신라 젠 이다 총 개최 경영 정상화 기 대감 강세
# 특징 주 엠로 따다 상 실패 장 중 급락 세
# 코스닥 메모 일 신규 상장 엠로 등
# 엠로 클라우드 솔루션 확대 고속 성장 기대 키우다
# 특징 주 엠로 상장 첫날 주가 롤러코스터
# 시그널 오 스템 임플란트 독일 의료 장비 기업 억 인수
# 거래소 오 스템 플 란트 독일 계 치과 인수 설 조회 공시 요구
# 오리 콤 에이스 바이옴 갱년기 관리 건강 기능 식품 비 날퀸 광고 선보이다
# 오리온 중국 쇼크 분기 매출 위 롯데 제과 내주다
# 농심 오뚜기 이다 삼 양 팔도 라면 가격 인상 종합
# 비빔면 한 봉 원 돼다 오뚜기 농심 이다 삼양 팔도 올리다
# 신 상품 라운지 맛 더하다 열량 낮추다 오뚜기 오 뮤 곤 라이스 종 추다
# 오로라월드 장난감 전문점 토이 플러스 가맹 사업 본격 화
# 클릭 종목 엔터테인먼트 블랙 핑크 없이 어닝 서프라이즈
# 깜짝 실적 와이지엔터테인먼트 이슈 호재 목표 메 리츠 증권
# 투자 와이지 터 팬덤 사업 본격 화 기 대 목표
# 와이지 터 터주 위 향 하다 달린다 목표 현대차 증권
# 폴라리스 우노 분기 매출 증가 하반기 긍정 적
# 특징 주 원 방 테크 무상증자 소식 이틀 째 상하
# 유니슨 코오롱 글로벌 억 규모 공급 계약 체결
# 유니 셈 오다 분기 사상 최대 실적 달성 영업 익 억
# 윌비스 분기 영업 익 억 원 전 년 흑자 전환
# 위세 아이 텍 상반기 영업 이익 억 원 전 년
# 유 바이오 직스 백신 생산 시설 장비 구축 지원 사업 선정
# 이마트 닷컴 상장 스타벅스 지 분 가치 재 평가 유 안타
# 이마트 스타벅스 지 분 상승 실적 성장 기 대 목표 삼성 증권
# 이마트 먹거리 생필품 날 특 최대 할인
# 집콕 게임 족 잡다 이마트 온라인게임 천 애 명월 도시락 출시
# 펫 케어 전문 업체 아베 크다 이마트 몰다 리스 입점
# 이마트 파바 대기업 제휴 믿다 머 포인트
# 이마트 년 흑자 전환 하반기 역대 최대 규모 재단 장
# 이마트 천 애 명월 도시락 출시 아이템 지급
# 이랜텍 억 규모 제 자 배정 유상증자 결정
# 이노 와이즈 화신 테크 상호 변경
# 이엔드디 분기 실적 회복 매 연 저 감 장치 장착 본격 화
# 인스 코비 아피 메 즈 천연 추출 물 기반 연구 정부 선도 과제 단계 선정
# 폐기물 업체 인선 이 티 상반기 매출 억원 전 년 뛰다
# 일 성 건설 억원 규모 채무 보증 결정
# 인텔 리안 테크 분기 영업 손실 억원 적자 전환
# 휴메딕스 제 넨 바이오 이종 피부 이 식다 공동 연구개발 협약
# 자이언트 스텝 임 직원 스톡옵션 만주 부여
# 자이언트 스텝 트립비 토즈 지 분 억 인수
# 잉크 테크 분기 영업 이익 억 흑자 전환
# 제 이 앤티 씨 연결 기준 분기 매출 억원 포트폴리오 다각 화 진행
# 특징 주 제이 씨 케미칼 탄소 중립 핵심 기업 구조 적 성장 가격 급등
# 제주항공 억원 규모 주주 배정 유상증자
# 제주항공 분기 영업 손실 억원 적자 지속
# 제주항공 기안 기금 억 받다
# 특징 주 제 일 제강 어닝 서프라이즈 행진 속 신 사업 추진 검토 중
# 시그널 자본잠식 진에어 한진 칼 억 수혈
# 투자 증권 진에어 영 구채 발행 등 자본잠식 우려 해소
# 코스닥 공시 갤럭시 멀다 트리 지에스 이
# 지 더블유 바이 텍 상반기 당 기 순이익 억원 창 추다
# 특징 주 삼 성 바이오 직스 주 최고 카카오 꺾다 시 총 위
# 최대 원 카카오 택시 스마트 호출 요금 결국 조정
# 네이버 카카오 합 보다 크다 하이닉스 굴욕
# 가다 논란 결국 카카오 택시 바이크 요금 인상 열흘 백지 화
# 특징 주 인터파크 폭발 적 성장 커머스 인터파크 확장 성 꽂히다 카카오 놀다
# 카카오 게임 즈 급락 넷마블 보유 주식 처분
# 청담러닝 영업 이익 배 급증 배당 배
# 청담러닝 주다 원 분기 현금 배당 결정
# 차 바이오 텍 상반기 연결 매출 억원 사상 최대
# 이 베스트 투자 컴투스 신작 부진 지 속 목표 하향
# 컴투스 백년전쟁 흥행 예상 저 조 목표 신한
# 케어 랩스 매출 억 원 전 년
# 케이피 에스 억 자금 조달 차세대 장비 항암 파이프라인 투자
# 콜 마비 앤 에이치 세종시 지역 아이 들 건강 지원
# 클릭 종목 코윈 테크 차다 투자 확대 분기 매출 급증 저 평가
# 유니슨 코오롱 글로벌 억 규모 공급 계약 체결
# 클리 노 믹스 매출 확대 지속 연결 기준 분기 영업 이익 흑자 전환
# 크리스탈 지노 믹스 섬유 증 신약 후보 임 상상 승인
# 제 회 대한민국 조 경 문 화대 상 대통령 상 수상 빛나다 주태 영 건설 신 경주 더 퍼스트 데시 앙 주목
# 김철호 티에스 이 대표 어린이 교통 안전 릴레이 채다 린지 동참
# 키우다 증권 신세계 백신 접종 률 상승 하다 중 장기 수요 회복 가능
# 특징 주 토박 스코리아 조 스마트 스터디 코스피 직행 소식 강세
# 파이오링크 오다 상반기 영업 익 억 달성 전 년 동기 증가
# 종목 속 부진 펄 어비스 중국 성과 모든 달리다
# 팬오션 년 만 억원 대 영업 이익 목표 대신 증권
# 클릭 종목 팬오션 분기도 순항 전망
# 팜스코 억원 규모 단기 차입 결정
# 파이다 디지털 고객 감사 그랜드 보상 판매 이벤트 실시
# 퓨쳐켐 파키슨병 진단 의약품 국내 평정하다 정 조준
# 싸이 티바 임마뉴엘 리그 너 회장 프레스티지 바이오 파마 오송 백신 센터 방문
# 프레스티지 바이오 파마 부산 건립 업무 협약 체결
# 플리 토 상반기 매출 액 억 원 전 년 증가
# 플랜 티넷 분기 매출 액 전 년 증가 하반기 해외 공략 강화
# 하나 금융 울산 북구 강동하다 어린이집 개원
# 유산 기부 신탁 하나은행 연세대 손잡다
# 한국 가스 공사 분기 영업 익 억원 흑자 전환
# 한국 공항 분기 영업 익 억 원 전 년 흑자 전환
# 하이트진로 빙그레 메로나 메로나 이슬 한정 출시
# 하이트진로 나파 밸리 안나 밸 와인 종 출시
# 하이트진로 상반기 매출 제자리걸음 영업 익
# 한국 캐피탈 상반기 순이익 억 원 전 년
# 한전 학점 받다 직원 자녀 장학금 만원
# 한전 권익위 윤리 준법 경영 협력 체계 구축
# 전기 료 동결 한전 분기 다시 적자
# 한국전력 분기 영업 손실 억원 전자 전환
# 진퇴양난 한 전전 기 료 인상 하다 물가 불안 안 하다 외국인 소송 우려
# 한전 분기 억원 영업 손실 연료비 상승 반영 못 하다 적자 전환
# 선심 정부 써다 한전 결국 적자 수렁 빠지다
# 민수 맑음 한화 에어로 흐리다 엇갈리다 분기 성적표
# 한국 타이어 나눔 재단 드림 위드 사업 참여 곳 선정
# 한라 홀딩스 오다 일 기업 설명 회 개최
# 한섬 분기 영업 이익 억 원 전 년비 증가
# 한섬 영업 이익 억 작년 늘다
# 한미 약품 창업 주 임 성기 회장 영 주기 추모식 가다
# 시그널 자본잠식 진에어 한진 칼 억 수혈
# 클릭 종목 한 올 바이오 파마 임 상 재개 기 대감 주가 반등 기회 오다
# 한송네오텍 억원 규모 디스플레이 장비 공급 계약 체결
# 한송네오텍 오다 공급 계약 중국 증설 수혜
# 한화 시스템 원 웹 오버 에어 투자 미래 신 사업 기 대 투자 증권
# 한화 투자 증권 펄 어비스 중국 성과 달리다 주가 목표 만원 하향
# 우주 인터넷 시장 개화 한화 시스템 원 웹 투자 이유 있다
# 한프 상반기 재무제표 감사 의견 거절
# 컴투스 신작 실패 실적 상승 모멘텀 당분간 부재 한화
# 플라스틱 업계 원자재 급등 위기 롯데 한화 동반성 장 촉구
# 민수 맑음 한화 에어로 흐리다 엇갈리다 분기 성적표
# 한화 오다 일 기업 설명 회 개최
# 현대 건설 힐스테이트 봉담 프라이드 시티 분양
# 건설 열전 정말 아름답다 땅 약점 있다 그 해결 책 찾다 이상민 현대 건설 주택 설계 팀 장
# 하이 증권 현대 백화점 코로나 유행 분기 실적 안 좋다 것 목표 하향
# 현대 백화점 코로나 재 확산 여파 불가피 목표 하향 조정
# 현대 백화점 핵심 고객 층 주도 하반기 전망 맑음
# 현대 백화점 호실 적 면세점 긍정 적 삼성
# 현대 모비스 오다 일 기업 설명 회 개최
# 샴푸 트릴 리온 향수 샴푸 퍼퓸 현대 홈쇼핑 일일 론칭
# 현대 해상 분기 영업 익 억 원 전 년 증가
# 현대 해상 분기 당 기 순 익 억 원 전 년 증가
# 현대 해상 상반기 순이익 억 원 전 년
# 현대 해상 상반기 당 기 순이익 억 전 년
# 년 만대 만들다 현대차 앨라배마 공장 주 지사 놀랍다 성과
# 또 코로나 발목 분기 실적 악 영향 현대 목표 주가 하 이 투자
# 정의선 뚝심 일 내다 현대차 누적 생산 만대 돌파
# 뉴스 솔 리콜 분담 금 현대차 코 억원 볼트 억원 왜
# 현대차 그룹 투자 대박 스타트업 내년 전기 상용차 양산
# 첼시 내년 현대차 로고 달 뛰다
# 일진 하 이솔 루스 현대차 수소 전기차 넥쏘 차세대 모델 수 소 연료 탱크 전량 공급
# 조 베팅 정의선 로봇 태권 꽂히다 현대차 의료 탐사 로봇 만들다
# 현대차 앨라배마 공장 누적 생산 만대
# 프리미엄 기 대감 높다 아파트 노려보다 상품 성과 미래 가치 있다 효성 해링턴 플 레이스 상무역 주목
# 흥국화재 소상 공인 응원 이벤트 진행 원금 홍보 지원
# 휴메딕스 제 넨 바이오 이종 피부 이 식다 공동 연구개발 협약
# 안기다 휴 젤 시너지 날다
# 휴메딕스 스푸트니크 백신 기술이전 총 책임자 공장 방문
# 특징 주 휴 마시스 변 코로나 진단 가능하다 항체 진단 키트 수출 용 허가 획득
# 식약처 바이오 센서 휴 마시스 자가 검사 시트 품목 허가
# 휠라 홀딩스 일 오후 시 기업 설명 회 개최
# 하나 금투 주간 추천 주호 실적 주목 하나 금융 지주 손보 리테일
# 하나 금투 주간 추천 주호 실적 주목 하나 금융 지주 손보 리테일
# 의 두 얼굴 사상 최대 실적 파업 위기
# 주간 추천 주 성장 모멘텀 현 대 제철 건설 골프 존
# 유 안타 주간 추천 주 매출 증가 기 대 삼성 우리금융 지주 네이버
# 아이유 왜 거기 나오다 네이버 맞선 카카오 웹툰 비밀 병기
# 주말 입사 지원 화학 현대 로템 등 채용 소식
# 포스코 조천억 규모 그린 본드 교환 사채 해외 발행
# 한주 제약 바이오 바사 코로나 백신 첫 임 상상 돌입
# 임 상 돋보기 바사 상 진입 국산 첫 코로나 백신 기대
# 인 베스트 바이오 바사 노바 백 스큐어 백 코로나 백신 선 구매 계약 기대
# 주간 추천 주 성장 모멘텀 현 대 제철 건설 골프 존
# 간신히 반등 마이크론 삼 전하 닉 뒤따르다
# 메모리 겨울 온 다년 전 슈퍼 사이클 땐 하이닉스 주가 개월 선행
# 삼성 전자 하이닉스 패닉 셀 이유 가지
# 부꾸미 이노베이션 왜 배터리 사업 물 적 분할 하다
# 주간 추천 주 성장 모멘텀 현 대 제철 건설 골프 존
# 방향 성비 거리 다 잡다 골프 존
# 골프 웨어 헛개차 만남 골든 베다 광동 제약 협업 제품 출시
# 녹십자 서다 화이자 넘다 혈우병 시장 지각 변동 예고
# 인도판 메가스터디 바이 주스 질주 온라인 교육 시장 위
# 모나 미스 벅 광복절 에디 션 기업 들 애국 마케팅 이유 있다
# 주목 스몰 캡폴 더블 폰 출시 년 부품 사 비 에이치 수혜
# 국내 폰 빈자리 채운 건 삼성 전자
# 달라지다 이재용 복귀 첫날 삼성 서초 사옥 풍경
# 램값 하락 전망 삼 성 전자 하반기 수요 견조할 것
# 삼성 전자 하이닉스 패닉 셀 이유 가지
# 간신히 반등 마이크론 삼 전하 닉 뒤따르다
# 지독하다 악연 삼 성전 자 무슨 일이 박신영 일렉트로 맨
# 주 일간 조 파다 외국인 삼성 전자 지 분율 년 개 월 최저
# 아이폰 보다 삼성 길목 막다
# 국민 기업 삼성 거듭 나기 위 이재용 약속
# 스마트 무료 콘텐츠 독점 채널 판 키우다 삼성
# 외인 담다 바이오 외국인 셀트리온 기관 삼 성 바이오 직스 러브콜
# 유 안타 주간 추천 주 매출 증가 기 대 삼성 우리금융 지주 네이버
# 외인 담다 바이오 외국인 셀트리온 기관 삼 성 바이오 직스 러브콜
# 영 리치 잡다 스타트업 강남 신세계 입성 이유
# 시너지 이노베이션 그룹 편입 후 실적 퀀텀 점프 당 기 순 익 증가
# 제 의 신 풍 제약 되다 카카오 뱅크 주가 상승 비밀
# 공시 줍다 줍다 에어부산 유상증자 증권 신고 정정 이유
# 오로라월드 장난감 전문점 토이 플러스 가맹 사업 본격 화
# 오뚜기 수난 시대 중국산 미역 국산 둔갑 이다 와사비 논란
# 유 안타 주간 추천 주 매출 증가 기 대 삼성 우리금융 지주 네이버
# 블랙 핑크 없이 깜짝 실적 와이지 터 목표 줄 상향
# 기업 공시 월 일 유니슨 억 원 규모 풍력 발전기 기 자재 공급 계약 등
# 아이유 왜 거기 나오다 네이버 맞선 카카오 웹툰 비밀 병기
# 비사 이드 하루 매출 억원 컴투스 솔직 화법 눈길
# 코 아스 소통 경영 사내 문화 강화
# 하나 금투 주간 추천 주호 실적 주목 하나 금융 지주 손보 리테일
# 웨이 브릿지 하나은행 리보 대응 개발 계약 체결
# 전기 료 발목 잡히다 한전 결국 적자 전환 연말 인상 물음표
# 뒷북 비즈 조 우주 인터넷 시장 정 조준 하 한화 하늘 길 우주 잡다
# 주말 입사 지원 화학 현대 로템 등 채용 소식
# 현대 건설 힐스테이트 봉담 프라이드 시티 분양
# 주간 추천 주 성장 모멘텀 현 대 제철 건설 골프 존
# 건설 열전 제주 팽나무 자다 아파트 상징 수가 되다 까닭 건설 박도 환 책임
# 리테일 인기 도넛 노티드 손잡다
# 동부 제철 노사 분규 없이 임단협 타결
# 국민은행 부코 핀 은행 지 분 확보 결정
# 프로야구 포인트 쌓다 경품 받다
# 영상 음향 최고 전자 올 레드 보
# 체험 기 사운드 바 블랙 써다 보다 쾅 폭발 굉음 감동
# 올 레드 보 영상 음향 최고 제품
# 올 레드 보 음향 전문가 협회 최고 프리미엄 로 선정
# 올 레드 보 세계 최고 올 레드
# 적자 쌓이다 카페 네이버 왜 억 어치 사다 인 싸다
# 네이버 페이 놔두다 왜 우리 갖다 그렇다 카드 사 분통
# 포스코 취급 량 감소 탄소 저 감 목표 달성 주춤
# 포스코 조 그린 본드 발행
# 바사 억 하이브 억 단숨 주식 부자 되다 샐러리맨
# 삼성 전자 하이닉스 저가 매수 기회 마이크론 반등
# 외국 계 매도 리포트 속수무책 삼성 전자 하이닉스 급락 개미 분통
# 반도체 주 패닉 삼성 전자 하이닉스 좌절 이르다
# 취약 계층 아동 스마트 기기
# 강원랜드 직원 연쇄 감염 일 카지노 긴급 휴장
# 광복절 지나다 빛 볼 수 있다 갈다 바쁘다 기아 한국 르노 삼성 노사
# 쌍용차 금호 타이어 공장 이전 제 활 뚫다 신의 한수 되다
# 마켓 워치 디티알 오토 모티브 두산 공작기계 인수
# 마켓 워치 미코 시 그 나이트 신한 캐피탈 의료 진단 스페 클립스 투자
# 삼성 화재 올해 배당 수익률 전망
# 반도체 주 패닉 삼성 전자 하이닉스 좌절 이르다
# 외신 놀라다 삼성 갤폴드 숨기다 신 기술 가지 노정 동의 분
# 현장 연휴 잊다 삼성 전자 서초 사옥 정현호 사장 등 경 영진 출근
# 삼성 전자 더 프레임 클림트 작품 담다
# 웃돈 만 원만 명 몰리다 삼성 로또 폰 또 대박
# 월 삼성 전자 매수 직장인 그때 고 점일 줄 모르다
# 삼성 더 프레임 클림트 작품 담다
# 삼성 전자 하이닉스 저가 매수 기회 마이크론 반등
# 국민 적금 되다 삼성 전자 저가 매수 투자 매력 떨어지다
# 인텔 서다 삼성 노골 적 견제
# 단독 이재용 컴백 삼성 인력 주요 사업 손대다
# 외국 계 매도 리포트 속수무책 삼성 전자 하이닉스 급락 개미 분통
# 이재용 경영 복귀 바닥 찍다 삼성 전자 주가 반등 열쇠
# 이재용 특별하다 광복절 삼성 경영 시계 다시 돈 다
# 뒷북 비즈 일리노이 이다 디트로이트 이다 삼성 선택 쏠리다 눈
# 삼성 물산 친환경 사업 삼각 편대 날개 펴다
# 쌍용차 금호 타이어 공장 이전 제 활 뚫다 신의 한수 되다
# 제주 간 신 한 금융 해녀 스타트업 돕다 까닭
# 에듀 중간배당 확 늘리다 이유
# 불닭 소스 에스 앤디 공 모주 맵다 맛 보여주다 일 일반 청약 김민석 브리핑
# 와이지 터 어닝 서프라이즈 주가 상승 기 대감
# 유니 셈 반도체 업종 투자 심리 악화 빛나다 호실 적
# 개국 상품 한자리 이마트 글로벌 상품 모으다 진행
# 반도체 장비 대량 수주 주 성 엔지니어링 상반기 매출 억 전 년 두 배 성장
# 적자 쌓이다 카페 네이버 왜 억 어치 사다 인 싸다
# 다급하다 카카오 모빌리티 요금 정책 갈팡질팡
# 단독 예 약 결제 이동 한번 카카오 최첨단 골프장 짓다
# 무겁다 받아들이다 카카오 택시 자전거 요금 인상 철회 하다
# 코윈 테크 차다 투자 확대 회복 되다 실적
# 공모 회복 못 하다 크래프톤제 하이브 되다
# 버스 인프라 투자 차 파트너 스 한 기 평 최고 등급 획득
# 가을 풍년 카카오 페이 현대 솔 출격 대기
# 한화 시스템 억 달러 들이다 우주 기업 투자 세 가지 이유
# 독일 전 문지 꼽 등 현대차 투싼
# 현대차 사무직 노조 출범 넉 달 돼다 흐지부지 되다 판도병욱 지금 기업
# 유플러스 손 배소 콘텐츠 비용 문제
# 대 한 통운 김시우 투어 윈덤 챔피언십 준우승
# 시스템 상반기 영업 이익 억 반도체 장비 효자
# 이 앤 씨 로 최적 설계 만들다 하자 점검 디지털 디벨로퍼 성큼
# 이 앤 씨 북가좌 구역 아크 드레브 로 비교 불가 주거 가치 실현
# 컨테이너선 운임 연일 순풍 역대 급 실적 기대
# 단독 연지동 사옥 떠나다 여의도 새둥지 틀다
# 리테일 오다 어바웃펫 투자 확대 시장 토탈 플랫폼 구축
# 플랫폼 올라타다 리테일 퀵 커머스 온라인 주도 권 쥐다
# 친환경 바이오 테크 스타트업 곳 발굴
# 카카오 그룹 현대차 그룹 서열 위 경쟁 전
# 전장 배터리 실적 효자
# 일 삼성 폴 더블 폰 사전예약 개시
# 엔솔 호주 사오다 니켈 코발트 공급 계약
# 잎담배 농가 수확 봉사 년 째 농민 상생 실천
# 오다 레이 터 적용 온도 습도 자동 제어
# 시원하다 원형 얼음 집 전자 오브 제 컬렉션 최 상위 냉장고 월 판매량
# 가전 세계 위 등 극 전자 대학생 채용 설명 회도 색다르다 곳
# 원형 얼음 앞세우다 전자 얼음 정수기 냉장고 인기
# 네이버 싸이월드 기획 자 대표 변신 이 람 공 동 대표 그리다 미래한국 유니콘 메이커
# 의료 진 검색 진료 예약 네이버 인물정보 서비스 진화
# 코스피 주간 외국인 순 매수 위 화학
# 유플러스 손 배소 콘텐츠 비용 문제
# 리테일 오다 어바웃펫 투자 확대 시장 토탈 플랫폼 구축
# 오다 상반기 정 유사 실적 위 에쓰오일 비결 사업 다각 화
# 포스코 철강 부문 이익 급증 친환경 소재 기업 변신
# 속도 내다 네트웍 스 전기차 파크 중고 폰 수거 탄력
# 주주 달래다 나선 이노 자회사 주식 배당 카드 꺼내다
# 쉬다 없이 달리다 그룹 주 성적표 보다 우등 생 바사
# 스토 까마귀 백조 되다 비결
# 단독 이노 배터리 영토 무한 확장 삼성 현대차 출신 파격 영 입
# 시그널 찜 베트남 마산 한국 투자 억 달러 베팅
# 현대차 테슬라 앞 다투다 참전 조 미래 먹거리 정체
# 배터리 사업 상반기 매출 조 돌파
# 조 던지다 외국인 삼성 하이닉스 빼다 천억 사다 증권 빠지다 빠지다
# 패닉 셀 커지다 적정 주가 괴리율 삼성 전자 하이닉스
# 하이닉스 반도체 슈퍼 사이클 특수 년 매출 조 클럽
# 스마트 공장 원스톱 지원 팀 구축
# 일 개다 폴드 플립 예약판매
# 카카오 대리 운전 빅뱅 모빌리티 주도 권 경쟁 격화
# 백신 만회 분 일 바이오 안동 공장 추가 출하
# 쉬다 없이 달리다 그룹 주 성적표 보다 우등 생 바사
# 바사 들어오다 억 더 달라 콧대 높아지다 송도
# 주간 추천 주 실적 개선 주목 현대 제철 골프 존 러브콜
# 현대차 기아 유럽 전기차 시장 승승장구 스웨덴 독일 판매 위
# 화제 남양유업 노쇼 매각 적정 성 따지다 보다
# 동원 준호 찬성 모델 동원 참치 새 공개
# 두산 중공업 억원 하수 처리 장 사업 수주
# 두산 중공업 영국 수처리 사업 수 주 총 억원 규모
# 시그널 조 상환 눈 앞 두산 그룹 채권 단 체제 월 조기졸업 청 신호
# 롯데 관광 개발 카지노 매출 액 증가 기대
# 분기 호실 적 기록 레이 언스 하반기 기 대감
# 마크로 젠 서울대 의대 연 구 지 원금 억 전달
# 바이 젠셀 공모 성황리 마감 보령제약 배 투자 이익 확보
# 기 괸 투자자 올해 상반기 삼 성 바이오 직스 쓸다 담다
# 삼성 글로벌 완성 차 업체 협력 가시 화
# 모건스탠리 한마디 삼성 전자 조 순삭 이재용 년 전 발표 해법
# 일 삼성 폴 더블 폰 사전예약 개시
# 추다 직후 서초 달려가다 이재용 샌드위치 삼성 전자 파격 적 돌파구 내놓다
# 단독 이노 배터리 영토 무한 확장 삼성 현대차 출신 파격 영 입
# 코스피 주간 개인 순 매수 위 삼성 전자
# 콤팩트 하다 수납 빵빵 삼성 전자 비 스포크 식기세척기 카운터 탑 선봬
# 패닉 셀 커지다 적정 주가 괴리율 삼성 전자 하이닉스
# 삼전 당분간 반등 어렵다 셀트리온 삼바 매수 타이밍 박의 명의 불개미 구조대
# 번가 삼성 갤럭시 시리즈 자급 제 폰 사전예약
# 삼성 전자 반도체 비 수기 징크스 깨다 램 낸드 메모리 사업 깜짝 성장
# 삼성 전자 인텔 나노 경쟁 격화
# 삼성 전자 인 가구 신혼부부 위 비 스포크 식기세척기 출시
# 베트남 락다운 연장 삼성 전자 가동 률 하락 속 앓이
# 이통 사 삼성 갤럭시 폴드 플립 일 사전예약
# 삼성 준법 경영 리스크 뿌리 없애다
# 연휴 잊다 삼성 전자 파운드리 억 달러 투자 백신 공급 인수합병 논의 본격 나서다
# 삼성 디스플레이 저 전력 친환경 스마트폰 패널 개발
# 조 던지다 외국인 삼성 하이닉스 빼다 천억 사다 증권 빠지다 빠지다
# 삼성 내일 유튜브 만회 조회
# 스마트폰 추다 하량 회복 삼 성 전 기 소재 수혜 전망
# 삼일 씨 에스 주택 공급 증가 콘크리트 파일 수요 늘다
# 솔 루스 첨단 소재 월 바이오 전 지 박 분할 육성
# 코스닥 주간 개인 순 매도 위 셀트리온 헬 스케 어
# 삼전 당분간 반등 어렵다 셀트리온 삼바 매수 타이밍 박의 명의 불개미 구조대
# 신세계 푸드 매출 배 주역 심장
# 호재 다발 신세계 그룹 매수 타이밍
# 신세계 전 부문 호실 적 코로나 타격 불가피
# 신세계 면세점 신진 아티스트 발굴 앞장서다
# 신한은행 경영 뿐 아니다 생활 속 실천
# 메타 버스 타다 은행 들 신한은행 가상 점포 내다
# 우리금융 다문화 장학재단 다문화 부부 쌍 예식 지원
# 우리금융 다문화 장학재단 다문화 부부 결혼식 참여자 모집
# 우리금융 다문화 부부 결혼식 쌍 모집
# 코스닥 주간 기관 순 매수 위 와이지엔터테인먼트
# 유진 투자 증권 디지털 혁신 임팩트 투자 앞세우다 퀀텀 점프 경 스타즈
# 지니 뮤직 메타 버스 여행기 혹캉스 공개
# 코스닥 주간 외국인 순 매수 위 카카오 게임 즈
# 카카오 싱가포르 블록 체인 자회사 크다 러스트 설립
# 싱가포르 가다 김범수 의장 제의 카카오 낙점 사업
# 카카오 뱅크 뱅크 중요하다 건 카카오 이다
# 카카오 대리 운전 빅뱅 모빌리티 주도 권 경쟁 격화
# 청담러닝 화끈 중간배당 오 너 부부 억 챙기다
# 코오롱 수소차 부품 아라미드 미래 신 사업 확대
# 고 점 찍다 내려오다 파라다이스 지금 담다 되다
# 행정공제회 효과 오다 수익률 쑥
# 빅히트 크래프톤 물 타 기한 개미 들 증권 가도 사라
# 하나은행 천안함 미성년 유족 성금 운용
# 천안함 전 사자 자녀 국민 성금 하나은행 신탁 계약 통해 관리
# 한국 조선해 양은 그린 수소 유망 주 대다 기업 선정
# 자가면역질환 치료 제 임 상 재개 가능성 한 올 바이오 파마 오르다 때 돼다
# 차다 사업 본 궤도 한솔 케미칼 목표 줄줄이 오르다
# 한화 태양광 중심 그린 에너지 육성 항공우주 등 신 사업 순항
# 한화 수 소우주 항공 쌍끌이 공략 나서다
# 단독 현대 그린 푸드 부정 당 업체 지정
# 현대 모비스 등 개사 수 소 모빌리티 쇼 수소 기술 발표
# 현대 모비스 전기차 핵심 부품 글로벌 고객 확보 총력
# 현대 모비스 등 개사 수소 신 기술 발표회 어워드 본선 진출
# 현 대리 바트 현대 프리미엄 아울렛 김포 점 리 바트 김포 점 개장
# 토탈 인테리어 전시장 리 바트 김포 점 오픈
# 현 대 건설 짓다 브랜드 주거 용 오피스텔 힐스테이트 도안 퍼스트 월 분양
# 현대 건설 부산 범천 구역 시공사 선정 년 연속 도시 정비 수주 조원 눈앞
# 현대 건설 부산 범천 구역 시공사 선정 올해 수 주 액 조원 달다
# 현대차 기아 유럽 전기차 시장 승승장구 스웨덴 독일 판매 위
# 단독 이노 배터리 영토 무한 확장 삼성 현대차 출신 파격 영 입
# 카카오 그룹 현대차 그룹 서열 위 경쟁 전
# 변중석 여사 주기 제 사범 현대 다시 모이다
# 현대차 월드 랠리 팀 벨기에 랠리 도요타 제 우승 준우승 차지
# 현대차 테슬라 앞 다투다 참전 조 미래 먹거리 정체
# 코로나 시대 택시 수요 조준현 대 스타 리아 본격 투입
# 주간 추천 주 실적 개선 주목 현대 제철 골프 존 러브콜
# 현대차 안 돼다 비웃음 사라지다 정의선 뚝심 일구다 내다 우승
# 현대차 반기 영업 익 천억 디지털 전환 힘쓰다
# 고 변중석 여사 주기 현대 개월 한자리 종합
# 현대차 국민 전기차 만들다 초 강수아 이 오 닉 싹 바꾸다
# 하이 텍 최대 실적 전망 반도체 중소형주 톱픽유 안타
# 금융투자 한섬 분기 호실 적 화장품 사업 영업 비용 늘 것
# 반기 보고서 감사 의견 의견 거절
# 제일제당 겉바 속 촉 고 메 치킨 신제품 종 선봬
# 제일제당 고 메 치킨 신제품 종 선봬
# 인질 필 감성 감독 무비 라이브 딜 진행
# 나영석 상반기 보수 억만원 오 너 일가 더 받다
# 홀딩스 억원 규모 제주항공 주식 취득
# 리테일 커머스 점 과녁 겨누
# 건설 대전 장대 구역 정비 사업 시 공자 선정 취소
# 허다 태수 그룹 회장 상반기 보수 억원 전 년 억원 늘다
# 거래소 개선 기간 종료 상장폐지 여부 결정 예정
# 억원 규모 만주 전환 청구권 행사 전환 원
# 이 앤 씨 역대 최고 성능 인증 받다 층 간 차다 바닥 구조 북가좌 구역 적용
# 김태오 금융 회장 실천 더 나은 미래 열다 갈다 것
# 표 등 코스닥 자 사주 신청 내 역일
# 올해 역대 급 실적 컨테이너선 운임 연일 순풍
# 인력 빼 가기 본격 화 선원 통째 스카우트
# 적선동 괴담 씻다 내다 현대 그룹 떠나다 여의도 새 둥지 서 종갑 헤비 뉴스
# 현대 산업 개발 고덕 아이파크 디어 반 갤러리 오픈
# 해운대 앞마당 건설 해운대 센트 스위첸 분양
# 하반기 확실하다 실적 개선 목표
# 배달 상권 빅데이터 분석 서비스 출시
# 카카오 처음 무료 무기한 공짜 상권 정보 이유
# 어느 구역 치킨 가장 많이 시키다 가다 분석 해주다
# 음성 조명 제어 강남 오피스텔 스마트홈 제공
# 클릭 종목 확실하다 실적 목표 주가 만천원
# 삼성 바이오 대다 직원 로 가장 많다 대가 절반
# 잘나가다 배달 분석 소상 공인 어려움 해결 하다
# 내 가게 주변 상권 배달 분석 해드리다
# 구 현모 사장 상반기 억 받다 박윤 영 전 사장 억원
# 진출 공식 화 디즈니 유플러스 손잡다
# 구광모 그룹 회장 상반기 보수 억원 수령
# 천원 사랑 캠페인 천안함 용다 자녀 기 부금 전달
# 유플러스 천원 사랑 통해 소외 이웃 크다 힘
# 황현 식 사장 상반기 보수 억원 하 현 회 전 부회장 억원
# 유플러스 천안함 정종 율 상사 자녀 기 부금 전달
# 구광모 회장 상반기 보수 억 만원 받다
# 중소 형 생산 능력 확충 디스플레이 조억 투자
# 디스플레이 중소 형 시설 투자 조원 투입 월 만장 생산 능력 구축 하다 것
# 조원 투자 하다 삼성 잡다 디스플레이 정면 대결
# 소비 심리 개선 분기 영업 익
# 증권 휠라 홀딩스 분기 실적 좋다 하반기 정체 목표 하향
# 투자 증권 상반기 순이익 억
# 투자 증권 상반기 순이익 억원 사상 최대 실적
# 잎담배 농가 수확 봉사 년 째 농민 상생 실천
# 코스피 외인 매 도세 낙폭 키우다 네이버 카카오 가까이 내리다
# 이 너 랩 일 네이버 쇼핑 라이브 구매 시 전 고객 김호중 이모티콘 증정
# 외국인 팔자 카카오 네이버 대다 동반 하락
# 골드 팡 네이버 브랜드 데이 맞다 쇼핑 라이브 진행
# 이번 주 추천 주 모멘텀 뚜렷하다 네이버 현대 제철 등 주목
# 네이버 이다 뮤지션 온라인 공연 활성화 나서다
# 디 앤디 플랫폼 리츠 공모 대박 증권 리츠 투자 역량 주목
# 프라임 리츠 보통주 주다 원 현금 배당 결정
# 구자열 그룹 회장 상반기 보수 억원
# 구자열 그룹 회장 상반기 보수 억원
# 헬로비전 오픈마켓 최신 프리미엄 폰 꿀 조합 유심 기획전
# 정철 동 이노 텍 사장 상반기 보수 억만원
# 전자 서비스 엔지니어 교육 플랫폼 배움 마당 확대
# 전자 하이 엠솔루텍 시스템 에어컨 및 공조 유지 보수 원 격 관리 결합 되다 에너지 절감 서비스 출시
# 전자 고객 만족 위해 서비스 엔지니어 교육 플랫폼 키우다
# 상반기 억 받다 전자 권봉 석송 대현 사장 억
# 평가 정보 비대 채권 추심 시스템 전면 시행 예정
# 분기 사상 최대 실적 행진 목표 만원 상향 하나 금융투자
# 전자 하이 엠솔루텍 시스템 에어컨 및 공조 유지 보수 원 격 관리 결합 되다 신규 에너지 절감 서비스 출시
# 전자 폭염 에어컨 불티 공장 가동 률 진 기록
# 자회사 실적 호조 목표 가신
# 상반기 전자 보수 위 권봉 석 지난해 대비 배 늘어나다 억
# 녹슬다 않다 철 강재 포스 맥 포스코 내진 강재 시장 공략
# 포스코 녹슬다 않다 철 강재 건설 시장 뚫다
# 포스코 부식 방지 특수 철 강재 판매 나서다
# 최정우 포스코 회장 상반기 보수 억만원
# 하이 투증 첨단 소재 높다 가동 률 실적 턴 어 라운드 가속 화 목표 업
# 하반기 확실하다 실적 개선 목표
# 그룹 품 안다 시 그 넷 이브이 빠르다 신용 개선 마켓 인사이트
# 신설 회사 스퀘어 월 출범 반도체 투자 주력
# 신설 투자 사명 스퀘어 글로벌 투자 기업 도약
# 신설 회사 사명 스퀘어 결정
# 에코 플랜트 유니콘 꿈꾸다 친환경 스타트업 모집 하다 메타 버스 데모 데이 개최
# 신설 회사 명 스퀘어 박정호 순 자산 가치 조로
# 에코 플랜트 친환경 스타트업 모집 메타 버스 데모 데이 개최
# 최태원 상반기 보수 억 하이닉스 받다 억 반납
# 신설 회사 스퀘어 월 출범 반도체 투자 집중
# 에너지 국내 첫 탄소 중립 휘발유 판다
# 특징 주 케미칼 바사 급등 덩달아 상승
# 에너지 국내 최초 탄소 중립 석 유제품 출시
# 에너지 국내 최초 탄소 중립 휘발유 항 공유 선보이다
# 삼 전 하이닉스 주가 바닥 근접 램 조정 크다 않다 것
# 삼성 전자 하이닉스 주가 불안하다 주목 하다 하다 종목 들
# 투자 노트 만원 대 횡보 하이닉스 사도 좋다 언제 사다 하다
# 속보 삼성 전자 하이닉스 일만 상승 반전
# 특징 주 주가 바닥 오다 삼성 전자 하이닉스 소 폭 상승
# 특징 주 하이닉스 외국인 러브콜 재개 삼성 전자 팔자 여전
# 반도체 대 장주 들 살아나다 삼 성전 자 하이닉스 장 초반 상승세
# 한미 반도체 하이닉스 억원 규모 반도체 장비 수주 계약
# 삼성 전자 하이닉스 저 점 찍다 오르다 나장 초반 반등
# 엿새 째 매도 나선 외국인 삼 성전 자 하이닉스 바닥
# 삼성 전자 하이닉스 단기 바닥 론 솔솔
# 도 반도체 주 경 고 삼 성전 자 하이닉스 목표 주가 하향
# 삼성 하이닉스 매도 외치다 주일 사라 주가 너무 떨어지다
# 하이닉스 램 수요 내년 늘어나다 것
# 하이닉스 이석희 사장 상반기 보수 억원 최태원 회장 급여 반납
# 신라 젠 새 대표이사 김상원 텔레콤 본부장 선임
# 신설 투자 사명 스퀘어 글로벌 투자 기업 도약
# 신설 회사 사명 스퀘어 결정
# 클라우드 레이 로 최적 비용 절감 방안 찾다
# 신설 회사 스퀘어 월 출범 반도체 투자 주력
# 신설 회사 명 스퀘어 박정호 순 자산 가치 조로
# 신설 회사 스퀘어 월 출범 반도체 투자 집중
# 박정호 사장 상반기 억만원 받다
# 통신사 연봉 킹 박정호 사장 상반기 억원
# 바이오 사이언스 장 초반 급등 백신 출하
# 특징 주 케미칼 바사 급등 덩달아 상승
# 특징 주 바이오 사이언스 신고 경신 강세
# 특징 주 바이오 날 삼바 사상 첫 만원 돌파 바이오 사이언스 신고
# 마켓 뷰 코스피 개월 최저 치 경 신 바사 삼 성 바이오 동반 상승
# 코스피 오전 중 외국인 매 도세 하락 바사 급등
# 주 식초 고수 지금 임 상 상 바이오 사이언스 매수 매도 위카 뱅 매다 몰리다
# 삼 성 바이오 직스 만원 뚫다 바사 장 중 주 신고
# 트릴 리온 식물성 카페인 만 함유 카페인 샴푸 출시
# 반기 보고서 감사 의견 의견 거절
# 경남 제약 상반기 매출 억원 역대 최대 실적
# 경동제약 억원 규모 자 사주 매입 결정 주주 가치 제 정책 적극 실행
# 강원랜드 일 오전 시 카지노 임시 휴장 코로나 확산 방지
# 갤럭시 멀다 트리 주주 가치 제 위해 중간배당 실시 주다 원주목 공시
# 교촌 에프 앤비 분기 매출 천억원 전 년
# 광림 억원 규모 파생상품 부채 평가 손실 발생
# 고 바이오 랩 신임 연구소장 강윤 경 박사 선임
# 계양 전기 상반기 매출 억 달성 최대 실적 경신
# 그린 플러스 년 상반기 매출 억원 전 년
# 굿 세다 중소 중견 상 장사 내부 회계 클라우드 서비스 본격 화
# 뒷 목 잡다 깨끗하다 영업 이익 분 토막
# 깨끗하다 광복절 맞다 독립유공자 후손 지원 하다 버츄얼 런 동참
# 기업은행 코로나 의료 진 등 희망 냉장고 지원
# 사계절 다 쓰다 가성 비 타이어 금호 타이어 신제품 솔 루스
# 금호 타이어 영업 익 억원 흑자 전환
# 임단협 불만 금호 타이어 노조 크릴 룸 점 거사 측 대책 마련 중
# 마켓 워치 한 앤 컴퍼니 홍원식 남양유업 회장 이다 총 전 사전 교감 없다
# 노쇼 아니다 맞다 남양유업 매각 산
# 한 앤 컴퍼니 남양유업 준비 미흡 사실 무근
# 대 주주 리스크 남양유업 상반기 억 영업 손실 적자 폭 확대
# 남양유업 분기 영업 손실 억 수익 품목 매출 정체
# 홍원식 남양유업 전 회장 매각 결렬 사실 무근 한 앤컴 기다리다
# 나이 벡 상반기 사상 최대 매출 골 재생 바이오 소재 성장 본격 화 기대
# 네오위즈 신작 의 거짓 티저 개설 인력 채용 진행
# 네오위즈 블레스 언리쉬드 인기 몰이 지속 누적 다운로드 만 돌파
# 넥 스턴 바이오 상반기 매출 액 억 원 전 년
# 마켓 하나 반도 체신 기술 투자 조합 네 패스 아크 주식 만주 블록딜
# 넥센 타이어 영업 이익 억원 운임 비 상승 수익 성 낮아지다
# 네 오 티스 억원 규모 자동차 써다 루프 모터 웜 공급 계약
# 뉴 로스 반기 검토 의견 부적정 등 사실 확인
# 농심 분기 영업 이익 억 원 전 년 동기 대비 감소
# 농심 팔도 라면 유해 물질 검 추다 식약처 위해 성 없다 수준
# 농심 분기 영업 이익 억 원 전 년 대비
# 특징 주 녹십자 랩셀 코로나 게임 체인 저 머크 세계 최초 경 구 용 개발 부각
# 노루 페인트 바이오 페인트 종 국내 최초 인증
# 노루 페인트 친환경 제품 농 무부 인증
# 스핀 엑스 인수 호재 맞다 넷마블 주가 전망 엇갈리다
# 넷마블 에프 앤 씨 자체 웹소설 카카오페이지 출시 게임화 모색
# 대 보마 그네 틱 억 규모 차다 소재 임 가공 계약
# 코스닥 공시 에이 디 칩스 대 보마 그네 틱
# 년 대동 해외 급성 장 상반기 매출 액 억원 돌파 역대 최대
# 대동 창사 이렇다 최대 상반기 매출 영업 이익
# 대 영 포장 제로 금리 억 발행
# 대양 금속 오다 분기 영업 익 억 달성 전 년 동기
# 대원미디어 분기 연결 영업 이익 억 원 전 년비
# 대우조선 하다 양도 후파 상승 울다 분기 영업 손 조원
# 대우조선 해양 매출 급감 후파 폭등 분기 조원 손실
# 건설 열전 코코넛 자라다 땅 신도시 베트남 지도 새롭다 그리다 최 동일 대우건설 차장
# 대웅제약 자회사 아이 테라 퓨틱스 안구 통증 치료 제 개발 협약
# 깜짝 주인공 대신 증권 나인 원 한남 년 결실 통 하다
# 대한항공 엔진 정비 계 열사 지 분 천만 불 인수
# 대한항공 화물 초 호황 실적 호조 세 하반기 지속
# 종목 속 대한항공 분기 실적 호조 여전하다 불확실 성
# 삼성 증권 대한항공 델타 변 이 여객 수요 회복 지연
# 대한항공 왕산 레저 매각 마무리 추정 금액 억대 유동성 숨통
# 대한항공 년 분기 영업 이익 최대 치대다 증권
# 대한항공 재무 구조 개선 수요 회복 과정 점유 율 확대
# 월 치과 미용 의료기기 수출 성장 지 속 덴티움 최선호
# 더블유 게임 즈 어닝쇼크 목표 자회사 상장 주목 현대차
# 대 호에이 상반기 영업 익 억만 원 전 년
# 대한해운 분기 영업 익 억원 전 년 증가
# 대한해운 상반기 영업 익 억원 그룹 편입 후 최대
# 동국제강 철근 컬러 강판 판매 호조 반년 지난해 더 벌다
# 년 이후 최대 생산 동국제강 분기 실적 날다
# 철강 건설 호조 동국제강 년 최대 실적
# 대한해운 그룹 편입 후 최대 실적 상반기 영업 이익 억원
# 동국제강 분기 영업 이익 억 깜짝 실적 년 최대
# 동양 피스톤 분기 뚜렷하다 실적 개선
# 디 알텍 분기 매출 증가 억 하반기 더 좋다
# 아이리버 풀 블랙박스 신제품 종 출시
# 이데일리 두산 중공업 수처리 사업 수주 억원 규모
# 두산 중공업 억원 규모 영국 수처리 사업 수주
# 동화 기업 강화 마루 아이온 출시
# 디케 이티 무상증자 권리락 급등
# 디앤 씨미디어 분기 실적 호조 콘텐츠 제작 능력 강화
# 레드 로버 반기 보고서 감사 의견 의견 거절
# 램 테크 놀다 지다 상반기 영업 익 전 년비 경 영 효율 화 효과
# 특징 주 라파스 주 신고 알레르기 성 비염 면역 치료 제 개발
# 라이프 시맨틱스 억원 파생상품 금융 부채 평가 손실 발생
# 라이프 시맨틱스 억원 규모 오픈 헬스 플랫폼 구축 계약
# 온 시 큐어 약국 체인 헬스 블록 체인 공급
# 닉스 억원 규모 밉다 전환사채 전환 가액 조정
# 끈질기다 코로나 롯데 관광 개발 여행 호텔 체질개선 안간힘
# 클릭 종목 롯데 관광 개발 분기 매출 억원 돌파 예상
# 마크로 젠 상반기 매출 영업 이익 사상 최대 규모 달성
# 매일유업 셀 렉스 단백질 시장 등 지키다
# 메 지온 유데나필 간질 환 개선 효과 특허 출원
# 메리츠화재 김용범 상반기 억 현 대 해상 정몽윤 억
# 표메 리츠 증권 등 코스피 자 사주 신청 내 역일
# 메디프론 상반기 영업 익 억원 관리종목 우려 해소
# 메 디톡스 분기 영업 이익 흑자 전환 하반기 회복 지속
# 메디앙스 반기 보고서 감사 의견 한정
# 하다 해치 벌다 남다 메가스터디
# 하다 해치 벌다 남다 메가스터디
# 맥스 텍 반기 보고서 감사 의견 의견 거절
# 미래 산업 상반기 영업 익 핸들 러 사업 부문 호조
# 신제품 신 기술 몸체 측면 버튼 심 조절 모나미 클리 키 샤프
# 명성 티엔 에스 반기 보고서 감사 의견 의견 거절
# 마켓 인사이트 코넥스 상 장사 바이옵트 코스닥 이전 상장 추진
# 마켓 인사이트 코넥스 상 장사 바이옵트 코스닥 이전 상장 추진
# 마켓 인사이트 코넥스 상 장사 바이옵트 코스닥 이전 상장 추진
# 마켓 인사이트 코넥스 상 장사 바이옵트 코스닥 이전 상장 추진
# 바이옵트 등 개사 코스닥 상장 예비 심사 청구
# 삼정 바이오 솔루션 제 약 조합 중대 재해 법 대응 협약
# 삼정 바이오 솔루션 한 국제 약 협동조합 협업 하다
# 특징 주 바이오 그 디바이스 네이처 비강 투여 스프레이 코로나 더 효과 적 보도 강세
# 보령제약 시 노 파다 억원 겔 포스 독점 공급 계약 체결
# 유가 증권 시장 공시 보령제약
# 보령제약 억 규모 겔 포스 중국 독점 판매 계약 체결
# 브랜드 엑스 코퍼레이션 무상증자 주권 매매 거래 정지
# 빙그레 분기 매출 억 전 년 동기 대비
# 원가 상승 이르다 장마 빙그레 분기 영업 익
# 도 순항 비즈니스 온 영업 익 억 역대 분기 최대 실적
# 비 에이치 아이 억 규모 복합 화 력 발전 설비 공급 계약
# 거래소 비디아이 반기 검토 의견 비적 정설 조회 공시 요구
# 삼성 전자 하이닉스 주가 불안하다 주목 하다 하다 종목 들
# 특징 주 삼 성 전자 거래 일만 상승 반도체 단 기 저 점
# 삼성 전자 제 회 삼성 보안 기술 포럼 개최
# 그래도 삼성 전자 뿐 개인 주주 석 달새 만 명 늘다
# 삼성 전자 갤럭시 기본 앱 광고 없애다
# 삼성 전자 하이닉스 단기 바닥 론 솔솔
# 삼성 전자 팔 제 끼다 외국인 그 와중 사들이다 종목
# 모간 스탠리 입 열자 만 전자 현금 조 삼성 해법
# 삼성 전자 김기남 상반기 급여 억원 이재용 년 째 무보수
# 삼성 준법 위 이재용 가석방 후 첫 회의 위법 리스크 지표 화
# 삼성 하이닉스 매도 외치다 주일 사라 주가 너무 떨어지다
# 삼성 전자 고용 만 명 돌파
# 중소 형 조억 선제 투자 삼성 독주 추격
# 대기업 홈피 다운 되다 삼성 닷컴 마비 시키다 한정판 정체
# 삼성 전자 팔 던 외국 계 증권사 일주일 오르다 것
# 도 반도체 주 경 고 삼 성전 자 하이닉스 목표 주가 하향
# 역대 급 상품 나오다 개다 폴드 예약 첫날 삼성 홈페이지 마비 돼다
# 코스피 코스닥 급락 삼전 내리다 카뱅 오르다
# 주가 횡보 삼성 전자 개미 늘다 개월 배
# 삼성 전자 스마트폰 패널 쓴다
# 폴 더블 핵심 지 분 매입 두다 삼성 소액 주주 신 경전 왜
# 제 회 삼성 보안 기술 포럼 개최 편의 성 강화 되다 만큼 보안 우려
# 삼성 전자 제 회 삼성 보안 기술 포럼 온라인 개최
# 삼성 닷컴 마비 신형 폴 더블 폰 인기 이 정도
# 삼성 구부러지다 고집 커브 드 모니터 시장 올해 성장
# 대기업 명 중 명 해외 고용 삼 성전 자 국내 더 늘리다
# 만 주주 자다 들다 하다 삼성 전자 거래 일 반등 시도 바닥 찍다
# 준지 입다 리복 삼성 물산 준지 리복 콜라보
# 삼성 전자 신 개념 조리 기기 비 스포크 큐 크다 소비자 사로자다
# 엿새 째 매도 나선 외국인 삼 성전 자 하이닉스 바닥
# 삼 전 하이닉스 주가 바닥 근접 램 조정 크다 않다 것
# ...
# 하나은행 신용 대출 한도 연 소득 마통 한도 만원
# 하나은행 신용 대출 죄기 한도 연봉 만큼 은행권 확산
# 엄빠 카드 이제 그만 하나은행 아이 부자 카드 출시
# 하나은행 어린이 용돈 용 선불카드 출시
# 지배구조 톺다 보기 국내 최초 증권사 중심 금융 그룹 한국 금융 지주 카뱅 함박 웃음
# 파다 캐드 내년 상장 추다 관사 한국 투자 증권 선정
# 하이트진로 환경 성적표 인증 업계 최 획득
# 하이트진로 친환경 경영 앞장서다
# 가스 공사 수소 사업 본격 화 저 탄소 친환경 에너지 시대 선도
# 단독 하나투어 공평동 사옥 키우다 증권 억 인수
# 하나투어 억원 규모 부동산 보 유지 분 매각
# 보릿고개 지나다 하나투어 억원 본사 매각
# 뮤지션 데뷔 하나투어 음원 발매 속사정 살펴보다
# 현대 그룹 식구 되다 두산 인프라 새 이름 현대 두산인프라코어
# 현대 카카오 페이 대다 출격 대형주 명예 회복하다
# 서부 발전 포스코 현대 안전 기술 교류 업무 협약
# 한전 경영 확대 열흘 바다 풍력 발전기 세우다 기술 첫 개발
# 개 공공기관 안전 관리 빨갛다 불 한전 코레일 패널 티
# 주 식초 고수 지금 한국 비엔 씨 코로나 치료 제 기 대감 이틀 연속 매수 위
# 한국 카본 이스라엘 항공기 외 장재 공급
# 최강 자 노리다 한국 타이어 전기차 타이어 역량 집중
# 한국 콜마 유엔 글로벌 콤팩트 가입 하다 글로벌 기준 경영 강화
# 한국 콜마 유엔 글로벌 콤팩트 가입 경영 강화
# 한솔 제지 실적 호조 주가 재 평가 목표 상향 현대차
# 한섬 현대 압구정 본점 럭셔리 스킨 케어 오 매장 연 다
# 금융위 직원 내부 정보 빼 돌리다 대우조선 한진 차 명 투자 덜미
# 한송네오텍 오다 억원 규모 장비 공급 계약
# 프로필 남 이현 한화 솔루션 케미칼 부문 대표이사 사장
# 예년 빠르다 한화 그룹 사 장단 인사 한화 시스템 어 성철 한화 케미칼 남 이현
# 프로필 이구영 한화 솔루션 큐셀 부문 대표이사 사장
# 한화 투자 증권 한화 운용 지 분 인수 소식 강세
# 예년 빠르다 한화 그룹 사 장단 인사 한화 시스템 어 성철 한화 케미칼 남 이현
# 프로필 어 성철 한화 시스템 대표이사 사장
# 한화 투자 증권 한화 운용 지 분 인수 소식 강세
# 예년 빠르다 한화 그룹 사 장단 인사 한화 시스템 어 성철 한화 케미칼 남 이현
# 한화 개 계 열사 대표이사 내 정세 용띠 클럽 이끌다
# 한화 하다 달 빨리 사 장단 인사 단행 이유
# 한화 김승연 회장 복귀 첫 사 장단 인사
# 한화 그룹 사 장단 깜짝 인사 급변 경 영 환경 신속 대처 종합
# 한화 개 계 열사 대표 인사 단행 경영 환경 급변 신속 대응
# 평일 서핑 하다 수 있다 회사 있다 한 화생 명 근무 실험
# 한화 그룹 노벨상 도전 과학 영재 경진 대회 년 째 개최 인재 곧 경쟁력 기업 들 미래 인재 확보 총력전
# 한화 생명 양 양 호텔 원 격 근무
# 바닷가 호텔 일 하다 바로 서핑 워 밸 원 격 근무 실험 나선 한화 생명
# 한 화생 명 새롭다 일 하다 방식 운영
# 바다 보다 일 하니 일 잘 되다 한화 생명 원 격 근무 호응
# 현대 건설 기계 사내 안전 전문가 집중 육성 나서다
# 에너지 공단 서울시 현대 건설 등 에너지 취약 계층 지원 협약
# 현 대리 바트 아동 용 가구 몰리 시리즈 출시
# 구경 해보다 흔들다 의자 만원 식탁 만원 현 대리 바트 수입 하다
# 현대 모비스 하이브리드 채용 임 직원 연 회 교육 인재 곧 경쟁력 기업 들 미래 인재 확보 총력전
# 현대 건설 힐스테이트 익산 완판
# 현대 모비스 초등생 주니어 공학 돌보다 교실 운영
# 현 대 모비스 나눔 초등생 대상 공학 돌보다 교실
# 현대 백화점 식당가 서빙 로봇 다니다
# 현 대 백화점 유통업 계 디지털 혁신 추진 다
# 유연석 푹 빠지다 캠핑카 현대차 내놓다 구 매 대 기자 줄 서다
# 현대차 마이티 등 만대 리콜
# 현대차 전세계 수소 사회 비다 선포 차세대 수소 기술 총 망라
# 수 소 스포츠카 이동식 충전기 현대차 수 소 신 기술 내달 일 선보이다
# 현대차 월 전세계 수소 물결 일으키다
# 현대 그룹 수소 사회 비다 연 다 내달 일 하 이드 젠 웨이브 개최
# 미래 수 소비 전 한눈 현대차 그룹 다음 달 일 하 이드 젠 웨이브 개최
# 장애인 고용 최 기업 현대차 년 연속 명 넘다
# 현대차 그룹 미래 모빌리티 특허 기술 개발자 통큰 포상 인재 곧 경쟁력 기업 들 미래 인재 확보 총력전
# 장애인 임 직원 최 달다 현대차 기업 장애인 고용 인원 증가 세
# 전향 적 안 현대 제철 자회사 통한 협력 사 직 고용 진통
# 현대 제철 사내 협력 사 근로자 직 고용 사회 적 책임 앞장 인재 곧 경쟁력 기업 들 미래 인재 확보 총력전
# 서울 신라 호텔 유니버설 뮤직 코리아 랜선 공연
# 쿠쿠 전자 트윈프레셔 쁘띠 현대 홈쇼핑 잇다 완판
# 고맙다 확대 빠르다 수익 성 높이다 현대차 증권 마켓 인사이트
# 효성 그룹 멘토링 임원 등 직급 별 맞춤 형 교육 인재 곧 경쟁력 기업 들 미래 인재 확보 총력전
# 효성 경 단 녀 재 취업 천만원 후원
# 특징 주 머티리얼즈 합병 소멸 투자 대안 주목 효성 화학 급등
# 시그널 글로벌 컨소시엄 팔리다 휴 젤 산업부 승인 남다
# 뒷북 비즈 보톡스 위 휴 젤 품다 허다 태 수표 혁신 시동 걸다
# 시그널 글로벌 컨소시엄 팔리다 휴 젤 산업부 승인 문턱 넘다
# 대신 휴켐스 장기 계약 탄소배출권 가격 상승 목표 상향
# 휴켐스 공장 신설 위해 억원 신규 투자 결정
# 에너지 대 한 통운 손 잡고 사업 나서다 종합
# 공 기 청정 항균 건강하다 아파트 내 건 이 앤 씨
# 손보 카카오 페이 제휴 암 보험 출시
# 나랏돈 조 투입 사상 최대 실적 은 파업 위기
# 현대 산업 개발 고덕 아이파크 디어 반 일 계약 시작
# 현장 천막 친 노조 파업 우리 싫다
# 상선 최대 실적 이면 아직도 한진해운 사태 후유증
# 메 리츠 건설 하반기 실적 회복 기 대감 자회사 모멘텀 부각
# 건설 홍성 자 온 오프라인 견본주택 오늘 개관
# 컨소시엄 인수 하다 휴 젤 연일 주가 떨어지다 이유
# 샵 로봇청소기 위 에브리 봇 신 상품 년 론칭
# 시 총 조원 훌쩍 넘다 신용 상향 전망 자다 나가다 김은정 기업 워치
# 건설 광명 퍼스트 스위첸 분양
# 마켓 워치 코퍼레이션 빌딩 관리 사업 부 매각 국내 등 참여
# 실적 자회사 상장 긍정 적 홀딩스 지 분 정리 관건 하나
# 변동 장 더 빛나다 배당 매력 증권 관심
# 추세 적 이익 성장 배당 수익 예상 대신
# 바디 프 랜드 요 금제 렌탈할 적용
# 상상 펀드 년 기억 년 상상 하다 전시 개최
# 방문 규 수 은행 장 대산 그린 에너지 동부 제철 방문
# 특징 주 넥스 원 주 신고 경북 대 미래 신 기술 개발
# 내 동료 돼다 네이버 카카오 스타트업 투자 가열
# 혈맹 플랫폼 공룡 이슈 정면 돌파 네이버 승부 수
# 네이버 현대 카드 뜨다 카카오 페이 삼 성 카드 격돌
# 네이버 엑스 퍼트 사업자 전용 웹페이지 비즈 홈 오픈
# 헬스 헬퍼 일 개그우먼 김나희 네이버 쇼핑 라이브 방송 진행
# 실적 자회사 상장 긍정 적 홀딩스 지 분 정리 관건 하나
# 일 렉 트릭 억원 규모 태양광 발전소 공사 수주
# 소비자 뽑다 등 냉장고 브랜드 전자
# 전자 인생 담다 영화 서다 소개 팬데믹 우리 연결 돼다 있다
# 전자 뉴욕 런던 영화 상영
# 전자 뉴욕 런던 영화 소개
# 유플러스 이익 개선 배당 성향 상향 전망 대신
# 오 마이걸 앞세우다 증권 투자가 문화 세대 취향 저격
# 포스코 최대 억원 회사채 발행 추진 마켓 인사이트
# 포스코 현 대미 포 조선 한국 조선해 양 액화 운반 선 개발 추진
# 한국 동서 발전 포스코 급 연료 전지 공동 사업 추진
# 밉다 포 조선 한국 조선 손잡다 액화 운반 선 만들다 포스코
# 차다 소재 진출 성장 전략 변화 목표 대신
# 청약 앞두다 리츠 투자 매력
# 최태원 상시 토론 딥 체인지
# 공정위 실 트론 사익 편취 조사 마무리 내주 심사 보고서 발송
# 최태원 끊임없다 변화 하다 만들다
# 대다 신평 사 오다 합병 머티리얼즈 신용등급 일제 히 상향 검토
# 최태원 회장 상시 토론 장 열다 부단하다 변화 하다 만들다
# 에쓰오일 화학 투자 현대 수소 동맹 협력 넓히다 아람 코
# 드림 어스 컴퍼니 오다 억 규모 이용권 제공 계약
# 번가 장애인 근로자 위 서비스 강화
# 내달 콘퍼런스 연 다 연 구 투자 연결 생태계 모색
# 대다 신평 사 오다 합병 머티리얼즈 신용등급 일제 히 상향 검토
# 디 앤디 에피소드 유희열 생활 음악 프로젝트 진행
# 파리 바게뜨 삼립 식빵 언니 김연경 선수 모델 선정
# 게임빌 별 되어다 세 컨드 임팩트 영웅 등장
# 기아 노조 임단협 잠정 합의 안 찬성 년 무 분규 타결
# 기아 노사 한 발 씩 양보 년 무 분규 임단협 타결
# 기업은행 전기차 충전 할인 혜택 카드 출시
# 깨끗하다 인증 획득 친환경 크라프트 보드 제품 출시
# 삼 성 물산 남해 화학 남부 발전 청정 수소 도입 체결
# 남양유업 케어 비 배달 이유식 썸머 케 스티 벌 이벤트
# 국민 청원 남양 홍원식 회장 규탄 글일 안 급여 받다 건 횡령
# 넥 스턴 바이오 자회사 로스 비보 제 약사 당뇨병 신약 공동 개발
# 특징 주 다믈 멀티미디어 베다 홀딩스 인수 상한 직행
# 특징 주다 믈 멀티미디어 최대 주주 변경
# 특징 주 대 양 금속 조강 생산 량 감소 반사 이익 기대 강세
# 대신 리뉴얼 대신 증권 이색 구 독자 이벤트
# 검찰 압수수색 받다 대웅제약 조 사 내용 쏠리다 의혹
# 특징 주 대 원강 업 현대차 내달 수소 비다 공개 넥쏘 핵심 부품 독점 공급 부각
# 유가 증권 시장 공시 대우건설
# 대 한 제분 헬스 밸런스 인수 결정 되다 사항 없다
# 동국제강 아동 센터 연 계 숲 생태 체험 활동 지원
# 공시 공정위 동 양 파일 과징금 억원 부과 부당 공동 행위
# 동양 파일 콘크리트 담합 과징금 억 부과
# 두산 브랜드 사용 료 억원 내면 현대 현 대 두산인프라코어 이름 정 이유
# 드래곤플라이 부산 메타 버스 생태계 구축 업무 협약 체결
# 두산 브랜드 사용 료 억원 내면 현대 현 대 두산인프라코어 이름 정 이유
# 부산 동원 시티 비스타 주택 전시관 오픈
# 드림 어스 컴퍼니 오다 억 규모 이용권 제공 계약
# 마켓 인사이트 롯데 지주 경영 롯데 자산 개발 억 수혈
# 롯데 칠성 베다 플래그 와인 종 출시
# 롯데 제과 한솔 제지 친환경 패키지 개발
# 롯데 제과 한솔 제지 친환경 포장재 개발 나서다
# 링 네트 억 규모 자 사주 취득 신탁 계약 체결
# 메이슨 캐피탈 운용 자금 마련 위해 억원 차입
# 매일유업 상하 농원 추석 선물 세트 출시
# 대우 증권 억 규모 충주 주상 복합 신축 사업 수주
# 미코 바이 오메 드 자가진단 용 코로나 항체 키트 수출 허가 획득
# 베스파 신작 타임 디펜더 스 시장 출격
# 특징 주 다믈 멀티미디어 베다 홀딩스 인수 상한 직행
# 베셀 에어로 스페이스 시리즈 투자 나서다 기업 가치 억 기대
# 특징 주 비디아이 사흘 째 급등 흡입 식 폐암 치료 제 승인 추진
# 특징 주비 엠티 현대차 수소 사회 비다 공개 수 소 충전 소 부품 국산 화 추진 부각
# 바나나 우유 줄 알다 네 빙그레 갤럭시 버즈 케이스 출시
# 삼성 물산 해외 청정 수소 도입 사업 추진
# 좋다 대표 님 삼성 전자 주식 어떻다 하다 하다 요 허다 란 경제 끼
# 시 황 저격 삼성 대규모 투자 증시 가뭄 단비
# 이데일리 낸드 세계 위 업체 위 기업 인수 추진 삼성 턱밑 추격
# 특징 주제 이 앤티 씨 삼성 폴 더블 폰 돌풍 세계 최초 플랙시블 커버 글라스 부각
# 오늘 도착 만원 파다 삼성 로또 폰 웃돈 만원 붙다
# 또 악재 터지다 삼 성전 자 초 격차 전략 어쩌나
# 역대 급 예 판 삼성 갤폴드 플립 전세계 개국 출격
# 삼성 갤폴드 플립 정식 출시 전 세계 개국 출격
# 년 상반기 법인세 분석 상반기 실적 대박 난 삼성 전자 법인세 중간 예 납
# 불다 완충 꿈 전기차 만들다 베트남 삼성 빈 그룹 발표 믿다 수 있다
# 삼성 워치 자다 나가다 글로벌 위 코 앞
# 뒷북 비즈 합종연횡 낸드 플래시 나노 양산 대결 파운드리 삼 성 전자 전략
# 단독 삼성 갤럭시 폴드 비 스포크 입히다
# 삼 성 바이오 직스 첫 공 모채 수요 예측 흥행 모집 액 배 몰리다
# 신 상품 라운지 사 조대림 해표 티백 조미료 종 출시
# 삼다 알미늄 사업 확장 필수 적 추가 리 레이 팅 기대 교보
# 삼성 증권 최대 달러 지원 백 불로 이벤트 실시
# 삼성 화재 일 농협생명 내달 일 금감원 종합 검사 재개 종합
# 틈틈하다 공부 하다 삼성 화재 설다 학습 플랫폼 인기
# 네이버 현대 카드 뜨다 카카오 페이 삼 성 카드 격돌
# 뛰다 상 아프다 론 테크 수소 밸류 체인 뜨다
# 성도 이 지다 억원 규모 양 극 재 라인 건설 계약 체결
# 방역 당국 셀트리온 렉 키로 개 병원 만 명 투여
# 코스피 잭슨 홀 회의 관망 세 속 막판 반등 셀트리온 대다 급등
# 특징 주 시장 공략 하다 셀트리온 만원 돌파 임박
# 세종 메다 칼 최대 주주 정현 국 타임 베 변경
# 솔루엠 성장하다 시장 시장점유율 높이다
# 소프트캠프 하나은행 억 규모 프로젝트 수주
# 스카이 이 앤엠 전환 가액 원 원 조정
# 과 기 정통부 스카이라이프 현대 인수 조건 부 승인
# 예술 과학 다 담다 일 대전 신세계 공식 오픈
# 인티 그 리트 신세계 백화점 로봇 큐브릭 공급 계약
# 밍크 뮤 대전 신세계 엑스포 점 신규 매장 오픈
# 단독 신 성 델타 테크 사장 등 리콜 전 보 유지 분 수십억 파다
# 시노펙 스 앱솔 루트 필터 마스크 출시
# 내달 상장 현대 중공업 글로벌 가스 추진 선 위 목표 만원 신한
# 국민 신 한 우리 가세 대 카뱅 신용 대출 연봉 이내
# 케이 뱅크 이다 신한은행 예 적금 금리 올라가다
# 서울 창조경제 혁신 센터 보육 기업 미식 시대 신한은행 배달 앱 운영 관련 제휴 업무 맡다 전망
# 신한은행 예 적금 금리 포인트 올리다
# 식약처 신 풍 제약 피 맥스 임 상 상 계획 승인
# 마켓 인사이트 쌍용차 인수 도전 하다 쎄다 밉다 시스코 에디슨 모터 스 지 분 취득
# 마켓 인사이트 쌍용차 인수 도전 하다 쎄다 밉다 시스코 에디슨 모터 스 지 분 취득
# 쌍용차 호주 법인 년 흑자 전환 오세아니아 시장 확대
# 쌍용차 호주 법인 출범 년 첫 흑자 오세아니아 공략 박차
# 아모레퍼시픽 큐브 밉다 국제 디자인 어워드 본상 수상
# 특징 주 아모레퍼시픽 염 모제 시장 위 권 진입 주가 오르다
# 씨티 케이 억 규모 거래 중단 매출
# 아이 원스 파운드리 증설 경쟁 수혜 입 기업
# 아이엘 사이언스 자회사 어헤즈 글로벌 진출 앞두다 변경
# 샵 로봇청소기 위 에브리 봇 신 상품 년 론칭
# 넥스 스토 서다 붙박다 이장 특별 할인 판매
# 애니 젠 만주 전환 청구권 행사
# 애니플러스 상반기 매출 억 원 전 년 증가
# 애니플러스 상반기 매출 전 년 증가 성장
# 에스 트래픽 해주다 전기차 충전 기술 개발 맞다 손
# 에이스침대 롯데 백화점 동탄 점 신규 오픈
# 코넥스 개 종목 거래 거래 대금 위 에이 비온
# 마켓 인 이비 온 공모 만원 희망 밴드 최상 단
# 에스 씨 엔지니어링 관계 사 셀론텍 첨단 바이오 의약품 재 허가 획득
# 에스티 큐브 당화 되다 표적 항체 특허 등록
# 케이 맥스 세포 활 성도 표준 항 암 화학요법 효과 상관관계
# 케이 맥스 전환 가액 만원 만원 조정
# 에프 씨 프랑스 이브 비건 인증 획득
# 블소 출시 엔씨소프트 주가 급락 도깨비 펄 어비스 급등
# 에스 쇼핑 하림 산업 물류 센터 억원 신축 투자
# 이 베스트 증권 엔씨소프트 블소 기 대치 미달 목표 주가 만원
# 삼성 엔씨소프트 투자 의견 홀드 낮추다 블소 초반 성과 아쉽다
# 특징 주 엔씨소프트 블소 흥행 참패 신저 목표 주가 잇따르다 하향
# 신작 부진 엔씨소프트 시 총 조 증발 증권사 전망 흐리다
# 엔씨소프트 블소 첫날 성적 부진 주말 내 순위 반등 변수
# 엔씨소프트 블소 과금 방식 실망 이틀 새 시 총 조 증발
# 블소 기대 못 미치다 엔씨소프트 이틀 째 하락 시 총 조원 증발
# 게임 대 장주 엔씨소프트 급락 또 급락 탈출 기관 외국인 크래프톤 눈길
# 엔씨소프트 블소 영기 시스템 전격 개편 이용자 의견 경청
# 영림 원 소프트 랩 한글과컴퓨터 공급
# 죠스떡볶이 오리온 고추 칩 증정 프로모션
# 예 스티 만주 전환 청구권 행사
# 속보 손태 승 우리금융 회장 금감원 소송 심 승소
# 손태 승 우리금융 회장 승소 재판 부 금감원 잘 못 되다 법리 적용 상보
# 속보 손태 승 우리금융 회장 징계 취소 판결
# 재판 부 우리은행 선정 절차 구조 적 문제 있다
# 속보 손태 승 우리금융 회장 금감원 소송 심 승소
# 우리은행 소송 판결 겸허 히 수용
# 속보 손태 승 우리금융 회장 징계 취소 판결
# 우리금융 산학 연 계 교육과정 디지털 전문 인력 육성
# 손태 승 우리금융 회장 사태 징계 취소 소송 승소
# 법적 근거 없다 무리하다 중 징계 우리은행 한시름 덜다
# 책임 우리금융 회장 심 선고 나오다
# 법원 우리금융 회장 징계 취소 하
# 오다 파다 스마트폰 출시 본격 화 실적 회복 기 대감
# 특징 주 옵 티시스 정부 메타 버스 세계 시장 선점 위해 적극 지원 세계 최초 기술 부각
# 커지다 흉터 멈추다 올 릭스 비대 흉터 치료 제 시장 겨냥
# 기업 공시 월 일 웅진 씽 크다 빅 자 사주 만 주 취득 결정 등
# 표 웅진 씽크빅 등 코스피 자 사주 신청 내 역일
# 우리 종합 금융 세대 대상 연 정기적금 출시
# 우성 사료 이다 총서 분할 등 원안 가결
# 위 닉스 타워 프라임 공기청정기 에너지 소비 효율 등급
# 특징 주 원 익피앤 주 신고 전기차 종합 솔루션 기업 기대
# 원 익머 트리 얼 즈 사상 최대 실적 경신 전망 저 평가 매력 신한
# 특징 주 투자 경고 종목 지정 원 방 테크 급등 세
# 유비 케어 멤버십 엑스선 투시 촬영 장치 추가
# 유진 로봇 아이 클레 보 로봇청소기 한가위 기념 이벤트
# 코스닥 공시 쎄다 밉다 시스코 유일 너 테크
# 유일 너 테크 억 규모 차다 조립 공정 장비 공급 계약
# 바닥 다지다 광고 이노션 제일기획 반등 채비
# 특징 주 이 그 잭스 제 인터넷 은행 사업 공동 추진 강세
# 단독 강희 석 이마트 대표 이베이 직원 들 온 오프 완성형 에코 시스템 구축 하다
# 이지스 레지던스 리츠 정기 주 총서 안건 원안 가결
# 유가 증권 기업 공시 일 일 성 건설 등
# 특징 주 여기다 때 참여 인터파크 열기 주가
# 인탑스 억 규모 자 사주 취득 신탁 계약 체결
# 유가 증권 메모 일 보통주 추가 상 장인 스 코비 전환 등
# 자안 바이오 만주 전환 청구권 행사 주식 총수
# 특징 주제 이 앤티 씨 삼성 폴 더블 폰 돌풍 세계 최초 플랙시블 커버 글라스 부각
# 제 일 제강 신 성장 동력 확보 나서다 그래핀 첨단 부품 소재 사업 진출
# 특징 주 제 일 파마 홀딩스 화이자 백신 정식 승인 소식 강세
# 바닥 다지다 광고 이노션 제일기획 반등 채비
# 진원 생명과학 백신 접종 기용 부품 개량 특허 출원
# 지 트리 비앤티 억원 독감 백신 유통 계약 흑 전 기대
# 카페 영업 이익 컨센서스 억억원 왜
# 내 동료 돼다 네이버 카카오 스타트업 투자 가열
# 고승 범 이해충돌 논란 나 카카오 관련 없다
# 노형욱 카카오 콜 몰다 공정위 결과 나오다 필요 조치 하다
# 주가 조정 매수 기회 천보 목표 주가 만원
# 차 바이오 텍 세포 치료 제 성과 언제 쯤
# 코스닥 기업 공시 일 케이 씨티 등
# 임종윤 한미 사이언스 대표 코스닥 진단 회사 캔서롭 최대 주주
# 코리아 센터 강원도 농어촌 민박 예약 일단 떠나다 출시
# 쿠쿠 홀딩스 액면 분할 마법 안통 하다 장 중
# 콜 마비 앤 에이치 토탈 서비스 건기 식 확대
# 코퍼스 코리아 상반기 영업 익 억 원 전 년
# 코오롱 더 장 중 대다 상승세 실적 개선 수소 기 대감
# 키 네 마스터 스톡 영상 제공 위해 콘텐츠 다량 확보
# 크리스탈 지노 믹스 췌장암 대상 아이 발 티노 스타트 국내 임 상 상 신청
# 태 영 건설 억원 빌딩 개발 사업 수주
# 투비소프트 나 무플 닛 사업 영업 망 확대 위해 협약
# 티웨이항공 객실 승무원 체험 비행 일반인 확대 크루 플라이트 실시
# 펌텍 코리아 하반기 고객 제품 다변 화로 지속 적 성장 한양
# 펄 어비스 급등 카겜 제 코스닥 시 총 위
# 신작 희비 엇갈리다 게임 펄 어비스 방긋 엔씨 울상
# 블소 출시 엔씨소프트 주가 급락 도깨비 펄 어비스 급등
# 주 식초 고수 지금 도깨비 효과 펄 어비스 최 매수 가량 상승세
# 펄 어비스 진출 본격 화 검다 사막 모바일 사전예약 시작
# 펄 어비스 검다 사막 모바일 중국 사전 예약 시작
# 특징 주 펄 어비스 도깨비 호평 이틀 째 신고 랠리
# 팜스빌 바이오 헬 스케 어 부문 리딩 기업 대상 년 연속 상
# 풍 강 일 배당 락 발생
# 종목 속 크다 그림 그리다 포스코 케미칼 양 극 재 성장 스토리 유효
# 내년 실적 추 정치 포스코 케미칼 합작 차다 사업 기 대감
# 특징 주 포인트 모바일 아마존 대 주주 등 극 신주인수권 만주 교부 소식 강세
# 표 포인트 엔지니어링 등 코스닥 자 사주 신청 내 역일
# 아마존 오프라인 매장 진출 포인트 모바일 수혜 기대
# 소프트캠프 하나은행 억 규모 프로젝트 수주
# 목표 상향 되다 하나마이크론 이유
# 이즈 백 올리다 참이슬 내리다 도수 낮추다 하이트진로 고민
# 하이트진로 나파 베다 컬트 와인 한정 판매
# 내달 상장 현대 중공업 글로벌 가스 추진 선 위 목표 만원 신한
# 위 클리 마켓 시 총 최대 조 현대 중공업 수요 예측 돌입
# 조 공모 나선 현대 중공업 적자 쌓이다 소송 액 억 넘다
# 두산 브랜드 사용 료 억원 내면 현대 현 대 두산인프라코어 이름 정 이유
# 에쓰오일 화학 투자 현대 수소 동맹 협력 넓히다 아람 코
# 포스코 현 대미 포 조선 한국 조선해 양 액화 운반 선 개발 추진
# 포스코 한국 조선해 양 액화 이산화탄소 운반 선 개발 맞다 손
# 김용균 벌써 잊다 나한전 등 곳 공공기관 안전 관리 구멍
# 영림 원 소프트 랩 한글과컴퓨터 공급
# 한국 타이어 버밍엄 국제 상용차 박람회 참가
# 한라 광양 한라 비발디 센트럴 마크 월 분양
# 한 샘 천안 아산 점 내달 추석 맞이 가구 이벤트
# 한섬 럭셔리 화장품 오 호 매장 오픈
# 한섬 화장품 사업 성장 모멘텀 목표 현대차
# 롯데 제과 한솔 제지 친환경 패키지 개발
# 롯데 제과 한솔 제지 친환경 포장재 개발 나서다
# 한빛소프트 신임 대표 이승현 경 영 지 원 실장 선임
# 한미 약품 세 임종윤 캔서롭 지 분 인수 최대 주주
# 임종윤 한미 사이언스 대표 코스닥 진단 회사 캔서롭 최대 주주
# 한라 홀딩스 년 지 속 가능 경 영 보고서 발간
# 한 신 공영 영업정지 처분 집행정지 인용 결정 공시
# 한화 김승연 복귀 후 첫 대표 인사 장남 신 사업 추진 력 더하다
# 한진 배송 용 전 동 대차 개발
# 루브리컨츠 한진 친환경 윤활유 협력 사업 탄소 감축 효과 확인
# 포스코 현 대미 포 조선 한국 조선해 양 액화 운반 선 개발 추진
# 밉다 포 조선 한국 조선 손잡다 액화 운반 선 만들다 포스코
# 현대 건설 비 규제 지역 가평 힐스테이트 가평 더뉴 클래스 월 분양
# 현대 건설 주거 용 오피스텔 힐스테이트 도안 퍼스트 견본주택 개관
# 현대 건설 도시 형 생활 주택 힐스테이트 남산 월 분양
# 해성 옵 틱 스 얼머스 억대 제 자 배정 유증 최대 주주 변경
# 특징 주비 엠티 현대차 수소 사회 비다 공개 수 소 충전 소 부품 국산 화 추진 부각
# 한섬 화장품 사업 성장 모멘텀 목표 현대차
# 현대차 그룹 년 전기차 다양성 위 회사 되다
# 현대 사이버 보안 가동 유럽 규제 선제 대응
# 서울 용산구 현대차 서비스 센터 부지 현대차 연구소 재탄생
# 특징 주 대 원강 업 현대차 내달 수소 비다 공개 넥쏘 핵심 부품 독점 공급 부각
# 국내 산 최고급 농축 수산물 엄선 서울 신라 호텔 추석 선물 세트 출시
# 현대 홈쇼핑 쇼핑 라이브 쏠 싸다 메인 코페르 포에버 에디 션 공개
# 종근당 건강 코어 틴 그린 프로 틴 일 현대 홈쇼핑 론칭 방송
# 과 기 정통부 스카이라이프 현대 인수 조건 부 승인
# 특징 주 수소 경제 잇따르다 호재 수 소주 상승세 효성 중공업
# 대기업 인수 다 고 기대하다 휴 젤 일 째 주가 하락 왜
# 휴먼 메타 버스 차다 소재 사업 진출
# 강북 최대 어 북가좌 구역 수 주전 승자 이 앤 씨
# 유 안타 주간 추천 주 성장 국면 진입 크다 프톤하이텍 쌍용
# 현장 사 측 파업 하다 전세계 해운 대란
# 한주 제 약 바이오 휴 젤 조원 인수
# 달라지다 이유 있다 네 공격 적 행보 그룹 회장 눈부시다 이력
# 위 클리 나이키 매니아 품다 네이버 크림 리셀 전쟁 막 오르다
# 단독 네이버 다윈 중개 크롤 링 차단 소송도 검토
# 시그널 엔터 매각 재등판 네이버
# 전기차 화재 발생 하다 왜 전자 언급 되다 재미있다 에너지 이야기
# 주간 추천 주 하반기 실적 개선 셀트리온 헬 스케 어 하나 머티리얼즈 천보
# 해외 직구 족 다 잡 아라가 꺼내다 특별 무기 바로 아마존
# 기아 파업 임협 파업 위기 넘기다 완성 차 업계
# 유가 증권 기업 공시 일 대우건설 등
# 매년 매출 대웅제약 신약 성과 터지다
# 주목 스몰 캡 미래에셋 베다 처 투자 성장 중
# 삼성 개다 노트 단종 하다 이유 이진욱 렛
# 세계 위 반도체 몰락 삼성 반면 교사 삼 아야 박신영 일렉트로 맨
# 위 삼성 잡다 거세지다 반도체 합종 연 횡 배진솔 전자사전
# 삼성 년 플랜 바이오 보다 먼저 등장 하다 이유
# 성사 되다 턱밑 위협 위 기업 합병 추진 삼성 낸드 위 자리 흔들다
# 서학 개미 흥분하다 대 어제 테슬라 상장 삼성 웃다 실리콘밸리 나우
# 삼성 증권 당분간 박스 피 테마 주목
# 금호 벽산 리 모델링 시공사 현 대 삼 성 물산 컨소시엄 선정
# 삼성 화재 설다 학습 플랫폼 호평
# 외인 담다 바이오 외국인 기관 투자자 셀트리온 집중 매수
# 주간 추천 주 하반기 실적 개선 셀트리온 헬 스케 어 하나 머티리얼즈 천보
# 임 상 돋보다 풍 제약 피 맥스 국내 상 승인
# 기업 공시 월 일 쎄다 밉다 시스코 에디슨 모터 스 지 분 억 취득 등
# 유 안타 주간 추천 주 성장 국면 진입 크다 프톤하이텍 쌍용
# 아시아나 항공 일주일 새 상승 무슨 일이 있다
# 시그널 엔터 매각 재등판 네이버
# 블소 부진 엔씨소프트 목표 주가 대폭 하향
# 김경민 템 이 정도 여름철 반려 가전 위니 딤채 창문 형 에어컨
# 하나 금투 주간 추천 주 실적 기 대감 현 대 모비스 하 금융 주원 익머 트리 얼 즈
# 코스닥 기업 공시 일 유일 너 테크 등
# 주목 스몰 캡 자이언트 스텝 가상 인간 새롭다 수익 창 추다
# 주간 추천 주 하반기 실적 개선 셀트리온 헬 스케 어 하나 머티리얼즈 천보
# 넥슨 컴투스 등 주요 게임 사 인재 채용 중
# 펄 어비스 주가 떡 상 시키다 도깨비 도대체 무슨 게임 싸다
# 주간 추천 주 하반기 실적 개선 셀트리온 헬 스케 어 하나 머티리얼즈 천보
# 하나 금투 주간 추천 주 실적 기 대감 현 대 모비스 하 금융 주원 익머 트리 얼 즈
# 한국 타이어 버밍엄 상용차 박람회 신제품 선보이다
# 한섬 온 오프라인 실적 개선 세 힘 입다 하반기 호실 적 전망
# 하나 금투 주간 추천 주 실적 기 대감 현 대 모비스 하 금융 주원 익머 트리 얼 즈
# 코앞 다가오다 사이버 보안 규제 현대차 연내 대응 완료 뒷북 비즈
# 보폭 넓히다 현대차 인도 시장 라인 첫 출시
# 현대차 몬터레이 챔피언십 년 연속 스폰서 브랜드 알리다
# 금호 벽산 리 모델링 시공사 현 대 삼 성 물산 컨소시엄 선정
# 한주 제 약 바이오 휴 젤 조원 인수
# 이 앤 씨 강북 최대 어 북가좌 구역 따내다
# 재건축 대다 북가좌 구역 아크 단 다시 공사 이 앤 씨 낙점
# 동 박 이다 알루미늄 박 뜨다 삼다 알미늄 동일 관심
# 이 앤 씨 서울 강북 최대 어 북가좌 구역 재건축 수주
# 이 앤 씨 층간소음 걱정 끝 바닥 소음 저 감 기술 개발
# 년 마통 쓰다 돈 들어오다 분배 갈등
# 해상 노조 사 측 마지막 협상 대한민국 바 닷 길 운명 하다 주
# 이번 주 파업 갈림길 극적 합의 이루다
# 삼성 두산 네이버 인재 끌다 모으다 한화 년 용인 술 빛나다
# 에너지 솔루션 리콜 비용 부담 늘어나다
# 폴란드 이집트 공조 사업 법인 신설
# 포장 김치 바코드 인식 하다 맞춤 숙성 김치냉장고 신제품 나오다
# 포 원 솔루션 스마트 환기 시스템 개발 하다
# 볼트 리콜 떨어지다 화학 싸다 사다
# 만도 프 플러스 함께 오다 일 네이버 쇼핑 라이브 진행
# 네이버웹툰 스토리 테크 플랫폼 경쟁력 입증
# 무제한 요 금제 고객 대상 갤럭시 버즈 팩 출시
# 유플러스 배당 성향 상향 기 대감
# 전자 김치냉장고 디오스 김치 톡톡 신제품 출시
# 전자 로 포장 김치 최상 맛 관리
# 무제한 요 금제 가입 하다 갤럭시 버즈 드리다
# 개다 사전예약 놓치다 버즈 없다 받다 보다
# 전 자월 풀 글로벌 생활 가전 위 북미 뒷 심 달리다
# 전자 년 째 탄소 배출 부채 원 탄소 중립 청 신호
# 가다 김치 맛 살리다 디오스 김치 톡톡 신제품 출시
# 현 대 중공업 리츠 이번 주 눈 여기다 볼 공 모주
# 종합 화학 브랜드 뉴 데이 열다 사명 변경 지오 세다 트릭 유력
# 뇌출혈 영상 판독 솔루션 의료기기 정식 허가
# 이노 맹그로브 숲 복원 베트남 공로상
# 베트남 인정 이노 맹그로브 숲 복원 사업
# 년 간 맹그로브 숲 복원 이노 베트남 공로상
# 리츠 수요 예측 대다 리츠 열풍 재 시작
# 젊다 총수 재계 맏형 자산 배 고속 성장 일구다 최태원 경영 년
# 종합 화학 년 간판 바꾸다 세다 트릭 유력
# 방역 로봇 키 미가 포스코 오다 산업 현장 적용 맞다 손
# 포스코 산업 안전 및 품질 검사 솔루션 개발 협력
# 방역 로봇 키 미가 포스코 오다 산업 현장 적용 맞다 손
# 신입사원 아이디어 채택 유심 크기 반 줄이다
# 번가 기반 장애인 근무 환경 개선
# 외교부 이프 랜드 세계 평화 유지 알리다 나서다
# 포스코 산업 안전 및 품질 검사 솔루션 개발 협력
# 이노베이션 맹그로브 숲 복원 베트남 공로상 수상
# 이노베이션 베트남 정부 공로상 수상
# 포스코 현 대미 포 조선 액화 이산화탄소 운반 선 개발 맞다 손
# 경동나비엔 보일러 위상 높이다
# 깨끗하다 친환경 포장재 크라프트 보드 출시
# 기아차 체험 공간 개장
# 내 돈 가져가다 명 외치 만들다 기아 신차 털다
# 배양육 개발 스페이스 에프 대상 롯데 등 억 투자 받다 주간 동향
# 눈높이 대교 에듀 테크 전문가 영 입 뒤
# 대우건설 소형 위주 생활 숙박시설 서면 푸르지오 시티 시 그 니 처 월 분양
# 대우건설 원전 해체 기술 력 확보 총력전
# 커피 왕 동서 카누 덕 톡톡 년새 현금 성 자산 껑충
# 삼성 두산 네이버 인재 끌다 모으다 한화 년 용인 술 빛나다
# 물류 호황 잡다 두산 현대 지게차
# 만도 프 플러스 함께 오다 일 네이버 쇼핑 라이브 진행
# 정몽원 실리콘밸리 만도 미래 찾다
# 현 대 건설 삼 성 물산 금호 벽산 리 모델링 수주 사업 규모 억 수준
# 현 대 건설 삼 성 물산 컨소시엄 금호 벽산 아파트 리 모델링 수주
# 삼성 전자 비 스코프 큐 크다 출시 개월 만대 판매
# 단독 플립 폴더 대 기자 서다 만 육박 삼성 스마트폰 재 도약 기 대감
# 삼성 두산 네이버 인재 끌다 모으다 한화 년 용인 술 빛나다
# 보험사 상반기 순 익 코로나 삼전 배당 효과
# 중국 폰 얕다 보지 말다 삼성 경고 장
# 보험사 상반기 순이익 약 증가 삼성 전자 배당 효과 등
# 년 간 만 명 채용 삼성 취준생 입사 싶다 그룹 위
# 사로자다 삼성 비 스포크 큐 크다
# 코스피 주간 외국인 순 매도 위 삼성 전자
# 삼성 야심작 엑시노스 월 출시 시스템 반도체 위 도전
# 삼성 비 스포크 큐 크다 만대 돌파
# 동 박 이다 알루미늄 박 뜨다 삼다 알미늄 동일 관심
# 저 점 확인 여전하다 종목 대응 구간 삼성 증권 주간 추천 종목
# 코스닥 주간 개인 순 매도 위 셀트리온 헬 스케 어
# 코스피 주간 개인 순 매도 위 셀트리온
# 쌍용차 예비 실사 종료 내달 일 인수 제안 접수
# 신한은행 금융 권 최초 글로벌 정보보호 시스템 오픈
# 알톤스포츠 배달 적합하다 전기자전거 종 출시
# 리츠 이비 온 와이 엠텍 등 공모 청약
# 항 암 백신 에스티 파다 믹트 리 기술 력 차이 극복 방안
# 코스닥 주간 외국인 순 매수 위 에코 프로비 엠
# 지 켐 생명과학 코로나 치료 제 후보 물질 임 상 상 실패
# 코스피 주간 개인 순 매수 위 엔씨소프트
# 코스피 주간 기관 순 매도 위 엔씨소프트
# 우리금융 가입 탄소 중립 앞장
# 우리금융 글로벌 환경 이니셔티브 가입
# 이베이 본격 나선 이마트 완성형 온 오프 에코 시스템 만들다
# 이마트 추석 선물 세트 사전예약
# 항 암 백신 에스티 파다 믹트 리 기술 력 차이 극복 방안
# 캔서롭 임종윤 대표 대상 백억 유증 글로벌 백신 허브 도약
# 매경 회계 대상 카카오
# 코스피 주간 외국인 순 매수 위 카카오
# 취준생 꿈 직장 삼성 카카오 택 이유 연봉 더 중요하다 것
# 샐러리맨 대박 신화 카카오 이직 선호 압도 적 위
# 프리미엄 디자인 가전 테리어 대세 되다 코웨이
# 공 시 돋보기 코오롱 생명과학 상반기 흑자 관리종목 해제 청 신호
# 크리스탈 지노 믹스 췌장암 임 상 상 승인 신청
# 코스닥 주간 외국인 순 매도 위 펄 어비스
# 하나은행 소상 공인 동반 캠페인 실시
# 현 대 중공업 리츠 이번 주 눈 여기다 볼 공 모주
# 증시 캘린더 이번 주 월주 현대 중공업 수 요 예측 스팩 호 상장 등
# 물류 호황 잡다 두산 현대 지게차
# 현대 이번 주 공모 확정
# 적자 한전 전기요금 올리다 대선 앞두다 다시 동결 하다
# 한국 타이어 유로파리그 년 더 뛰다
# 한진 루브리컨츠 친환경 윤활유 협력 속도
# 현 대 건설 삼 성 물산 컨소시엄 금호 벽산 아파트 리 모델링 수주
# 글로벌 수준 확대 현대 건설 토탈 솔루션 크리에이터 변신
# 코스피 주간 기관 순 매수 위 한화 투자 증권
# 한화 솔루션 합성가스 사업 증설 내달 완료
# 삼성 두산 네이버 인재 끌다 모으다 한화 년 용인 술 빛나다
# 백화점 곰표 오다 곰 현 대 백화점 판교 점 곰표 하우스 팝업 스토어 오픈
# 포스코 현 대미 포 조선 액화 이산화탄소 운반 선 개발 맞다 손
# 메인 컬러 레드 금기 도전 현 대리 바트 세대 잡다
# 현대 글로비스 협력 사오다 경영 속도
# 장재훈 현대차 사장 글로벌 대다 모터쇼 데뷔
# 현대차 통합 제어 적용 테슬라 넘다
# 리 모델링 시동 건 당산 현대 홈 타운 효성
# 탄소배출권 값 오르다 휴 켐스 꿈틀꿈틀

# %%
data_file = 'news_title.data'

# %%
# # 추출한 핵심 형태소파일 저장 
# with open(data_file, 'w', encoding='utf-8') as fp:
#   fp.write('\n'.join(result))

# %%
data = word2vec.LineSentence(data_file)
model = word2vec.Word2Vec(data, size=200, window=10, hs=1, min_count=2, sg=1)

# %%
# # 모델 저장
# model.save('news_title.model')

# %%
## 비슷한 단어를 찾아보자

# %%
# 삼성
# 2021년 여름, 삼성엔 호재보다는 악재가 많았던 듯 하다.
model.wv.most_similar(positive=['삼성'])
# Out:
# [('전자', 0.7103176116943359),
#  ('좌절', 0.6284874677658081),
#  ('훈풍간', 0.5995469093322754),
#  ('빨르다', 0.5895366668701172),
#  ('패닉', 0.5888943672180176),
#  ('지나', 0.5865036249160767),
#  ('모처럼', 0.5823673009872437),
#  ('메모리', 0.5794491767883301),
#  ('횡보', 0.5729840993881226),
#  ('뚝뚝', 0.5729659795761108)]

# %%
#하이닉스
model.wv.most_similar(positive=['하이닉스'])
# Out:
# [('마이크론', 0.743344783782959),
#  ('연중', 0.7430227994918823),
#  ('성전', 0.7170588970184326),
#  ('외치다', 0.7150694131851196),
#  ('한때', 0.7109510898590088),
#  ('시도', 0.7078979015350342),
#  ('깨지다', 0.7068849802017212),
#  ('반갑다', 0.7015964984893799),
#  ('엿새', 0.700909435749054),
#  ('램', 0.7005412578582764)]

# %%
# 메타버스

model.wv.most_similar(positive=['메타'])
# Out:
# [('버스', 0.9269239902496338),
#  ('합류', 0.8003524541854858),
#  ('연합군', 0.7831463813781738),
#  ('가상현실', 0.7659169435501099),
#  ('수료식', 0.759905219078064),
#  ('성큼', 0.7563462257385254),
#  ('콘텍', 0.7466071844100952),
#  ('타이젠', 0.7371206283569336),
#  ('신입사원', 0.7317814230918884),
#  ('이프', 0.7258995771408081)]

# %%
# 엔씨소프트
model.wv.most_similar(positive=['엔씨소프트'])
# Out:
# [('블소', 0.8332501649856567),
#  ('신작', 0.8095821142196655),
#  ('리니지', 0.8027992248535156),
#  ('참패', 0.7702467441558838),
#  ('홀드', 0.7569772005081177),
#  ('펄', 0.7539892196655273),
#  ('도깨비', 0.7504485845565796),
#  ('오딘', 0.7477036118507385),
#  ('붉다', 0.7418726682662964),
#  ('어비스', 0.7409175634384155)]
