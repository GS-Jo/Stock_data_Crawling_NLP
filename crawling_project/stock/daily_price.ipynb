# %%
# !scrapy startproject S_price

# %%
from datetime import datetime
import pandas as pd
import requests
import time


today = datetime.today().strftime('%Y-%m-%d')


print(today, end=" ")
date = str(today).split(" ")[0].replace("-", "")
url = "http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"
params = {
    "bld": "dbms/MDC/STAT/standard/MDCSTAT01501",
    "mktId": "ALL",
    "trdDd": date,
    "share": "1",
    "money": "1",
    "csvxls_isNo": "false",
}
response = requests.post(url, params)
datas = response.json()["OutBlock_1"]
df = pd.DataFrame(datas)
df["DATE"] = date


df.reset_index(inplace=True)
df.to_csv("데이터.csv")
# Out:
# 2021-06-10

# %%
stock_price = pd.read_csv('/Users/ksjo/Documents/cp/데이터.csv',index_col=0)
stock_price
# Out:
#       index ISU_SRT_CD ISU_ABBRV  MKT_NM SECT_TP_NM TDD_CLSPRC  FLUC_TP_CD  \
# 0         0     060310        3S  KOSDAQ      중견기업부      3,150           1
# 1         1     095570    AJ네트웍스   KOSPI        NaN      5,350           1
# 2         2     006840     AK홀딩스   KOSPI        NaN     35,600           1
# 3         3     054620    APS홀딩스  KOSDAQ      중견기업부     14,150           2
# 4         4     265520     AP시스템  KOSDAQ      우량기업부     29,000           3
# ...     ...        ...       ...     ...        ...        ...         ...
# 2565   2565     000547   흥국화재2우B   KOSPI        NaN     31,950           1
# 2566   2566     000545     흥국화재우   KOSPI        NaN     11,350           1
# 2567   2567     003280      흥아해운   KOSPI        NaN        258           0
# 2568   2568     037440        희림  KOSDAQ      중견기업부      8,810           2
# 2569   2569     238490        힘스  KOSDAQ      우량기업부     11,400           1
#
#      CMPPREVDD_PRC  FLUC_RT TDD_OPNPRC TDD_HGPRC TDD_LWPRC ACC_TRDVOL  \
# 0               45     1.45      3,105     3,185     3,010    314,027
# 1               40     0.75      5,410     5,470     5,320    270,969
# 2              350     0.99     35,250    35,900    34,900     69,442
# 3             -550    -3.74     14,650    14,850    14,050     82,771
# 4                0     0.00     29,000    29,250    28,650    172,117
# ...            ...      ...        ...       ...       ...        ...
# 2565           650     2.08     31,750    33,900    31,300     10,183
# 2566           150     1.34     11,250    11,550    11,250      7,720
# 2567             0     0.00          0         0         0          0
# 2568          -890    -9.18      9,480     9,650     8,220  1,734,940
# 2569           100     0.88     11,350    11,550    11,300     38,259
#
#           ACC_TRDVAL           MKTCAP    LIST_SHRS MKT_ID      DATE
# 0        975,190,275  145,755,265,950   46,271,513    KSQ  20210610
# 1      1,455,922,900  250,499,278,250   46,822,295    STK  20210610
# 2      2,471,358,350  471,613,171,600   13,247,561    STK  20210610
# 3      1,192,341,300  288,578,227,150   20,394,221    KSQ  20210610
# 4      4,998,816,250  419,926,583,000   14,480,227    KSQ  20210610
# ...              ...              ...          ...    ...       ...
# 2565     335,564,900    4,907,520,000      153,600    STK  20210610
# 2566      87,901,950    8,716,800,000      768,000    STK  20210610
# 2567               0   30,117,000,222  116,732,559    STK  20210610
# 2568  15,672,918,340  122,657,004,750   13,922,475    KSQ  20210610
# 2569     436,801,500  128,959,490,400   11,312,236    KSQ  20210610
#
# [2570 rows x 18 columns]
